# %%
import logging
logging.captureWarnings(False)
logging.getLogger('py.warnings').setLevel(logging.ERROR)
from dask.distributed import Client, progress
client = Client(n_workers=5, threads_per_worker=4, memory_limit='30GB')
client
# Out:
# <Client: 'tcp://127.0.0.1:56920' processes=5 threads=20, memory=139.70 GiB>

# %%
import xarray
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import numpy as np
import scipy as sp
import pandas as pd
from netCDF4 import Dataset
import dask
import torch
import torch.nn as nn
import torch.fft as fft
import subprocess
import sys

from sht_utils import *
from subs1_utils import *

# %%
### This cell initializes the model
###
###     First Define all spectral grids
###
zw = 42 # zonal wave number
mw = 42 # meridional wave number
kmax = 11
imax = 128
jmax = 64
steps_per_day = 216 ### Changing this number implies time step changes and should
#                       be implemented carefully
rescale = 13 # rescale interval for bred-vector approach to linear model
###
#
#
# provide experiment name and data path for writing out data
# datapath may need to be edited for your system
#
expname = 'PrescribedMeanLinearT42L11F'
foo = str(subprocess.check_output(['whoami']))
end = len(foo) - 3
uname = foo[2:end]
datapath = '/Users/'+uname+'/Work/AGCM/AGCM/tmp4/'+expname+'/'
subprocess.call(['rm','-r', datapath])
subprocess.check_output(['mkdir', datapath])
# Out:
# b''

# %%
# Get the Gaussian latitudes and equally spaced longitudes
#
cost_lg, wlg = legendre_gauss_weights(jmax, -1, 1)
lats = np.flip(np.arccos(cost_lg))
lats = -90+180*lats/(np.pi)
#
lons = np.linspace(0.0,360.0-360.0/imax,imax)
#
# Initialize grid to spectral (sht) and spectral to grid (isht)
# transforms
#
sht = RealSHT(jmax, imax, lmax=mw, mmax=zw, grid="legendre-gauss", csphase=False)
isht = InverseRealSHT(jmax, imax, lmax=mw, mmax=zw, grid="legendre-gauss", csphase=False)
vsht = RealVectorSHT(jmax, imax, lmax=mw, mmax=zw, grid="legendre-gauss", csphase=False)
ivsht = InverseRealVectorSHT(jmax, imax, lmax=mw, mmax=zw, grid="legendre-gauss", csphase=False)

# %%
#
# Initialization: Could read spectral restarts, or could
#              start at rest. If wanting to use grid point see
#              jupyter notebook preprocess
#              
#
# Implement at rest initial condition, but need coriolis
#
#
coriolis = np.zeros((jmax,imax))
for jj in range(jmax):
    coriolis[jj,:] = -(4.0*np.pi/86400)*cost_lg[jj] # minus sign because 
                                                    #grid runs South-To-North
#
#
# Initialize spectral fields (at rest or to be read in)
#
zmn1 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
zmn2 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
zmn3 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
dmn1 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
dmn2 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
dmn3 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
tmn1 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
tmn2 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
tmn3 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
wmn1 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
wmn2 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
wmn3 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
qmn1 = torch.zeros((mw,zw),dtype=torch.complex128)
qmn2 = torch.zeros((mw,zw),dtype=torch.complex128)
qmn3 = torch.zeros((mw,zw),dtype=torch.complex128)
#
# Introduce an initial perturbation to get things going (but make them small)
#
datapath_init = '/Users/'+uname+'/Work/AGCM/AGCM/tmp4/Restarts/PerturbationT42L11/'
zmn1 = (torch.load(datapath_init+'zmn1.spectral.pt'))/1000.0
zmn2 = (torch.load(datapath_init+'zmn2.spectral.pt'))/1000.0
dmn1 = (torch.load(datapath_init+'dmn1.spectral.pt'))/1000.0
dmn2 = (torch.load(datapath_init+'dmn2.spectral.pt'))/1000.0
tmn1 = (torch.load(datapath_init+'tmn1.spectral.pt'))/1000.0
tmn2 = (torch.load(datapath_init+'tmn2.spectral.pt'))/1000.0
qmn1 = (torch.load(datapath_init+'qmn1.spectral.pt'))/1000.0
qmn2 = (torch.load(datapath_init+'qmn2.spectral.pt'))/1000.0
#
#
# Topography data - this should be spectral data or can be
#                        initialized to zero. If grid point data
#                        is desired see gptosp.agcm.ipynb for how to
#                        convert to spectral. 
#
# Setting topography to zero here
#
phismn = torch.zeros((mw,zw),dtype=torch.complex128)
#
# If non-zero topog read here
#
####phismn = torch.load('topog.spectral.pt') # only read topography is background state is zonally symmetric
#
#
# Adding heating here see preprocess.ipynb
#
heat = torch.load('heat.ggrid.pt')
#
# or set to zero
#
###heat = torch.zeros((kmax,jmax,imax),dtype=torch.float64)
#
#
# Read Climatology on Gausian Grid
#
uclim = torch.load('usig.ggrid.pt')
vclim = torch.load('vsig.ggrid.pt')
tclim = torch.load('tsig.ggrid.pt')
vortclim = torch.load('vortsig.ggrid.pt')
divclim = torch.load('divsig.ggrid.pt')
dxqclim = torch.load('dxq_gg.ggrid.pt')
dyqclim = torch.load('dyq_gg.ggrid.pt')
#
#

# %%
###
### Constants, parameters, vertical differencing parameters,
### matricies for geopotential height, etc ...
###
delsig, si, sl, sikap, slkap, cth1, cth2, r1b, r2b = bscst(kmax)
### The above code is in subs1_utils.py - vertical structure related
### This code would need to be changed if the vertical resolution
### is changed - could be done by simply specifying delsig in bscst
###
amtrx, cmtrx, dmtrx = mcoeff(kmax,si,sl,slkap,r1b,r2b,delsig)
### The above code is for geopotential height and implicit scheme
### in subs1_utils.py but unlikely any changes would be needed
emtrx = inv_em(dmtrx,steps_per_day,kmax,mw,zw)
### The above code
### emtrix is used in the implicit time scheme, computed once here to save cpu time
### changes unlikely

# %%
#### Preprocessing is complete - now time to run model
#
#
# The Model Runs in 30-day chuncks - need to specify how many 30-day chunks to run
tl = 30 ##### tl is the chunk size - typically 30 days, but for testing 3 is reasonable
#
# Suggested ichunk for time dependent models: 120
#
ae = 6.371E+06 # Earth radius
tmnt = torch.zeros((tl,kmax,mw,zw),dtype=torch.complex128)
zmnt = torch.zeros((tl,kmax,mw,zw),dtype=torch.complex128)
dmnt = torch.zeros((tl,kmax,mw,zw),dtype=torch.complex128)
qmnt = torch.zeros((tl,mw,zw),dtype=torch.complex128)
wmnt = torch.zeros((tl,kmax,mw,zw),dtype=torch.complex128)
#
ddtdiv = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
ddtvort = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
junk = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
ttend = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
#
vort = torch.zeros((kmax,jmax,imax),dtype=torch.float64)
div = torch.zeros((kmax,jmax,imax),dtype=torch.float64)
temp = torch.zeros((kmax,jmax,imax),dtype=torch.float64)
qdot = torch.zeros((kmax,jmax,imax),dtype=torch.float64)
times = pd.date_range(start = '1950-01-01', end='2100-01-01', freq='D')
# 
ichunk = 30
#
idays = tl * ichunk
#
#
#
#
# Begin Time Loop
#
ii = 0
savedat = 0
daycount = 0
total_days = 0
nstep = idays*steps_per_day
irescale = 0
#
while ii < nstep:
    ii = ii + 1
    savedat = savedat + 1
    zmnt[daycount] = zmnt[daycount] + zmn1/steps_per_day
    dmnt[daycount] = dmnt[daycount] + dmn1/steps_per_day
    tmnt[daycount] = tmnt[daycount] + tmn1/steps_per_day
    qmnt[daycount] = qmnt[daycount] + qmn1/steps_per_day
    wmnt[daycount] = wmnt[daycount] + wmn1/steps_per_day
    if (savedat == steps_per_day): # post processing
        #
        # Call Postprocessing Routine as needed
        #
        print((dmn1[10,2,2],dmn1[9,2,1]))
        daycount = daycount + 1
        total_days = total_days + 1
        print(['Day = ',total_days])
        if (daycount == tl):
            times_30day = times[total_days-tl:total_days]
            postprocessing(isht,ivsht,zmnt,dmnt,tmnt,qmnt,wmnt,\
                           phismn,amtrx,times_30day,mw,zw,\
                           kmax,imax,jmax,sl,lats,lons,tl,datapath)
            tmnt = torch.zeros((tl,kmax,mw,zw),dtype=torch.complex128)
            zmnt = torch.zeros((tl,kmax,mw,zw),dtype=torch.complex128)
            dmnt = torch.zeros((tl,kmax,mw,zw),dtype=torch.complex128)
            qmnt = torch.zeros((tl,mw,zw),dtype=torch.complex128)
            wmnt = torch.zeros((tl,kmax,mw,zw),dtype=torch.complex128)
            daycount = 0
        savedat = 0
        irescale = irescale + 1
        scale = 1.0e+03
        if ( irescale == rescale ): ### Applying bred vector approach here
            irescale = 0
            zmn1 = zmn1/scale
            zmn2 = zmn2/scale
            dmn1 = dmn1/scale
            dmn2 = dmn2/scale
            tmn1 = tmn1/scale
            tmn2 = tmn1/scale
            qmn1 = qmn1/scale
            qmn2 = qmn1/scale
        #
    #
    # Run model for one time step
    #
    # Spectral to grid transformation of needed fields:
    #   Vorticity, divergence, temperature, U, V, 
    #   grad(ln(Ps)), Q prescibed heating
    #
    #
    for k in range(kmax):
        vort[k] = isht(zmn2[k]).cpu() ### This is the relative vorticity
        div[k] = isht(dmn2[k]).cpu()
        temp[k] = isht(tmn2[k]).cpu()
        qdot[k] = isht(wmn2[k]).cpu()
    u,v = uv(ivsht,zmn2,dmn2,mw,zw,kmax,imax,jmax)
    dxq,dyq = gradq(ivsht,qmn2,mw,zw,imax,jmax)
    #
    # Stack grid variables climo first[0] perturbation second[1]
    #
    vort2 = torch.stack((vortclim,vort)) # vortclim is the absolute vorticity
    div2 = torch.stack((divclim,div))
    temp2 = torch.stack((tclim,temp))
    u2 = torch.stack((uclim,u))
    v2 = torch.stack((vclim,v))
    dxq2 = torch.stack((dxqclim,dxq))
    dyq2 = torch.stack((dyqclim,dyq))
    #
    # Non-Linear products
    #
    a,b,e,ut,vt,ri,wj,cbar,dbar = nlprod_prescribed_mean_linear(u2,v2,vort2,div2,temp2,dxq2,dyq2,heat,coriolis,delsig,si,sikap,slkap,\
                                         r1b,r2b,cth1,cth2,cost_lg,kmax,imax,jmax)
    #
    #
    # Grid to spectral transformation of nlprod results
    #
    ddtdiv,ddtvort = vortdivspec(vsht,a,b,kmax,mw,zw)
    zmn3 = - ddtvort
    dmn3 = ddtdiv
    junk,ttend = vortdivspec(vsht,ut,vt,kmax,mw,zw)
    for k in range(kmax):
        dddt = dmn3[k] - lap_sht(sht,e[k],mw,zw) 
        dmn3[k] = dddt
        tmn3[k] = -ttend[k] + sht(ri[k]).cpu()
        wmn3[k] = sht(wj[k]).cpu() ### Prescribed heating converted to spectral
    qmn3 = -sht(cbar[1]).cpu() ### Only cbar here since dbar is included in implicit or explicit
    # 
    # Diffusion, Damping, Implicit or Explicit time differencing, Time filter
    #
    zmn3,dmn3,tmn3 = diffsn(zmn1,zmn3,dmn1,dmn3,tmn1,tmn3,\
                            kmax,mw,zw)
    #
    zmn3,dmn3,tmn3,qmn3 = damp_prescribed_mean(zmn1,zmn3,dmn1,dmn3,tmn1,tmn3,qmn1,qmn3,\
                          kmax)
    #
    dt = 86400.0/steps_per_day
    #
    zmn1,zmn2,zmn3,dmn1,dmn2,dmn3,tmn1,tmn2,tmn3,qmn1,qmn2,qmn3 = \
                        explicit(dt,amtrx,cmtrx,dmtrx,emtrx,\
                        zmn1,zmn2,zmn3,dmn1,dmn2,dmn3,tmn1,tmn2,\
                        tmn3,wmn1,wmn2,wmn3,qmn1,qmn2,qmn3,phismn,\
                        delsig,kmax,mw,zw)
    ####
    ## Reset zmn3, dmn3, tmn3,wmn3 & qmn3
    ###
    zmn3 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
    dmn3 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
    tmn3 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
    wmn3 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
    qmn3 = torch.zeros((mw,zw),dtype=torch.complex128)
#
# Done
# Out:
# (tensor(-8.8111e-08+2.5327e-08j, dtype=torch.complex128), tensor(2.1477e-08-2.4242e-09j, dtype=torch.complex128))
# ['Day = ', 1]
# (tensor(-7.8242e-08+1.2677e-07j, dtype=torch.complex128), tensor(1.5507e-08+9.3716e-09j, dtype=torch.complex128))
# ['Day = ', 2]
# (tensor(-2.2272e-08+1.3529e-07j, dtype=torch.complex128), tensor(2.1964e-08-5.1959e-09j, dtype=torch.complex128))
# ['Day = ', 3]
# (tensor(-2.4270e-08+1.0265e-07j, dtype=torch.complex128), tensor(2.1024e-08-7.5943e-10j, dtype=torch.complex128))
# ['Day = ', 4]
# (tensor(-2.0588e-08+7.8092e-08j, dtype=torch.complex128), tensor(1.5259e-08+1.2912e-09j, dtype=torch.complex128))
# ['Day = ', 5]
# (tensor(-2.2321e-08+5.7502e-08j, dtype=torch.complex128), tensor(2.5193e-08-7.0214e-09j, dtype=torch.complex128))
# ['Day = ', 6]
# (tensor(-3.2092e-08+3.2826e-08j, dtype=torch.complex128), tensor(1.4349e-08-5.7282e-09j, dtype=torch.complex128))
# ['Day = ', 7]
# (tensor(-7.7918e-08+2.5130e-08j, dtype=torch.complex128), tensor(1.5258e-08+2.1609e-09j, dtype=torch.complex128))
# ['Day = ', 8]
# (tensor(-9.2532e-08+6.6950e-08j, dtype=torch.complex128), tensor(2.2667e-08+1.4550e-08j, dtype=torch.complex128))
# ['Day = ', 9]
# (tensor(-6.3647e-08+8.5013e-08j, dtype=torch.complex128), tensor(2.7753e-08+1.1080e-09j, dtype=torch.complex128))
# ['Day = ', 10]
# (tensor(-5.3548e-08+6.6759e-08j, dtype=torch.complex128), tensor(1.4252e-08+6.9111e-09j, dtype=torch.complex128))
# ['Day = ', 11]
# (tensor(-7.2867e-08+4.7049e-08j, dtype=torch.complex128), tensor(8.6525e-09+7.3669e-09j, dtype=torch.complex128))
# ['Day = ', 12]
# (tensor(-7.7967e-08+6.2465e-08j, dtype=torch.complex128), tensor(1.3213e-08+9.0558e-09j, dtype=torch.complex128))
# ['Day = ', 13]
# (tensor(-8.7821e-08+2.5712e-08j, dtype=torch.complex128), tensor(2.1575e-08-2.5941e-09j, dtype=torch.complex128))
# ['Day = ', 14]
# (tensor(-7.7870e-08+1.2690e-07j, dtype=torch.complex128), tensor(1.5695e-08+9.3618e-09j, dtype=torch.complex128))
# ['Day = ', 15]
# (tensor(-2.2254e-08+1.3490e-07j, dtype=torch.complex128), tensor(2.2032e-08-5.4956e-09j, dtype=torch.complex128))
# ['Day = ', 16]
# (tensor(-2.4415e-08+1.0272e-07j, dtype=torch.complex128), tensor(2.0903e-08-5.7265e-10j, dtype=torch.complex128))
# ['Day = ', 17]
# (tensor(-2.0496e-08+7.8503e-08j, dtype=torch.complex128), tensor(1.5286e-08+1.0418e-09j, dtype=torch.complex128))
# ['Day = ', 18]
# (tensor(-2.2057e-08+5.7714e-08j, dtype=torch.complex128), tensor(2.4648e-08-7.5170e-09j, dtype=torch.complex128))
# ['Day = ', 19]
# (tensor(-3.1830e-08+3.2893e-08j, dtype=torch.complex128), tensor(1.4267e-08-6.0213e-09j, dtype=torch.complex128))
# ['Day = ', 20]
# (tensor(-7.7903e-08+2.5515e-08j, dtype=torch.complex128), tensor(1.4920e-08+1.1980e-09j, dtype=torch.complex128))
# ['Day = ', 21]
# (tensor(-9.2684e-08+6.7097e-08j, dtype=torch.complex128), tensor(2.2596e-08+1.4165e-08j, dtype=torch.complex128))
# ['Day = ', 22]
# (tensor(-6.4114e-08+8.4957e-08j, dtype=torch.complex128), tensor(2.9834e-08+1.1530e-09j, dtype=torch.complex128))
# ['Day = ', 23]
# (tensor(-5.3681e-08+6.6957e-08j, dtype=torch.complex128), tensor(1.6539e-08+6.5042e-09j, dtype=torch.complex128))
# ['Day = ', 24]
# (tensor(-7.1925e-08+4.8820e-08j, dtype=torch.complex128), tensor(9.8288e-09+6.8737e-09j, dtype=torch.complex128))
# ['Day = ', 25]
# (tensor(-7.4767e-08+6.7438e-08j, dtype=torch.complex128), tensor(8.2835e-09+2.6212e-09j, dtype=torch.complex128))
# ['Day = ', 26]
# (tensor(-8.7817e-08+2.5717e-08j, dtype=torch.complex128), tensor(2.1564e-08-2.6048e-09j, dtype=torch.complex128))
# ['Day = ', 27]
# (tensor(-7.7869e-08+1.2690e-07j, dtype=torch.complex128), tensor(1.5683e-08+9.3496e-09j, dtype=torch.complex128))
# ['Day = ', 28]
# (tensor(-2.2260e-08+1.3489e-07j, dtype=torch.complex128), tensor(2.2034e-08-5.4980e-09j, dtype=torch.complex128))
# ['Day = ', 29]
# (tensor(-2.4427e-08+1.0270e-07j, dtype=torch.complex128), tensor(2.0949e-08-5.5349e-10j, dtype=torch.complex128))
# ['Day = ', 30]
# (tensor(-2.0503e-08+7.8494e-08j, dtype=torch.complex128), tensor(1.5370e-08+1.0710e-09j, dtype=torch.complex128))
# ['Day = ', 31]
# (tensor(-2.2037e-08+5.7751e-08j, dtype=torch.complex128), tensor(2.4685e-08-7.5119e-09j, dtype=torch.complex128))
# ['Day = ', 32]
# (tensor(-3.1754e-08+3.3010e-08j, dtype=torch.complex128), tensor(1.4119e-08-6.1246e-09j, dtype=torch.complex128))
# ['Day = ', 33]
# (tensor(-7.7799e-08+2.5653e-08j, dtype=torch.complex128), tensor(1.4426e-08+9.4378e-10j, dtype=torch.complex128))
# ['Day = ', 34]
# (tensor(-9.2692e-08+6.7143e-08j, dtype=torch.complex128), tensor(2.1968e-08+1.3969e-08j, dtype=torch.complex128))
# ['Day = ', 35]
# (tensor(-6.4369e-08+8.4707e-08j, dtype=torch.complex128), tensor(3.0047e-08+1.4056e-09j, dtype=torch.complex128))
# ['Day = ', 36]
# (tensor(-5.4160e-08+6.6171e-08j, dtype=torch.complex128), tensor(1.8649e-08+7.7024e-09j, dtype=torch.complex128))
# ['Day = ', 37]
# (tensor(-7.2292e-08+4.8178e-08j, dtype=torch.complex128), tensor(1.3549e-08+8.9307e-09j, dtype=torch.complex128))
# ['Day = ', 38]
# (tensor(-7.3938e-08+6.8627e-08j, dtype=torch.complex128), tensor(1.0419e-08+3.3318e-09j, dtype=torch.complex128))
# ['Day = ', 39]
# (tensor(-8.7815e-08+2.5720e-08j, dtype=torch.complex128), tensor(2.1561e-08-2.6088e-09j, dtype=torch.complex128))
# ['Day = ', 40]
# (tensor(-7.7867e-08+1.2690e-07j, dtype=torch.complex128), tensor(1.5668e-08+9.3407e-09j, dtype=torch.complex128))
# ['Day = ', 41]
# (tensor(-2.2259e-08+1.3489e-07j, dtype=torch.complex128), tensor(2.2016e-08-5.5042e-09j, dtype=torch.complex128))
# ['Day = ', 42]
# (tensor(-2.4435e-08+1.0269e-07j, dtype=torch.complex128), tensor(2.0955e-08-5.4677e-10j, dtype=torch.complex128))
# ['Day = ', 43]
# (tensor(-2.0520e-08+7.8466e-08j, dtype=torch.complex128), tensor(1.5429e-08+1.1065e-09j, dtype=torch.complex128))
# ['Day = ', 44]
# (tensor(-2.2053e-08+5.7734e-08j, dtype=torch.complex128), tensor(2.4798e-08-7.4548e-09j, dtype=torch.complex128))
# ['Day = ', 45]
# (tensor(-3.1729e-08+3.3034e-08j, dtype=torch.complex128), tensor(1.4205e-08-6.1089e-09j, dtype=torch.complex128))
# ['Day = ', 46]
# (tensor(-7.7714e-08+2.5739e-08j, dtype=torch.complex128), tensor(1.4238e-08+8.3382e-10j, dtype=torch.complex128))
# ['Day = ', 47]
# (tensor(-9.2598e-08+6.7319e-08j, dtype=torch.complex128), tensor(2.1326e-08+1.3679e-08j, dtype=torch.complex128))
# ['Day = ', 48]
# (tensor(-6.4370e-08+8.4756e-08j, dtype=torch.complex128), tensor(2.9326e-08+1.0699e-09j, dtype=torch.complex128))
# ['Day = ', 49]
# (tensor(-5.4478e-08+6.5635e-08j, dtype=torch.complex128), tensor(1.8853e-08+7.9698e-09j, dtype=torch.complex128))
# ['Day = ', 50]
# (tensor(-7.3072e-08+4.7229e-08j, dtype=torch.complex128), tensor(1.6066e-08+1.0468e-08j, dtype=torch.complex128))
# ['Day = ', 51]
# (tensor(-7.4430e-08+6.8014e-08j, dtype=torch.complex128), tensor(1.5655e-08+5.4441e-09j, dtype=torch.complex128))
# ['Day = ', 52]
# (tensor(-8.7814e-08+2.5720e-08j, dtype=torch.complex128), tensor(2.1564e-08-2.6080e-09j, dtype=torch.complex128))
# ['Day = ', 53]
# (tensor(-7.7865e-08+1.2691e-07j, dtype=torch.complex128), tensor(1.5662e-08+9.3372e-09j, dtype=torch.complex128))
# ['Day = ', 54]
# (tensor(-2.2256e-08+1.3490e-07j, dtype=torch.complex128), tensor(2.1998e-08-5.5137e-09j, dtype=torch.complex128))
# ['Day = ', 55]
# (tensor(-2.4434e-08+1.0269e-07j, dtype=torch.complex128), tensor(2.0932e-08-5.5531e-10j, dtype=torch.complex128))
# ['Day = ', 56]
# (tensor(-2.0531e-08+7.8452e-08j, dtype=torch.complex128), tensor(1.5429e-08+1.1169e-09j, dtype=torch.complex128))
# ['Day = ', 57]
# (tensor(-2.2076e-08+5.7711e-08j, dtype=torch.complex128), tensor(2.4872e-08-7.4138e-09j, dtype=torch.complex128))
# ['Day = ', 58]
# (tensor(-3.1742e-08+3.3000e-08j, dtype=torch.complex128), tensor(1.4367e-08-6.0427e-09j, dtype=torch.complex128))
# ['Day = ', 59]
# (tensor(-7.7689e-08+2.5750e-08j, dtype=torch.complex128), tensor(1.4337e-08+8.8140e-10j, dtype=torch.complex128))
# ['Day = ', 60]
# (tensor(-9.2503e-08+6.7494e-08j, dtype=torch.complex128), tensor(2.1094e-08+1.3541e-08j, dtype=torch.complex128))
# ['Day = ', 61]
# (tensor(-6.4198e-08+8.4969e-08j, dtype=torch.complex128), tensor(2.8573e-08+6.3198e-10j, dtype=torch.complex128))
# ['Day = ', 62]
# (tensor(-5.4470e-08+6.5580e-08j, dtype=torch.complex128), tensor(1.7773e-08+7.6134e-09j, dtype=torch.complex128))
# ['Day = ', 63]
# (tensor(-7.3579e-08+4.6837e-08j, dtype=torch.complex128), tensor(1.6125e-08+1.0850e-08j, dtype=torch.complex128))
# ['Day = ', 64]
# (tensor(-7.5271e-08+6.6817e-08j, dtype=torch.complex128), tensor(1.9237e-08+7.0768e-09j, dtype=torch.complex128))
# ['Day = ', 65]
# (tensor(-8.7815e-08+2.5718e-08j, dtype=torch.complex128), tensor(2.1568e-08-2.6049e-09j, dtype=torch.complex128))
# ['Day = ', 66]
# (tensor(-7.7864e-08+1.2691e-07j, dtype=torch.complex128), tensor(1.5665e-08+9.3399e-09j, dtype=torch.complex128))
# ['Day = ', 67]
# (tensor(-2.2252e-08+1.3491e-07j, dtype=torch.complex128), tensor(2.1991e-08-5.5182e-09j, dtype=torch.complex128))
# ['Day = ', 68]
# (tensor(-2.4428e-08+1.0270e-07j, dtype=torch.complex128), tensor(2.0908e-08-5.6566e-10j, dtype=torch.complex128))
# ['Day = ', 69]
# (tensor(-2.0532e-08+7.8455e-08j, dtype=torch.complex128), tensor(1.5394e-08+1.1088e-09j, dtype=torch.complex128))
# ['Day = ', 70]
# (tensor(-2.2088e-08+5.7703e-08j, dtype=torch.complex128), tensor(2.4877e-08-7.4093e-09j, dtype=torch.complex128))
# ['Day = ', 71]
# (tensor(-3.1765e-08+3.2947e-08j, dtype=torch.complex128), tensor(1.4466e-08-5.9910e-09j, dtype=torch.complex128))
# ['Day = ', 72]
# (tensor(-7.7721e-08+2.5704e-08j, dtype=torch.complex128), tensor(1.4524e-08+9.9904e-10j, dtype=torch.complex128))
# ['Day = ', 73]
# (tensor(-9.2477e-08+6.7564e-08j, dtype=torch.complex128), tensor(2.1262e-08+1.3583e-08j, dtype=torch.complex128))
# ['Day = ', 74]
# (tensor(-6.4031e-08+8.5098e-08j, dtype=torch.complex128), tensor(2.8334e-08+4.1891e-10j, dtype=torch.complex128))
# ['Day = ', 75]
# (tensor(-5.4300e-08+6.5792e-08j, dtype=torch.complex128), tensor(1.6649e-08+7.1829e-09j, dtype=torch.complex128))
# ['Day = ', 76]
# (tensor(-7.3623e-08+4.7121e-08j, dtype=torch.complex128), tensor(1.4752e-08+1.0301e-08j, dtype=torch.complex128))
# ['Day = ', 77]
# (tensor(-7.5679e-08+6.6015e-08j, dtype=torch.complex128), tensor(1.9589e-08+7.1943e-09j, dtype=torch.complex128))
# ['Day = ', 78]
# (tensor(-8.7816e-08+2.5717e-08j, dtype=torch.complex128), tensor(2.1570e-08-2.6027e-09j, dtype=torch.complex128))
# ['Day = ', 79]
# (tensor(-7.7865e-08+1.2691e-07j, dtype=torch.complex128), tensor(1.5671e-08+9.3443e-09j, dtype=torch.complex128))
# ['Day = ', 80]
# (tensor(-2.2251e-08+1.3491e-07j, dtype=torch.complex128), tensor(2.1997e-08-5.5175e-09j, dtype=torch.complex128))
# ['Day = ', 81]
# (tensor(-2.4424e-08+1.0270e-07j, dtype=torch.complex128), tensor(2.0900e-08-5.6965e-10j, dtype=torch.complex128))
# ['Day = ', 82]
# (tensor(-2.0528e-08+7.8468e-08j, dtype=torch.complex128), tensor(1.5362e-08+1.0964e-09j, dtype=torch.complex128))
# ['Day = ', 83]
# (tensor(-2.2084e-08+5.7709e-08j, dtype=torch.complex128), tensor(2.4842e-08-7.4325e-09j, dtype=torch.complex128))
# ['Day = ', 84]
# (tensor(-3.1777e-08+3.2911e-08j, dtype=torch.complex128), tensor(1.4461e-08-5.9823e-09j, dtype=torch.complex128))
# ['Day = ', 85]
# (tensor(-7.7770e-08+2.5663e-08j, dtype=torch.complex128), tensor(1.4627e-08+1.0835e-09j, dtype=torch.complex128))
# ['Day = ', 86]
# (tensor(-9.2505e-08+6.7543e-08j, dtype=torch.complex128), tensor(2.1560e-08+1.3683e-08j, dtype=torch.complex128))
# ['Day = ', 87]
# (tensor(-6.3968e-08+8.5055e-08j, dtype=torch.complex128), tensor(2.8554e-08+4.7165e-10j, dtype=torch.complex128))
# ['Day = ', 88]
# (tensor(-5.4178e-08+6.6024e-08j, dtype=torch.complex128), tensor(1.6207e-08+7.0443e-09j, dtype=torch.complex128))
# ['Day = ', 89]
# (tensor(-7.3372e-08+4.7709e-08j, dtype=torch.complex128), tensor(1.3548e-08+9.5389e-09j, dtype=torch.complex128))
# ['Day = ', 90]
# (tensor(-7.5480e-08+6.5821e-08j, dtype=torch.complex128), tensor(1.7937e-08+6.2989e-09j, dtype=torch.complex128))
# ['Day = ', 91]
# (tensor(-8.7816e-08+2.5716e-08j, dtype=torch.complex128), tensor(2.1569e-08-2.6025e-09j, dtype=torch.complex128))
# ['Day = ', 92]
# (tensor(-7.7866e-08+1.2691e-07j, dtype=torch.complex128), tensor(1.5674e-08+9.3464e-09j, dtype=torch.complex128))
# ['Day = ', 93]
# (tensor(-2.2251e-08+1.3490e-07j, dtype=torch.complex128), tensor(2.2006e-08-5.5147e-09j, dtype=torch.complex128))
# ['Day = ', 94]
# (tensor(-2.4423e-08+1.0270e-07j, dtype=torch.complex128), tensor(2.0905e-08-5.6630e-10j, dtype=torch.complex128))
# ['Day = ', 95]
# (tensor(-2.0525e-08+7.8481e-08j, dtype=torch.complex128), tensor(1.5353e-08+1.0898e-09j, dtype=torch.complex128))
# ['Day = ', 96]
# (tensor(-2.2072e-08+5.7720e-08j, dtype=torch.complex128), tensor(2.4812e-08-7.4589e-09j, dtype=torch.complex128))
# ['Day = ', 97]
# (tensor(-3.1775e-08+3.2902e-08j, dtype=torch.complex128), tensor(1.4395e-08-5.9995e-09j, dtype=torch.complex128))
# ['Day = ', 98]
# (tensor(-7.7800e-08+2.5667e-08j, dtype=torch.complex128), tensor(1.4607e-08+1.0959e-09j, dtype=torch.complex128))
# ['Day = ', 99]
# (tensor(-9.2535e-08+6.7488e-08j, dtype=torch.complex128), tensor(2.1751e-08+1.3732e-08j, dtype=torch.complex128))
# ['Day = ', 100]
# (tensor(-6.4001e-08+8.4899e-08j, dtype=torch.complex128), tensor(2.8872e-08+6.5406e-10j, dtype=torch.complex128))
# ['Day = ', 101]
# (tensor(-5.4199e-08+6.6160e-08j, dtype=torch.complex128), tensor(1.6412e-08+7.2009e-09j, dtype=torch.complex128))
# ['Day = ', 102]
# (tensor(-7.3093e-08+4.8131e-08j, dtype=torch.complex128), tensor(1.3354e-08+9.0851e-09j, dtype=torch.complex128))
# ['Day = ', 103]
# (tensor(-7.5018e-08+6.5872e-08j, dtype=torch.complex128), tensor(1.6244e-08+5.4494e-09j, dtype=torch.complex128))
# ['Day = ', 104]
# (tensor(-8.7817e-08+2.5717e-08j, dtype=torch.complex128), tensor(2.1566e-08-2.6035e-09j, dtype=torch.complex128))
# ['Day = ', 105]
# (tensor(-7.7867e-08+1.2691e-07j, dtype=torch.complex128), tensor(1.5675e-08+9.3453e-09j, dtype=torch.complex128))
# ['Day = ', 106]
# (tensor(-2.2252e-08+1.3490e-07j, dtype=torch.complex128), tensor(2.2010e-08-5.5128e-09j, dtype=torch.complex128))
# ['Day = ', 107]
# (tensor(-2.4426e-08+1.0270e-07j, dtype=torch.complex128), tensor(2.0913e-08-5.5994e-10j, dtype=torch.complex128))
# ['Day = ', 108]
# (tensor(-2.0524e-08+7.8488e-08j, dtype=torch.complex128), tensor(1.5365e-08+1.0898e-09j, dtype=torch.complex128))
# ['Day = ', 109]
# (tensor(-2.2061e-08+5.7720e-08j, dtype=torch.complex128), tensor(2.4807e-08-7.4715e-09j, dtype=torch.complex128))
# ['Day = ', 110]
# (tensor(-3.1769e-08+3.2911e-08j, dtype=torch.complex128), tensor(1.4332e-08-6.0134e-09j, dtype=torch.complex128))
# ['Day = ', 111]
# (tensor(-7.7803e-08+2.5710e-08j, dtype=torch.complex128), tensor(1.4534e-08+1.0561e-09j, dtype=torch.complex128))
# ['Day = ', 112]
# (tensor(-9.2535e-08+6.7437e-08j, dtype=torch.complex128), tensor(2.1770e-08+1.3702e-08j, dtype=torch.complex128))
# ['Day = ', 113]
# (tensor(-6.4074e-08+8.4752e-08j, dtype=torch.complex128), tensor(2.8996e-08+8.1617e-10j, dtype=torch.complex128))
# ['Day = ', 114]
# (tensor(-5.4312e-08+6.6234e-08j, dtype=torch.complex128), tensor(1.6838e-08+7.4259e-09j, dtype=torch.complex128))
# ['Day = ', 115]
# (tensor(-7.2931e-08+4.8154e-08j, dtype=torch.complex128), tensor(1.3977e-08+9.0170e-09j, dtype=torch.complex128))
# ['Day = ', 116]
# (tensor(-7.4719e-08+6.5807e-08j, dtype=torch.complex128), tensor(1.5545e-08+5.3113e-09j, dtype=torch.complex128))
# ['Day = ', 117]
# (tensor(-8.7817e-08+2.5718e-08j, dtype=torch.complex128), tensor(2.1564e-08-2.6043e-09j, dtype=torch.complex128))
# ['Day = ', 118]
# (tensor(-7.7866e-08+1.2691e-07j, dtype=torch.complex128), tensor(1.5674e-08+9.3424e-09j, dtype=torch.complex128))
# ['Day = ', 119]
# (tensor(-2.2253e-08+1.3490e-07j, dtype=torch.complex128), tensor(2.2010e-08-5.5125e-09j, dtype=torch.complex128))
# ['Day = ', 120]
# (tensor(-2.4429e-08+1.0270e-07j, dtype=torch.complex128), tensor(2.0916e-08-5.5537e-10j, dtype=torch.complex128))
# ['Day = ', 121]
# (tensor(-2.0525e-08+7.8489e-08j, dtype=torch.complex128), tensor(1.5383e-08+1.0913e-09j, dtype=torch.complex128))
# ['Day = ', 122]
# (tensor(-2.2056e-08+5.7709e-08j, dtype=torch.complex128), tensor(2.4820e-08-7.4675e-09j, dtype=torch.complex128))
# ['Day = ', 123]
# (tensor(-3.1769e-08+3.2928e-08j, dtype=torch.complex128), tensor(1.4305e-08-6.0095e-09j, dtype=torch.complex128))
# ['Day = ', 124]
# (tensor(-7.7787e-08+2.5761e-08j, dtype=torch.complex128), tensor(1.4490e-08+1.0040e-09j, dtype=torch.complex128))
# ['Day = ', 125]
# (tensor(-9.2505e-08+6.7393e-08j, dtype=torch.complex128), tensor(2.1687e-08+1.3641e-08j, dtype=torch.complex128))
# ['Day = ', 126]
# (tensor(-6.4139e-08+8.4705e-08j, dtype=torch.complex128), tensor(2.8883e-08+8.9459e-10j, dtype=torch.complex128))
# ['Day = ', 127]
# (tensor(-5.4410e-08+6.6314e-08j, dtype=torch.complex128), tensor(1.7137e-08+7.5073e-09j, dtype=torch.complex128))
# ['Day = ', 128]
# (tensor(-7.2876e-08+4.7822e-08j, dtype=torch.complex128), tensor(1.4726e-08+9.1443e-09j, dtype=torch.complex128))
# ['Day = ', 129]
# (tensor(-7.4781e-08+6.5602e-08j, dtype=torch.complex128), tensor(1.5671e-08+5.8564e-09j, dtype=torch.complex128))
# ['Day = ', 130]
# (tensor(-8.7816e-08+2.5719e-08j, dtype=torch.complex128), tensor(2.1564e-08-2.6044e-09j, dtype=torch.complex128))
# ['Day = ', 131]
# (tensor(-7.7865e-08+1.2691e-07j, dtype=torch.complex128), tensor(1.5673e-08+9.3400e-09j, dtype=torch.complex128))
# ['Day = ', 132]
# (tensor(-2.2253e-08+1.3490e-07j, dtype=torch.complex128), tensor(2.2006e-08-5.5127e-09j, dtype=torch.complex128))
# ['Day = ', 133]
# (tensor(-2.4432e-08+1.0270e-07j, dtype=torch.complex128), tensor(2.0914e-08-5.5479e-10j, dtype=torch.complex128))
# ['Day = ', 134]
# (tensor(-2.0524e-08+7.8485e-08j, dtype=torch.complex128), tensor(1.5396e-08+1.0901e-09j, dtype=torch.complex128))
# ['Day = ', 135]
# (tensor(-2.2059e-08+5.7692e-08j, dtype=torch.complex128), tensor(2.4831e-08-7.4539e-09j, dtype=torch.complex128))
# ['Day = ', 136]
# (tensor(-3.1777e-08+3.2946e-08j, dtype=torch.complex128), tensor(1.4312e-08-5.9939e-09j, dtype=torch.complex128))
# ['Day = ', 137]
# (tensor(-7.7765e-08+2.5789e-08j, dtype=torch.complex128), tensor(1.4509e-08+9.6609e-10j, dtype=torch.complex128))
# ['Day = ', 138]
# (tensor(-9.2472e-08+6.7347e-08j, dtype=torch.complex128), tensor(2.1595e-08+1.3610e-08j, dtype=torch.complex128))
# ['Day = ', 139]
# (tensor(-6.4181e-08+8.4778e-08j, dtype=torch.complex128), tensor(2.8674e-08+9.0510e-10j, dtype=torch.complex128))
# ['Day = ', 140]
# (tensor(-5.4417e-08+6.6409e-08j, dtype=torch.complex128), tensor(1.7233e-08+7.3883e-09j, dtype=torch.complex128))
# ['Day = ', 141]
# (tensor(-7.2867e-08+4.7334e-08j, dtype=torch.complex128), tensor(1.5052e-08+9.2862e-09j, dtype=torch.complex128))
# ['Day = ', 142]
# (tensor(-7.5129e-08+6.5510e-08j, dtype=torch.complex128), tensor(1.5948e-08+6.6230e-09j, dtype=torch.complex128))
# ['Day = ', 143]
# (tensor(-8.7816e-08+2.5720e-08j, dtype=torch.complex128), tensor(2.1565e-08-2.6038e-09j, dtype=torch.complex128))
# ['Day = ', 144]
# (tensor(-7.7865e-08+1.2691e-07j, dtype=torch.complex128), tensor(1.5673e-08+9.3392e-09j, dtype=torch.complex128))
# ['Day = ', 145]
# (tensor(-2.2253e-08+1.3490e-07j, dtype=torch.complex128), tensor(2.2002e-08-5.5122e-09j, dtype=torch.complex128))
# ['Day = ', 146]
# (tensor(-2.4432e-08+1.0271e-07j, dtype=torch.complex128), tensor(2.0910e-08-5.5764e-10j, dtype=torch.complex128))
# ['Day = ', 147]
# (tensor(-2.0522e-08+7.8479e-08j, dtype=torch.complex128), tensor(1.5399e-08+1.0863e-09j, dtype=torch.complex128))
# ['Day = ', 148]
# (tensor(-2.2065e-08+5.7679e-08j, dtype=torch.complex128), tensor(2.4828e-08-7.4390e-09j, dtype=torch.complex128))
# ['Day = ', 149]
# (tensor(-3.1787e-08+3.2967e-08j, dtype=torch.complex128), tensor(1.4334e-08-5.9828e-09j, dtype=torch.complex128))
# ['Day = ', 150]
# (tensor(-7.7745e-08+2.5777e-08j, dtype=torch.complex128), tensor(1.4566e-08+9.4764e-10j, dtype=torch.complex128))
# ['Day = ', 151]
# (tensor(-9.2463e-08+6.7300e-08j, dtype=torch.complex128), tensor(2.1536e-08+1.3637e-08j, dtype=torch.complex128))
# ['Day = ', 152]
# (tensor(-6.4206e-08+8.4931e-08j, dtype=torch.complex128), tensor(2.8535e-08+8.8389e-10j, dtype=torch.complex128))
# ['Day = ', 153]
# (tensor(-5.4326e-08+6.6454e-08j, dtype=torch.complex128), tensor(1.7242e-08+7.1566e-09j, dtype=torch.complex128))
# ['Day = ', 154]
# (tensor(-7.2874e-08+4.6896e-08j, dtype=torch.complex128), tensor(1.4842e-08+9.4080e-09j, dtype=torch.complex128))
# ['Day = ', 155]
# (tensor(-7.5545e-08+6.5789e-08j, dtype=torch.complex128), tensor(1.5956e-08+7.1393e-09j, dtype=torch.complex128))
# ['Day = ', 156]
# (tensor(-8.7816e-08+2.5719e-08j, dtype=torch.complex128), tensor(2.1567e-08-2.6032e-09j, dtype=torch.complex128))
# ['Day = ', 157]
# (tensor(-7.7864e-08+1.2690e-07j, dtype=torch.complex128), tensor(1.5673e-08+9.3403e-09j, dtype=torch.complex128))
# ['Day = ', 158]
# (tensor(-2.2254e-08+1.3490e-07j, dtype=torch.complex128), tensor(2.2000e-08-5.5107e-09j, dtype=torch.complex128))
# ['Day = ', 159]
# (tensor(-2.4431e-08+1.0271e-07j, dtype=torch.complex128), tensor(2.0910e-08-5.6208e-10j, dtype=torch.complex128))
# ['Day = ', 160]
# (tensor(-2.0518e-08+7.8470e-08j, dtype=torch.complex128), tensor(1.5395e-08+1.0832e-09j, dtype=torch.complex128))
# ['Day = ', 161]
# (tensor(-2.2072e-08+5.7678e-08j, dtype=torch.complex128), tensor(2.4812e-08-7.4275e-09j, dtype=torch.complex128))
# ['Day = ', 162]
# (tensor(-3.1793e-08+3.2989e-08j, dtype=torch.complex128), tensor(1.4356e-08-5.9879e-09j, dtype=torch.complex128))
# ['Day = ', 163]
# (tensor(-7.7729e-08+2.5731e-08j, dtype=torch.complex128), tensor(1.4617e-08+9.4404e-10j, dtype=torch.complex128))
# ['Day = ', 164]
# (tensor(-9.2485e-08+6.7273e-08j, dtype=torch.complex128), tensor(2.1502e-08+1.3709e-08j, dtype=torch.complex128))
# ['Day = ', 165]
# (tensor(-6.4216e-08+8.5102e-08j, dtype=torch.complex128), tensor(2.8548e-08+8.4437e-10j, dtype=torch.complex128))
# ['Day = ', 166]
# (tensor(-5.4186e-08+6.6371e-08j, dtype=torch.complex128), tensor(1.7274e-08+6.9506e-09j, dtype=torch.complex128))
# ['Day = ', 167]
# (tensor(-7.2922e-08+4.6651e-08j, dtype=torch.complex128), tensor(1.4313e-08+9.5729e-09j, dtype=torch.complex128))
# ['Day = ', 168]
# (tensor(-7.5827e-08+6.6473e-08j, dtype=torch.complex128), tensor(1.5786e-08+7.1773e-09j, dtype=torch.complex128))
# ['Day = ', 169]
# (tensor(-8.7815e-08+2.5719e-08j, dtype=torch.complex128), tensor(2.1569e-08-2.6031e-09j, dtype=torch.complex128))
# ['Day = ', 170]
# (tensor(-7.7864e-08+1.2690e-07j, dtype=torch.complex128), tensor(1.5673e-08+9.3425e-09j, dtype=torch.complex128))
# ['Day = ', 171]
# (tensor(-2.2255e-08+1.3490e-07j, dtype=torch.complex128), tensor(2.2001e-08-5.5093e-09j, dtype=torch.complex128))
# ['Day = ', 172]
# (tensor(-2.4429e-08+1.0271e-07j, dtype=torch.complex128), tensor(2.0914e-08-5.6631e-10j, dtype=torch.complex128))
# ['Day = ', 173]
# (tensor(-2.0516e-08+7.8460e-08j, dtype=torch.complex128), tensor(1.5388e-08+1.0841e-09j, dtype=torch.complex128))
# ['Day = ', 174]
# (tensor(-2.2080e-08+5.7690e-08j, dtype=torch.complex128), tensor(2.4796e-08-7.4214e-09j, dtype=torch.complex128))
# ['Day = ', 175]
# (tensor(-3.1788e-08+3.3004e-08j, dtype=torch.complex128), tensor(1.4375e-08-6.0092e-09j, dtype=torch.complex128))
# ['Day = ', 176]
# (tensor(-7.7720e-08+2.5668e-08j, dtype=torch.complex128), tensor(1.4628e-08+9.5277e-10j, dtype=torch.complex128))
# ['Day = ', 177]
# (tensor(-9.2531e-08+6.7291e-08j, dtype=torch.complex128), tensor(2.1471e-08+1.3786e-08j, dtype=torch.complex128))
# ['Day = ', 178]
# (tensor(-6.4205e-08+8.5231e-08j, dtype=torch.complex128), tensor(2.8690e-08+7.7704e-10j, dtype=torch.complex128))
# ['Day = ', 179]
# (tensor(-5.4064e-08+6.6139e-08j, dtype=torch.complex128), tensor(1.7330e-08+6.8733e-09j, dtype=torch.complex128))
# ['Day = ', 180]
# (tensor(-7.3050e-08+4.6677e-08j, dtype=torch.complex128), tensor(1.3769e-08+9.8192e-09j, dtype=torch.complex128))
# ['Day = ', 181]
# (tensor(-7.5868e-08+6.7326e-08j, dtype=torch.complex128), tensor(1.5802e-08+6.7672e-09j, dtype=torch.complex128))
# ['Day = ', 182]
# (tensor(-8.7815e-08+2.5718e-08j, dtype=torch.complex128), tensor(2.1571e-08-2.6036e-09j, dtype=torch.complex128))
# ['Day = ', 183]
# (tensor(-7.7865e-08+1.2690e-07j, dtype=torch.complex128), tensor(1.5672e-08+9.3449e-09j, dtype=torch.complex128))
# ['Day = ', 184]
# (tensor(-2.2256e-08+1.3490e-07j, dtype=torch.complex128), tensor(2.2002e-08-5.5090e-09j, dtype=torch.complex128))
# ['Day = ', 185]
# (tensor(-2.4426e-08+1.0271e-07j, dtype=torch.complex128), tensor(2.0920e-08-5.6915e-10j, dtype=torch.complex128))
# ['Day = ', 186]
# (tensor(-2.0516e-08+7.8453e-08j, dtype=torch.complex128), tensor(1.5380e-08+1.0903e-09j, dtype=torch.complex128))
# ['Day = ', 187]
# (tensor(-2.2085e-08+5.7712e-08j, dtype=torch.complex128), tensor(2.4788e-08-7.4215e-09j, dtype=torch.complex128))
# ['Day = ', 188]
# (tensor(-3.1774e-08+3.3003e-08j, dtype=torch.complex128), tensor(1.4393e-08-6.0371e-09j, dtype=torch.complex128))
# ['Day = ', 189]
# (tensor(-7.7721e-08+2.5610e-08j, dtype=torch.complex128), tensor(1.4594e-08+9.7606e-10j, dtype=torch.complex128))
# ['Day = ', 190]
# (tensor(-9.2581e-08+6.7367e-08j, dtype=torch.complex128), tensor(2.1442e-08+1.3831e-08j, dtype=torch.complex128))
# ['Day = ', 191]
# (tensor(-6.4161e-08+8.5271e-08j, dtype=torch.complex128), tensor(2.8881e-08+6.7644e-10j, dtype=torch.complex128))
# ['Day = ', 192]
# (tensor(-5.4011e-08+6.5817e-08j, dtype=torch.complex128), tensor(1.7323e-08+6.9573e-09j, dtype=torch.complex128))
# ['Day = ', 193]
# (tensor(-7.3252e-08+4.6992e-08j, dtype=torch.complex128), tensor(1.3425e-08+1.0085e-08j, dtype=torch.complex128))
# ['Day = ', 194]
# (tensor(-7.5659e-08+6.7962e-08j, dtype=torch.complex128), tensor(1.6252e-08+6.0878e-09j, dtype=torch.complex128))
# ['Day = ', 195]
# (tensor(-8.7815e-08+2.5717e-08j, dtype=torch.complex128), tensor(2.1571e-08-2.6044e-09j, dtype=torch.complex128))
# ['Day = ', 196]
# (tensor(-7.7866e-08+1.2690e-07j, dtype=torch.complex128), tensor(1.5670e-08+9.3468e-09j, dtype=torch.complex128))
# ['Day = ', 197]
# (tensor(-2.2256e-08+1.3491e-07j, dtype=torch.complex128), tensor(2.2004e-08-5.5105e-09j, dtype=torch.complex128))
# ['Day = ', 198]
# (tensor(-2.4424e-08+1.0270e-07j, dtype=torch.complex128), tensor(2.0924e-08-5.6984e-10j, dtype=torch.complex128))
# ['Day = ', 199]
# (tensor(-2.0520e-08+7.8451e-08j, dtype=torch.complex128), tensor(1.5371e-08+1.0996e-09j, dtype=torch.complex128))
# ['Day = ', 200]
# (tensor(-2.2086e-08+5.7736e-08j, dtype=torch.complex128), tensor(2.4796e-08-7.4288e-09j, dtype=torch.complex128))
# ['Day = ', 201]
# (tensor(-3.1756e-08+3.2980e-08j, dtype=torch.complex128), tensor(1.4410e-08-6.0584e-09j, dtype=torch.complex128))
# ['Day = ', 202]
# (tensor(-7.7735e-08+2.5579e-08j, dtype=torch.complex128), tensor(1.4532e-08+1.0147e-09j, dtype=torch.complex128))
# ['Day = ', 203]
# (tensor(-9.2613e-08+6.7486e-08j, dtype=torch.complex128), tensor(2.1438e-08+1.3823e-08j, dtype=torch.complex128))
# ['Day = ', 204]
# (tensor(-6.4087e-08+8.5196e-08j, dtype=torch.complex128), tensor(2.9041e-08+5.6370e-10j, dtype=torch.complex128))
# ['Day = ', 205]
# (tensor(-5.4049e-08+6.5533e-08j, dtype=torch.complex128), tensor(1.7174e-08+7.1730e-09j, dtype=torch.complex128))
# ['Day = ', 206]
# (tensor(-7.3463e-08+4.7543e-08j, dtype=torch.complex128), tensor(1.3369e-08+1.0232e-08j, dtype=torch.complex128))
# ['Day = ', 207]
# (tensor(-7.5259e-08+6.8036e-08j, dtype=torch.complex128), tensor(1.7055e-08+5.3641e-09j, dtype=torch.complex128))
# ['Day = ', 208]
# (tensor(-8.7815e-08+2.5716e-08j, dtype=torch.complex128), tensor(2.1570e-08-2.6050e-09j, dtype=torch.complex128))
# ['Day = ', 209]
# (tensor(-7.7867e-08+1.2690e-07j, dtype=torch.complex128), tensor(1.5669e-08+9.3477e-09j, dtype=torch.complex128))
# ['Day = ', 210]
# (tensor(-2.2254e-08+1.3491e-07j, dtype=torch.complex128), tensor(2.2006e-08-5.5133e-09j, dtype=torch.complex128))
# ['Day = ', 211]
# (tensor(-2.4422e-08+1.0269e-07j, dtype=torch.complex128), tensor(2.0924e-08-5.6792e-10j, dtype=torch.complex128))
# ['Day = ', 212]
# (tensor(-2.0527e-08+7.8457e-08j, dtype=torch.complex128), tensor(1.5364e-08+1.1081e-09j, dtype=torch.complex128))
# ['Day = ', 213]
# (tensor(-2.2083e-08+5.7754e-08j, dtype=torch.complex128), tensor(2.4815e-08-7.4433e-09j, dtype=torch.complex128))
# ['Day = ', 214]
# (tensor(-3.1741e-08+3.2938e-08j, dtype=torch.complex128), tensor(1.4416e-08-6.0629e-09j, dtype=torch.complex128))
# ['Day = ', 215]
# (tensor(-7.7762e-08+2.5590e-08j, dtype=torch.complex128), tensor(1.4467e-08+1.0614e-09j, dtype=torch.complex128))
# ['Day = ', 216]
# (tensor(-9.2614e-08+6.7606e-08j, dtype=torch.complex128), tensor(2.1485e-08+1.3760e-08j, dtype=torch.complex128))
# ['Day = ', 217]
# (tensor(-6.4001e-08+8.5013e-08j, dtype=torch.complex128), tensor(2.9115e-08+4.8543e-10j, dtype=torch.complex128))
# ['Day = ', 218]
# (tensor(-5.4175e-08+6.5421e-08j, dtype=torch.complex128), tensor(1.6889e-08+7.4510e-09j, dtype=torch.complex128))
# ['Day = ', 219]
# (tensor(-7.3584e-08+4.8192e-08j, dtype=torch.complex128), tensor(1.3605e-08+1.0131e-08j, dtype=torch.complex128))
# ['Day = ', 220]
# (tensor(-7.4781e-08+6.7399e-08j, dtype=torch.complex128), tensor(1.7851e-08+4.8206e-09j, dtype=torch.complex128))
# ['Day = ', 221]
# (tensor(-8.7815e-08+2.5715e-08j, dtype=torch.complex128), tensor(2.1568e-08-2.6053e-09j, dtype=torch.complex128))
# ['Day = ', 222]
# (tensor(-7.7868e-08+1.2691e-07j, dtype=torch.complex128), tensor(1.5668e-08+9.3470e-09j, dtype=torch.complex128))
# ['Day = ', 223]
# (tensor(-2.2252e-08+1.3491e-07j, dtype=torch.complex128), tensor(2.2007e-08-5.5166e-09j, dtype=torch.complex128))
# ['Day = ', 224]
# (tensor(-2.4423e-08+1.0269e-07j, dtype=torch.complex128), tensor(2.0920e-08-5.6344e-10j, dtype=torch.complex128))
# ['Day = ', 225]
# (tensor(-2.0533e-08+7.8472e-08j, dtype=torch.complex128), tensor(1.5360e-08+1.1119e-09j, dtype=torch.complex128))
# ['Day = ', 226]
# (tensor(-2.2073e-08+5.7757e-08j, dtype=torch.complex128), tensor(2.4839e-08-7.4621e-09j, dtype=torch.complex128))
# ['Day = ', 227]
# (tensor(-3.1736e-08+3.2890e-08j, dtype=torch.complex128), tensor(1.4404e-08-6.0468e-09j, dtype=torch.complex128))
# ['Day = ', 228]
# (tensor(-7.7797e-08+2.5646e-08j, dtype=torch.complex128), tensor(1.4424e-08+1.0995e-09j, dtype=torch.complex128))
# ['Day = ', 229]
# (tensor(-9.2578e-08+6.7677e-08j, dtype=torch.complex128), tensor(2.1585e-08+1.3661e-08j, dtype=torch.complex128))
# ['Day = ', 230]
# (tensor(-6.3939e-08+8.4762e-08j, dtype=torch.complex128), tensor(2.9075e-08+4.9114e-10j, dtype=torch.complex128))
# ['Day = ', 231]
# (tensor(-5.4355e-08+6.5567e-08j, dtype=torch.complex128), tensor(1.6571e-08+7.7021e-09j, dtype=torch.complex128))
# ['Day = ', 232]
# (tensor(-7.3532e-08+4.8723e-08j, dtype=torch.complex128), tensor(1.4084e-08+9.7478e-09j, dtype=torch.complex128))
# ['Day = ', 233]
# (tensor(-7.4370e-08+6.6175e-08j, dtype=torch.complex128), tensor(1.8213e-08+4.6571e-09j, dtype=torch.complex128))
# ['Day = ', 234]
# (tensor(-8.7816e-08+2.5716e-08j, dtype=torch.complex128), tensor(2.1565e-08-2.6051e-09j, dtype=torch.complex128))
# ['Day = ', 235]
# (tensor(-7.7868e-08+1.2691e-07j, dtype=torch.complex128), tensor(1.5670e-08+9.3448e-09j, dtype=torch.complex128))
# ['Day = ', 236]
# (tensor(-2.2250e-08+1.3490e-07j, dtype=torch.complex128), tensor(2.2009e-08-5.5189e-09j, dtype=torch.complex128))
# ['Day = ', 237]
# (tensor(-2.4425e-08+1.0268e-07j, dtype=torch.complex128), tensor(2.0912e-08-5.5731e-10j, dtype=torch.complex128))
# ['Day = ', 238]
# (tensor(-2.0537e-08+7.8491e-08j, dtype=torch.complex128), tensor(1.5363e-08+1.1086e-09j, dtype=torch.complex128))
# ['Day = ', 239]
# (tensor(-2.2060e-08+5.7742e-08j, dtype=torch.complex128), tensor(2.4859e-08-7.4793e-09j, dtype=torch.complex128))
# ['Day = ', 240]
# (tensor(-3.1744e-08+3.2853e-08j, dtype=torch.complex128), tensor(1.4371e-08-6.0133e-09j, dtype=torch.complex128))
# ['Day = ', 241]
# (tensor(-7.7825e-08+2.5738e-08j, dtype=torch.complex128), tensor(1.4419e-08+1.1097e-09j, dtype=torch.complex128))
# ['Day = ', 242]
# (tensor(-9.2514e-08+6.7658e-08j, dtype=torch.complex128), tensor(2.1709e-08+1.3557e-08j, dtype=torch.complex128))
# ['Day = ', 243]
# (tensor(-6.3934e-08+8.4524e-08j, dtype=torch.complex128), tensor(2.8924e-08+6.0463e-10j, dtype=torch.complex128))
# ['Day = ', 244]
# (tensor(-5.4536e-08+6.5967e-08j, dtype=torch.complex128), tensor(1.6367e-08+7.8346e-09j, dtype=torch.complex128))
# ['Day = ', 245]
# (tensor(-7.3285e-08+4.8902e-08j, dtype=torch.complex128), tensor(1.4701e-08+9.1775e-09j, dtype=torch.complex128))
# ['Day = ', 246]
# (tensor(-7.4186e-08+6.4737e-08j, dtype=torch.complex128), tensor(1.7874e-08+5.0045e-09j, dtype=torch.complex128))
# ['Day = ', 247]
# (tensor(-8.7817e-08+2.5717e-08j, dtype=torch.complex128), tensor(2.1562e-08-2.6043e-09j, dtype=torch.complex128))
# ['Day = ', 248]
# (tensor(-7.7867e-08+1.2691e-07j, dtype=torch.complex128), tensor(1.5673e-08+9.3413e-09j, dtype=torch.complex128))
# ['Day = ', 249]
# (tensor(-2.2248e-08+1.3490e-07j, dtype=torch.complex128), tensor(2.2009e-08-5.5191e-09j, dtype=torch.complex128))
# ['Day = ', 250]
# (tensor(-2.4429e-08+1.0269e-07j, dtype=torch.complex128), tensor(2.0904e-08-5.5139e-10j, dtype=torch.complex128))
# ['Day = ', 251]
# (tensor(-2.0536e-08+7.8508e-08j, dtype=torch.complex128), tensor(1.5374e-08+1.0982e-09j, dtype=torch.complex128))
# ['Day = ', 252]
# (tensor(-2.2048e-08+5.7711e-08j, dtype=torch.complex128), tensor(2.4866e-08-7.4874e-09j, dtype=torch.complex128))
# ['Day = ', 253]
# (tensor(-3.1764e-08+3.2847e-08j, dtype=torch.complex128), tensor(1.4325e-08-5.9722e-09j, dtype=torch.complex128))
# ['Day = ', 254]
# (tensor(-7.7835e-08+2.5837e-08j, dtype=torch.complex128), tensor(1.4459e-08+1.0791e-09j, dtype=torch.complex128))
# ['Day = ', 255]
# (tensor(-9.2440e-08+6.7535e-08j, dtype=torch.complex128), tensor(2.1806e-08+1.3483e-08j, dtype=torch.complex128))
# ['Day = ', 256]
# (tensor(-6.4004e-08+8.4393e-08j, dtype=torch.complex128), tensor(2.8693e-08+8.0575e-10j, dtype=torch.complex128))
# ['Day = ', 257]
# (tensor(-5.4651e-08+6.6514e-08j, dtype=torch.complex128), tensor(1.6399e-08+7.7774e-09j, dtype=torch.complex128))
# ['Day = ', 258]
# (tensor(-7.2902e-08+4.8568e-08j, dtype=torch.complex128), tensor(1.5280e-08+8.6217e-09j, dtype=torch.complex128))
# ['Day = ', 259]
# (tensor(-7.4352e-08+6.3608e-08j, dtype=torch.complex128), tensor(1.6842e-08+5.8567e-09j, dtype=torch.complex128))
# ['Day = ', 260]
# (tensor(-8.7818e-08+2.5719e-08j, dtype=torch.complex128), tensor(2.1560e-08-2.6034e-09j, dtype=torch.complex128))
# ['Day = ', 261]
# (tensor(-7.7866e-08+1.2691e-07j, dtype=torch.complex128), tensor(1.5676e-08+9.3376e-09j, dtype=torch.complex128))
# ['Day = ', 262]
# (tensor(-2.2249e-08+1.3489e-07j, dtype=torch.complex128), tensor(2.2007e-08-5.5167e-09j, dtype=torch.complex128))
# ['Day = ', 263]
# (tensor(-2.4433e-08+1.0270e-07j, dtype=torch.complex128), tensor(2.0898e-08-5.4806e-10j, dtype=torch.complex128))
# ['Day = ', 264]
# (tensor(-2.0530e-08+7.8514e-08j, dtype=torch.complex128), tensor(1.5391e-08+1.0835e-09j, dtype=torch.complex128))
# ['Day = ', 265]
# (tensor(-2.2042e-08+5.7671e-08j, dtype=torch.complex128), tensor(2.4857e-08-7.4806e-09j, dtype=torch.complex128))
# ['Day = ', 266]
# (tensor(-3.1792e-08+3.2881e-08j, dtype=torch.complex128), tensor(1.4282e-08-5.9377e-09j, dtype=torch.complex128))
# ['Day = ', 267]
# (tensor(-7.7816e-08+2.5908e-08j, dtype=torch.complex128), tensor(1.4538e-08+1.0100e-09j, dtype=torch.complex128))
# ['Day = ', 268]
# (tensor(-9.2380e-08+6.7336e-08j, dtype=torch.complex128), tensor(2.1827e-08+1.3475e-08j, dtype=torch.complex128))
# ['Day = ', 269]
# (tensor(-6.4137e-08+8.4447e-08j, dtype=torch.complex128), tensor(2.8447e-08+1.0312e-09j, dtype=torch.complex128))
# ['Day = ', 270]
# (tensor(-5.4640e-08+6.7023e-08j, dtype=torch.complex128), tensor(1.6705e-08+7.5094e-09j, dtype=torch.complex128))
# ['Day = ', 271]
# (tensor(-7.2509e-08+4.7726e-08j, dtype=torch.complex128), tensor(1.5603e-08+8.3148e-09j, dtype=torch.complex128))
# ['Day = ', 272]
# (tensor(-7.4889e-08+6.3294e-08j, dtype=torch.complex128), tensor(1.5418e-08+7.0164e-09j, dtype=torch.complex128))
# ['Day = ', 273]
# (tensor(-8.7818e-08+2.5721e-08j, dtype=torch.complex128), tensor(2.1561e-08-2.6024e-09j, dtype=torch.complex128))
# ['Day = ', 274]
# (tensor(-7.7864e-08+1.2691e-07j, dtype=torch.complex128), tensor(1.5678e-08+9.3352e-09j, dtype=torch.complex128))
# ['Day = ', 275]
# (tensor(-2.2251e-08+1.3489e-07j, dtype=torch.complex128), tensor(2.2004e-08-5.5122e-09j, dtype=torch.complex128))
# ['Day = ', 276]
# (tensor(-2.4437e-08+1.0271e-07j, dtype=torch.complex128), tensor(2.0898e-08-5.4934e-10j, dtype=torch.complex128))
# ['Day = ', 277]
# (tensor(-2.0520e-08+7.8506e-08j, dtype=torch.complex128), tensor(1.5408e-08+1.0692e-09j, dtype=torch.complex128))
# ['Day = ', 278]
# (tensor(-2.2045e-08+5.7637e-08j, dtype=torch.complex128), tensor(2.4832e-08-7.4578e-09j, dtype=torch.complex128))
# ['Day = ', 279]
# (tensor(-3.1818e-08+3.2949e-08j, dtype=torch.complex128), tensor(1.4261e-08-5.9241e-09j, dtype=torch.complex128))
# ['Day = ', 280]
# (tensor(-7.7771e-08+2.5915e-08j, dtype=torch.complex128), tensor(1.4635e-08+9.2153e-10j, dtype=torch.complex128))
# ['Day = ', 281]
# (tensor(-9.2362e-08+6.7123e-08j, dtype=torch.complex128), tensor(2.1746e-08+1.3548e-08j, dtype=torch.complex128))
# ['Day = ', 282]
# (tensor(-6.4294e-08+8.4709e-08j, dtype=torch.complex128), tensor(2.8273e-08+1.1939e-09j, dtype=torch.complex128))
# ['Day = ', 283]
# (tensor(-5.4480e-08+6.7285e-08j, dtype=torch.complex128), tensor(1.7216e-08+7.0830e-09j, dtype=torch.complex128))
# ['Day = ', 284]
# (tensor(-7.2263e-08+4.6590e-08j, dtype=torch.complex128), tensor(1.5476e-08+8.4349e-09j, dtype=torch.complex128))
# ['Day = ', 285]
# (tensor(-7.5679e-08+6.4095e-08j, dtype=torch.complex128), tensor(1.4096e-08+8.1092e-09j, dtype=torch.complex128))
# ['Day = ', 286]
# (tensor(-8.7817e-08+2.5723e-08j, dtype=torch.complex128), tensor(2.1565e-08-2.6018e-09j, dtype=torch.complex128))
# ['Day = ', 287]
# (tensor(-7.7863e-08+1.2690e-07j, dtype=torch.complex128), tensor(1.5679e-08+9.3352e-09j, dtype=torch.complex128))
# ['Day = ', 288]
# (tensor(-2.2254e-08+1.3489e-07j, dtype=torch.complex128), tensor(2.2000e-08-5.5069e-09j, dtype=torch.complex128))
# ['Day = ', 289]
# (tensor(-2.4438e-08+1.0272e-07j, dtype=torch.complex128), tensor(2.0903e-08-5.5588e-10j, dtype=torch.complex128))
# ['Day = ', 290]
# (tensor(-2.0509e-08+7.8483e-08j, dtype=torch.complex128), tensor(1.5419e-08+1.0611e-09j, dtype=torch.complex128))
# ['Day = ', 291]
# (tensor(-2.2060e-08+5.7623e-08j, dtype=torch.complex128), tensor(2.4795e-08-7.4243e-09j, dtype=torch.complex128))
# ['Day = ', 292]
# (tensor(-3.1831e-08+3.3034e-08j, dtype=torch.complex128), tensor(1.4276e-08-5.9412e-09j, dtype=torch.complex128))
# ['Day = ', 293]
# (tensor(-7.7710e-08+2.5841e-08j, dtype=torch.complex128), tensor(1.4718e-08+8.4531e-10j, dtype=torch.complex128))
# ['Day = ', 294]
# (tensor(-9.2402e-08+6.6977e-08j, dtype=torch.complex128), tensor(2.1572e-08+1.3695e-08j, dtype=torch.complex128))
# ['Day = ', 295]
# (tensor(-6.4416e-08+8.5125e-08j, dtype=torch.complex128), tensor(2.8255e-08+1.2141e-09j, dtype=torch.complex128))
# ['Day = ', 296]
# (tensor(-5.4197e-08+6.7143e-08j, dtype=torch.complex128), tensor(1.7768e-08+6.6262e-09j, dtype=torch.complex128))
# ['Day = ', 297]
# (tensor(-7.2293e-08+4.5544e-08j, dtype=torch.complex128), tensor(1.4832e-08+9.0260e-09j, dtype=torch.complex128))
# ['Day = ', 298]
# (tensor(-7.6472e-08+6.5946e-08j, dtype=torch.complex128), tensor(1.3415e-08+8.6858e-09j, dtype=torch.complex128))
# ['Day = ', 299]
# (tensor(-8.7816e-08+2.5722e-08j, dtype=torch.complex128), tensor(2.1570e-08-2.6020e-09j, dtype=torch.complex128))
# ['Day = ', 300]
# (tensor(-7.7862e-08+1.2690e-07j, dtype=torch.complex128), tensor(1.5677e-08+9.3384e-09j, dtype=torch.complex128))
# ['Day = ', 301]
# (tensor(-2.2258e-08+1.3489e-07j, dtype=torch.complex128), tensor(2.1997e-08-5.5027e-09j, dtype=torch.complex128))
# ['Day = ', 302]
# (tensor(-2.4435e-08+1.0273e-07j, dtype=torch.complex128), tensor(2.0914e-08-5.6631e-10j, dtype=torch.complex128))
# ['Day = ', 303]
# (tensor(-2.0501e-08+7.8451e-08j, dtype=torch.complex128), tensor(1.5417e-08+1.0635e-09j, dtype=torch.complex128))
# ['Day = ', 304]
# (tensor(-2.2081e-08+5.7639e-08j, dtype=torch.complex128), tensor(2.4760e-08-7.3913e-09j, dtype=torch.complex128))
# ['Day = ', 305]
# (tensor(-3.1825e-08+3.3104e-08j, dtype=torch.complex128), tensor(1.4330e-08-5.9894e-09j, dtype=torch.complex128))
# ['Day = ', 306]
# (tensor(-7.7655e-08+2.5696e-08j, dtype=torch.complex128), tensor(1.4752e-08+8.1476e-10j, dtype=torch.complex128))
# ['Day = ', 307]
# (tensor(-9.2499e-08+6.6970e-08j, dtype=torch.complex128), tensor(2.1356e-08+1.3875e-08j, dtype=torch.complex128))
# ['Day = ', 308]
# (tensor(-6.4448e-08+8.5566e-08j, dtype=torch.complex128), tensor(2.8439e-08+1.0522e-09j, dtype=torch.complex128))
# ['Day = ', 309]
# (tensor(-5.3872e-08+6.6561e-08j, dtype=torch.complex128), tensor(1.8150e-08+6.3117e-09j, dtype=torch.complex128))
# ['Day = ', 310]
# (tensor(-7.2648e-08+4.5026e-08j, dtype=torch.complex128), tensor(1.3795e-08+9.9567e-09j, dtype=torch.complex128))
# ['Day = ', 311]
# (tensor(-7.6952e-08+6.8361e-08j, dtype=torch.complex128), tensor(1.3773e-08+8.3900e-09j, dtype=torch.complex128))
# ['Day = ', 312]
# (tensor(-8.7814e-08+2.5720e-08j, dtype=torch.complex128), tensor(2.1575e-08-2.6029e-09j, dtype=torch.complex128))
# ['Day = ', 313]
# (tensor(-7.7863e-08+1.2689e-07j, dtype=torch.complex128), tensor(1.5673e-08+9.3441e-09j, dtype=torch.complex128))
# ['Day = ', 314]
# (tensor(-2.2261e-08+1.3490e-07j, dtype=torch.complex128), tensor(2.1996e-08-5.5014e-09j, dtype=torch.complex128))
# ['Day = ', 315]
# (tensor(-2.4429e-08+1.0273e-07j, dtype=torch.complex128), tensor(2.0927e-08-5.7739e-10j, dtype=torch.complex128))
# ['Day = ', 316]
# (tensor(-2.0501e-08+7.8421e-08j, dtype=torch.complex128), tensor(1.5400e-08+1.0780e-09j, dtype=torch.complex128))
# ['Day = ', 317]
# (tensor(-2.2104e-08+5.7687e-08j, dtype=torch.complex128), tensor(2.4740e-08-7.3720e-09j, dtype=torch.complex128))
# ['Day = ', 318]
# (tensor(-3.1796e-08+3.3128e-08j, dtype=torch.complex128), tensor(1.4409e-08-6.0571e-09j, dtype=torch.complex128))
# ['Day = ', 319]
# (tensor(-7.7629e-08+2.5520e-08j, dtype=torch.complex128), tensor(1.4711e-08+8.5235e-10j, dtype=torch.complex128))
# ['Day = ', 320]
# (tensor(-9.2626e-08+6.7137e-08j, dtype=torch.complex128), tensor(2.1176e-08+1.4025e-08j, dtype=torch.complex128))
# ['Day = ', 321]
# (tensor(-6.4357e-08+8.5861e-08j, dtype=torch.complex128), tensor(2.8804e-08+7.3203e-10j, dtype=torch.complex128))
# ['Day = ', 322]
# (tensor(-5.3626e-08+6.5668e-08j, dtype=torch.complex128), tensor(1.8177e-08+6.2982e-09j, dtype=torch.complex128))
# ['Day = ', 323]
# (tensor(-7.3262e-08+4.5365e-08j, dtype=torch.complex128), tensor(1.2685e-08+1.0936e-08j, dtype=torch.complex128))
# ['Day = ', 324]
# (tensor(-7.6853e-08+7.0517e-08j, dtype=torch.complex128), tensor(1.5253e-08+7.1307e-09j, dtype=torch.complex128))
# ['Day = ', 325]
# (tensor(-8.7813e-08+2.5716e-08j, dtype=torch.complex128), tensor(2.1578e-08-2.6044e-09j, dtype=torch.complex128))
# ['Day = ', 326]
# (tensor(-7.7865e-08+1.2689e-07j, dtype=torch.complex128), tensor(1.5667e-08+9.3507e-09j, dtype=torch.complex128))
# ['Day = ', 327]
# (tensor(-2.2261e-08+1.3492e-07j, dtype=torch.complex128), tensor(2.1998e-08-5.5042e-09j, dtype=torch.complex128))
# ['Day = ', 328]
# (tensor(-2.4421e-08+1.0272e-07j, dtype=torch.complex128), tensor(2.0938e-08-5.8483e-10j, dtype=torch.complex128))
# ['Day = ', 329]
# (tensor(-2.0509e-08+7.8404e-08j, dtype=torch.complex128), tensor(1.5372e-08+1.1016e-09j, dtype=torch.complex128))
# ['Day = ', 330]
# (tensor(-2.2118e-08+5.7753e-08j, dtype=torch.complex128), tensor(2.4746e-08-7.3772e-09j, dtype=torch.complex128))
# ['Day = ', 331]
# (tensor(-3.1750e-08+3.3088e-08j, dtype=torch.complex128), tensor(1.4488e-08-6.1221e-09j, dtype=torch.complex128))
# ['Day = ', 332]
# (tensor(-7.7649e-08+2.5377e-08j, dtype=torch.complex128), tensor(1.4593e-08+9.5849e-10j, dtype=torch.complex128))
# ['Day = ', 333]
# (tensor(-9.2741e-08+6.7452e-08j, dtype=torch.complex128), tensor(2.1108e-08+1.4079e-08j, dtype=torch.complex128))
# ['Day = ', 334]
# (tensor(-6.4150e-08+8.5860e-08j, dtype=torch.complex128), tensor(2.9245e-08+3.4449e-10j, dtype=torch.complex128))
# ['Day = ', 335]
# (tensor(-5.3574e-08+6.4746e-08j, dtype=torch.complex128), tensor(1.7760e-08+6.6625e-09j, dtype=torch.complex128))
# ['Day = ', 336]
# (tensor(-7.3950e-08+4.6625e-08j, dtype=torch.complex128), tensor(1.1930e-08+1.1588e-08j, dtype=torch.complex128))
# ['Day = ', 337]
# (tensor(-7.6079e-08+7.1505e-08j, dtype=torch.complex128), tensor(1.7527e-08+5.1833e-09j, dtype=torch.complex128))
# ['Day = ', 338]
# (tensor(-8.7812e-08+2.5713e-08j, dtype=torch.complex128), tensor(2.1578e-08-2.6061e-09j, dtype=torch.complex128))
# ['Day = ', 339]
# (tensor(-7.7868e-08+1.2690e-07j, dtype=torch.complex128), tensor(1.5663e-08+9.3557e-09j, dtype=torch.complex128))
# ['Day = ', 340]
# (tensor(-2.2259e-08+1.3493e-07j, dtype=torch.complex128), tensor(2.2003e-08-5.5110e-09j, dtype=torch.complex128))
# ['Day = ', 341]
# (tensor(-2.4414e-08+1.0269e-07j, dtype=torch.complex128), tensor(2.0942e-08-5.8483e-10j, dtype=torch.complex128))
# ['Day = ', 342]
# (tensor(-2.0525e-08+7.8411e-08j, dtype=torch.complex128), tensor(1.5341e-08+1.1272e-09j, dtype=torch.complex128))
# ['Day = ', 343]
# (tensor(-2.2117e-08+5.7817e-08j, dtype=torch.complex128), tensor(2.4782e-08-7.4105e-09j, dtype=torch.complex128))
# ['Day = ', 344]
# (tensor(-3.1703e-08+3.2984e-08j, dtype=torch.complex128), tensor(1.4534e-08-6.1582e-09j, dtype=torch.complex128))
# ['Day = ', 345]
# (tensor(-7.7717e-08+2.5331e-08j, dtype=torch.complex128), tensor(1.4428e-08+1.1067e-09j, dtype=torch.complex128))
# ['Day = ', 346]
# (tensor(-9.2796e-08+6.7823e-08j, dtype=torch.complex128), tensor(2.1207e-08+1.3992e-08j, dtype=torch.complex128))
# ['Day = ', 347]
# (tensor(-6.3884e-08+8.5495e-08j, dtype=torch.complex128), tensor(2.9607e-08+2.7292e-11j, dtype=torch.complex128))
# ['Day = ', 348]
# (tensor(-5.3783e-08+6.4151e-08j, dtype=torch.complex128), tensor(1.6964e-08+7.3482e-09j, dtype=torch.complex128))
# ['Day = ', 349]
# (tensor(-7.4458e-08+4.8516e-08j, dtype=torch.complex128), tensor(1.1916e-08+1.1584e-08j, dtype=torch.complex128))
# ['Day = ', 350]
# (tensor(-7.4781e-08+7.0664e-08j, dtype=torch.complex128), tensor(1.9886e-08+3.1632e-09j, dtype=torch.complex128))
# ['Day = ', 351]
# (tensor(-8.7813e-08+2.5710e-08j, dtype=torch.complex128), tensor(2.1573e-08-2.6074e-09j, dtype=torch.complex128))
# ['Day = ', 352]
# (tensor(-7.7870e-08+1.2690e-07j, dtype=torch.complex128), tensor(1.5661e-08+9.3569e-09j, dtype=torch.complex128))
# ['Day = ', 353]
# (tensor(-2.2253e-08+1.3493e-07j, dtype=torch.complex128), tensor(2.2010e-08-5.5200e-09j, dtype=torch.complex128))
# ['Day = ', 354]
# (tensor(-2.4411e-08+1.0267e-07j, dtype=torch.complex128), tensor(2.0936e-08-5.7568e-10j, dtype=torch.complex128))
# ['Day = ', 355]
# (tensor(-2.0543e-08+7.8444e-08j, dtype=torch.complex128), tensor(1.5319e-08+1.1450e-09j, dtype=torch.complex128))
# ['Day = ', 356]
# (tensor(-2.2097e-08+5.7853e-08j, dtype=torch.complex128), tensor(2.4841e-08-7.4651e-09j, dtype=torch.complex128))
# ['Day = ', 357]
# (tensor(-3.1672e-08+3.2842e-08j, dtype=torch.complex128), tensor(1.4523e-08-6.1443e-09j, dtype=torch.complex128))
# ['Day = ', 358]
# (tensor(-7.7818e-08+2.5422e-08j, dtype=torch.complex128), tensor(1.4269e-08+1.2478e-09j, dtype=torch.complex128))
# ['Day = ', 359]
# (tensor(-9.2755e-08+6.8119e-08j, dtype=torch.complex128), tensor(2.1469e-08+1.3766e-08j, dtype=torch.complex128))
# ['Day = ', 360]
# (tensor(-6.3649e-08+8.4827e-08j, dtype=torch.complex128), tensor(2.9725e-08-7.8461e-11j, dtype=torch.complex128))
# ['Day = ', 361]
# (tensor(-5.4229e-08+6.4195e-08j, dtype=torch.complex128), tensor(1.6015e-08+8.1574e-09j, dtype=torch.complex128))
# ['Day = ', 362]
# (tensor(-7.4545e-08+5.0434e-08j, dtype=torch.complex128), tensor(1.2820e-08+1.0775e-08j, dtype=torch.complex128))
# ['Day = ', 363]
# (tensor(-7.3354e-08+6.7904e-08j, dtype=torch.complex128), tensor(2.1421e-08+1.8569e-09j, dtype=torch.complex128))
# ['Day = ', 364]
# (tensor(-8.7816e-08+2.5710e-08j, dtype=torch.complex128), tensor(2.1565e-08-2.6076e-09j, dtype=torch.complex128))
# ['Day = ', 365]
# (tensor(-7.7872e-08+1.2691e-07j, dtype=torch.complex128), tensor(1.5663e-08+9.3528e-09j, dtype=torch.complex128))
# ['Day = ', 366]
# (tensor(-2.2246e-08+1.3492e-07j, dtype=torch.complex128), tensor(2.2016e-08-5.5281e-09j, dtype=torch.complex128))
# ['Day = ', 367]
# (tensor(-2.4414e-08+1.0265e-07j, dtype=torch.complex128), tensor(2.0920e-08-5.5892e-10j, dtype=torch.complex128))
# ['Day = ', 368]
# (tensor(-2.0559e-08+7.8497e-08j, dtype=torch.complex128), tensor(1.5317e-08+1.1463e-09j, dtype=torch.complex128))
# ['Day = ', 369]
# (tensor(-2.2061e-08+5.7839e-08j, dtype=torch.complex128), tensor(2.4905e-08-7.5242e-09j, dtype=torch.complex128))
# ['Day = ', 370]
# ...
# ['Day = ', 778]
# (tensor(-1.0765e-07+1.4210e-07j, dtype=torch.complex128), tensor(-5.5801e-09+2.6511e-08j, dtype=torch.complex128))
# ['Day = ', 779]
# (tensor(-1.2545e-08+6.4528e-08j, dtype=torch.complex128), tensor(1.5295e-07-1.1060e-07j, dtype=torch.complex128))
# ['Day = ', 780]
# (tensor(-8.7842e-08+2.5533e-08j, dtype=torch.complex128), tensor(2.1396e-08-2.6900e-09j, dtype=torch.complex128))
# ['Day = ', 781]
# (tensor(-7.8035e-08+1.2726e-07j, dtype=torch.complex128), tensor(1.5492e-08+9.5129e-09j, dtype=torch.complex128))
# ['Day = ', 782]
# (tensor(-2.2000e-08+1.3519e-07j, dtype=torch.complex128), tensor(2.2360e-08-5.9844e-09j, dtype=torch.complex128))
# ['Day = ', 783]
# (tensor(-2.4146e-08+1.0127e-07j, dtype=torch.complex128), tensor(2.0818e-08-2.6177e-10j, dtype=torch.complex128))
# ['Day = ', 784]
# (tensor(-2.1548e-08+7.9740e-08j, dtype=torch.complex128), tensor(1.3874e-08+2.3427e-09j, dtype=torch.complex128))
# ['Day = ', 785]
# (tensor(-2.1374e-08+6.0540e-08j, dtype=torch.complex128), tensor(2.7695e-08-1.0094e-08j, dtype=torch.complex128))
# ['Day = ', 786]
# (tensor(-2.9530e-08+2.5586e-08j, dtype=torch.complex128), tensor(1.5227e-08-6.4917e-09j, dtype=torch.complex128))
# ['Day = ', 787]
# (tensor(-8.2823e-08+2.7496e-08j, dtype=torch.complex128), tensor(5.0315e-09+9.4710e-09j, dtype=torch.complex128))
# ['Day = ', 788]
# (tensor(-9.2595e-08+8.6762e-08j, dtype=torch.complex128), tensor(3.2657e-08+4.0382e-09j, dtype=torch.complex128))
# ['Day = ', 789]
# (tensor(-4.9518e-08+5.3590e-08j, dtype=torch.complex128), tensor(4.1999e-08-1.0988e-08j, dtype=torch.complex128))
# ['Day = ', 790]
# (tensor(-7.4327e-08+5.2039e-08j, dtype=torch.complex128), tensor(-3.4718e-08+5.1601e-08j, dtype=torch.complex128))
# ['Day = ', 791]
# (tensor(-8.9209e-08+1.5939e-07j, dtype=torch.complex128), tensor(4.3655e-08-1.6960e-08j, dtype=torch.complex128))
# ['Day = ', 792]
# (tensor(5.2117e-09-4.5978e-08j, dtype=torch.complex128), tensor(1.2839e-07-8.8995e-08j, dtype=torch.complex128))
# ['Day = ', 793]
# (tensor(-8.7918e-08+2.5645e-08j, dtype=torch.complex128), tensor(2.1168e-08-2.6425e-09j, dtype=torch.complex128))
# ['Day = ', 794]
# (tensor(-7.7993e-08+1.2746e-07j, dtype=torch.complex128), tensor(1.5694e-08+9.2401e-09j, dtype=torch.complex128))
# ['Day = ', 795]
# (tensor(-2.1887e-08+1.3467e-07j, dtype=torch.complex128), tensor(2.2370e-08-6.0150e-09j, dtype=torch.complex128))
# ['Day = ', 796]
# (tensor(-2.4455e-08+1.0145e-07j, dtype=torch.complex128), tensor(2.0214e-08+2.2441e-10j, dtype=torch.complex128))
# ['Day = ', 797]
# (tensor(-2.1512e-08+8.1062e-08j, dtype=torch.complex128), tensor(1.4739e-08+1.5987e-09j, dtype=torch.complex128))
# ['Day = ', 798]
# (tensor(-2.0393e-08+5.8187e-08j, dtype=torch.complex128), tensor(2.8447e-08-1.0796e-08j, dtype=torch.complex128))
# ['Day = ', 799]
# (tensor(-3.1006e-08+2.4929e-08j, dtype=torch.complex128), tensor(1.1576e-08-3.3510e-09j, dtype=torch.complex128))
# ['Day = ', 800]
# (tensor(-8.3669e-08+3.5409e-08j, dtype=torch.complex128), tensor(7.5482e-09+7.1952e-09j, dtype=torch.complex128))
# ['Day = ', 801]
# (tensor(-8.6747e-08+7.7859e-08j, dtype=torch.complex128), tensor(4.0160e-08-2.2140e-09j, dtype=torch.complex128))
# ['Day = ', 802]
# (tensor(-5.4645e-08+4.2180e-08j, dtype=torch.complex128), tensor(2.4329e-08+4.3776e-09j, dtype=torch.complex128))
# ['Day = ', 803]
# (tensor(-8.4280e-08+9.3815e-08j, dtype=torch.complex128), tensor(-3.2696e-08+4.9231e-08j, dtype=torch.complex128))
# ['Day = ', 804]
# (tensor(-6.0143e-08+1.3637e-07j, dtype=torch.complex128), tensor(9.2577e-08-5.9943e-08j, dtype=torch.complex128))
# ['Day = ', 805]
# (tensor(-4.7802e-09-1.3747e-07j, dtype=torch.complex128), tensor(5.3845e-08-2.4753e-08j, dtype=torch.complex128))
# ['Day = ', 806]
# (tensor(-8.7972e-08+2.5813e-08j, dtype=torch.complex128), tensor(2.1046e-08-2.5687e-09j, dtype=torch.complex128))
# ['Day = ', 807]
# (tensor(-7.7890e-08+1.2748e-07j, dtype=torch.complex128), tensor(1.5933e-08+8.9452e-09j, dtype=torch.complex128))
# ['Day = ', 808]
# (tensor(-2.1893e-08+1.3412e-07j, dtype=torch.complex128), tensor(2.2238e-08-5.8536e-09j, dtype=torch.complex128))
# ['Day = ', 809]
# (tensor(-2.4824e-08+1.0217e-07j, dtype=torch.complex128), tensor(1.9748e-08+5.1127e-10j, dtype=torch.complex128))
# ['Day = ', 810]
# (tensor(-2.1076e-08+8.1663e-08j, dtype=torch.complex128), tensor(1.6058e-08+4.8329e-10j, dtype=torch.complex128))
# ['Day = ', 811]
# (tensor(-1.9850e-08+5.5104e-08j, dtype=torch.complex128), tensor(2.7936e-08-1.0333e-08j, dtype=torch.complex128))
# ['Day = ', 812]
# (tensor(-3.3125e-08+2.7295e-08j, dtype=torch.complex128), tensor(8.1874e-09-5.4041e-10j, dtype=torch.complex128))
# ['Day = ', 813]
# (tensor(-8.2371e-08+4.1303e-08j, dtype=torch.complex128), tensor(1.3412e-08+1.9446e-09j, dtype=torch.complex128))
# ['Day = ', 814]
# (tensor(-8.1839e-08+6.2773e-08j, dtype=torch.complex128), tensor(4.2029e-08-3.6085e-09j, dtype=torch.complex128))
# ['Day = ', 815]
# (tensor(-6.4702e-08+4.5071e-08j, dtype=torch.complex128), tensor(4.3540e-09+2.1842e-08j, dtype=torch.complex128))
# ['Day = ', 816]
# (tensor(-8.4641e-08+1.3424e-07j, dtype=torch.complex128), tensor(-1.0522e-08+2.9702e-08j, dtype=torch.complex128))
# ['Day = ', 817]
# (tensor(-2.9515e-08+7.2862e-08j, dtype=torch.complex128), tensor(1.2175e-07-8.5310e-08j, dtype=torch.complex128))
# ['Day = ', 818]
# (tensor(-4.4952e-08-1.6936e-07j, dtype=torch.complex128), tensor(-5.2663e-08+6.6503e-08j, dtype=torch.complex128))
# ['Day = ', 819]
# (tensor(-8.7976e-08+2.5981e-08j, dtype=torch.complex128), tensor(2.1102e-08-2.4919e-09j, dtype=torch.complex128))
# ['Day = ', 820]
# (tensor(-7.7755e-08+1.2728e-07j, dtype=torch.complex128), tensor(1.6125e-08+8.7399e-09j, dtype=torch.complex128))
# ['Day = ', 821]
# (tensor(-2.2043e-08+1.3376e-07j, dtype=torch.complex128), tensor(2.1983e-08-5.5202e-09j, dtype=torch.complex128))
# ['Day = ', 822]
# (tensor(-2.5121e-08+1.0326e-07j, dtype=torch.complex128), tensor(1.9636e-08+4.3938e-10j, dtype=torch.complex128))
# ['Day = ', 823]
# (tensor(-2.0321e-08+8.1140e-08j, dtype=torch.complex128), tensor(1.7412e-08-6.4761e-10j, dtype=torch.complex128))
# ['Day = ', 824]
# (tensor(-2.0062e-08+5.2342e-08j, dtype=torch.complex128), tensor(2.6073e-08-8.6207e-09j, dtype=torch.complex128))
# ['Day = ', 825]
# (tensor(-3.5195e-08+3.2445e-08j, dtype=torch.complex128), tensor(6.4635e-09+7.5167e-10j, dtype=torch.complex128))
# ['Day = ', 826]
# (tensor(-7.8949e-08+4.2378e-08j, dtype=torch.complex128), tensor(2.1073e-08-4.8870e-09j, dtype=torch.complex128))
# ['Day = ', 827]
# (tensor(-8.0029e-08+4.6051e-08j, dtype=torch.complex128), tensor(3.6227e-08+1.5247e-09j, dtype=torch.complex128))
# ['Day = ', 828]
# (tensor(-7.6843e-08+6.4411e-08j, dtype=torch.complex128), tensor(-1.0548e-08+3.4975e-08j, dtype=torch.complex128))
# ['Day = ', 829]
# (tensor(-7.3059e-08+1.5700e-07j, dtype=torch.complex128), tensor(2.7665e-08-3.2059e-09j, dtype=torch.complex128))
# ['Day = ', 830]
# (tensor(-9.0897e-09-1.5306e-08j, dtype=torch.complex128), tensor(1.1507e-07-7.8966e-08j, dtype=torch.complex128))
# ['Day = ', 831]
# (tensor(-1.0635e-07-1.1529e-07j, dtype=torch.complex128), tensor(-1.5633e-07+1.5487e-07j, dtype=torch.complex128))
# ['Day = ', 832]
# (tensor(-8.7918e-08+2.6084e-08j, dtype=torch.complex128), tensor(2.1355e-08-2.4418e-09j, dtype=torch.complex128))
# ['Day = ', 833]
# (tensor(-7.7632e-08+1.2689e-07j, dtype=torch.complex128), tensor(1.6181e-08+8.7261e-09j, dtype=torch.complex128))
# ['Day = ', 834]
# (tensor(-2.2310e-08+1.3376e-07j, dtype=torch.complex128), tensor(2.1678e-08-5.1070e-09j, dtype=torch.complex128))
# ['Day = ', 835]
# (tensor(-2.5212e-08+1.0439e-07j, dtype=torch.complex128), tensor(2.0005e-08-4.5356e-11j, dtype=torch.complex128))
# ['Day = ', 836]
# (tensor(-1.9473e-08+7.9441e-08j, dtype=torch.complex128), tensor(1.8274e-08-1.3499e-09j, dtype=torch.complex128))
# ['Day = ', 837]
# (tensor(-2.1117e-08+5.1068e-08j, dtype=torch.complex128), tensor(2.3285e-08-6.0488e-09j, dtype=torch.complex128))
# ['Day = ', 838]
# (tensor(-3.6387e-08+3.8979e-08j, dtype=torch.complex128), tensor(7.4696e-09-3.3579e-10j, dtype=torch.complex128))
# ['Day = ', 839]
# (tensor(-7.4269e-08+3.7101e-08j, dtype=torch.complex128), tensor(2.7912e-08-1.0959e-08j, dtype=torch.complex128))
# ['Day = ', 840]
# (tensor(-8.2748e-08+3.3938e-08j, dtype=torch.complex128), tensor(2.3286e-08+1.2656e-08j, dtype=torch.complex128))
# ['Day = ', 841]
# (tensor(-8.6742e-08+9.6329e-08j, dtype=torch.complex128), tensor(-1.3310e-08+3.7580e-08j, dtype=torch.complex128))
# ['Day = ', 842]
# (tensor(-5.1370e-08+1.4902e-07j, dtype=torch.complex128), tensor(7.0433e-08-3.9545e-08j, dtype=torch.complex128))
# ['Day = ', 843]
# (tensor(-9.3008e-09-9.8909e-08j, dtype=torch.complex128), tensor(6.6941e-08-3.6123e-08j, dtype=torch.complex128))
# ['Day = ', 844]
# (tensor(-1.6955e-07+2.3096e-08j, dtype=torch.complex128), tensor(-2.1548e-07+2.0469e-07j, dtype=torch.complex128))
# ['Day = ', 845]
# (tensor(-8.7806e-08+2.6065e-08j, dtype=torch.complex128), tensor(2.1750e-08-2.4443e-09j, dtype=torch.complex128))
# ['Day = ', 846]
# (tensor(-7.7573e-08+1.2641e-07j, dtype=torch.complex128), tensor(1.6049e-08+8.9532e-09j, dtype=torch.complex128))
# ['Day = ', 847]
# (tensor(-2.2617e-08+1.3421e-07j, dtype=torch.complex128), tensor(2.1432e-08-4.7593e-09j, dtype=torch.complex128))
# ['Day = ', 848]
# (tensor(-2.5014e-08+1.0510e-07j, dtype=torch.complex128), tensor(2.0818e-08-8.4608e-10j, dtype=torch.complex128))
# ['Day = ', 849]
# (tensor(-1.8844e-08+7.6968e-08j, dtype=torch.complex128), tensor(1.8189e-08-1.2468e-09j, dtype=torch.complex128))
# ['Day = ', 850]
# (tensor(-2.2792e-08+5.2130e-08j, dtype=torch.complex128), tensor(2.0462e-08-3.4376e-09j, dtype=torch.complex128))
# ['Day = ', 851]
# (tensor(-3.6026e-08+4.4630e-08j, dtype=torch.complex128), tensor(1.1436e-08-3.9200e-09j, dtype=torch.complex128))
# ['Day = ', 852]
# (tensor(-6.9893e-08+2.6098e-08j, dtype=torch.complex128), tensor(3.1032e-08-1.3693e-08j, dtype=torch.complex128))
# ['Day = ', 853]
# (tensor(-8.9961e-08+3.2287e-08j, dtype=torch.complex128), tensor(6.6857e-09+2.6760e-08j, dtype=torch.complex128))
# ['Day = ', 854]
# (tensor(-8.9963e-08+1.3109e-07j, dtype=torch.complex128), tensor(-4.6029e-11+2.6205e-08j, dtype=torch.complex128))
# ['Day = ', 855]
# (tensor(-2.5834e-08+1.0638e-07j, dtype=torch.complex128), tensor(1.0191e-07-6.5720e-08j, dtype=torch.complex128))
# ['Day = ', 856]
# (tensor(-3.4814e-08-1.4380e-07j, dtype=torch.complex128), tensor(-1.3127e-08+3.4659e-08j, dtype=torch.complex128))
# ['Day = ', 857]
# (tensor(-2.0995e-07+2.1044e-07j, dtype=torch.complex128), tensor(-1.9643e-07+1.8739e-07j, dtype=torch.complex128))
# ['Day = ', 858]
# (tensor(-8.7672e-08+2.5905e-08j, dtype=torch.complex128), tensor(2.2163e-08-2.5106e-09j, dtype=torch.complex128))
# ['Day = ', 859]
# (tensor(-7.7617e-08+1.2601e-07j, dtype=torch.complex128), tensor(1.5738e-08+9.3869e-09j, dtype=torch.complex128))
# ['Day = ', 860]
# (tensor(-2.2850e-08+1.3505e-07j, dtype=torch.complex128), tensor(2.1355e-08-4.6297e-09j, dtype=torch.complex128))
# ['Day = ', 861]
# (tensor(-2.4538e-08+1.0503e-07j, dtype=torch.complex128), tensor(2.1856e-08-1.7185e-09j, dtype=torch.complex128))
# ['Day = ', 862]
# (tensor(-1.8736e-08+7.4522e-08j, dtype=torch.complex128), tensor(1.6974e-08-1.9394e-10j, dtype=torch.complex128))
# ['Day = ', 863]
# (tensor(-2.4567e-08+5.5644e-08j, dtype=torch.complex128), tensor(1.8715e-08-1.8118e-09j, dtype=torch.complex128))
# ['Day = ', 864]
# (tensor(-3.3898e-08+4.6958e-08j, dtype=torch.complex128), tensor(1.7473e-08-9.1567e-09j, dtype=torch.complex128))
# ['Day = ', 865]
# (tensor(-6.7624e-08+1.2407e-08j, dtype=torch.complex128), tensor(2.8342e-08-1.1239e-08j, dtype=torch.complex128))
# ['Day = ', 866]
# (tensor(-9.9848e-08+4.4162e-08j, dtype=torch.complex128), tensor(-7.8457e-09+3.8937e-08j, dtype=torch.complex128))
# ['Day = ', 867]
# (tensor(-8.3695e-08+1.5558e-07j, dtype=torch.complex128), tensor(2.7683e-08+2.1330e-09j, dtype=torch.complex128))
# ['Day = ', 868]
# (tensor(-5.6738e-09+3.7992e-08j, dtype=torch.complex128), tensor(1.0703e-07-6.9030e-08j, dtype=torch.complex128))
# ['Day = ', 869]
# (tensor(-8.1354e-08-1.2331e-07j, dtype=torch.complex128), tensor(-1.0079e-07+1.1179e-07j, dtype=torch.complex128))
# ['Day = ', 870]
# (tensor(-2.0631e-07+3.8385e-07j, dtype=torch.complex128), tensor(-8.8746e-08+9.4353e-08j, dtype=torch.complex128))
# ['Day = ', 871]
# (tensor(-8.7564e-08+2.5634e-08j, dtype=torch.complex128), tensor(2.2436e-08-2.6291e-09j, dtype=torch.complex128))
# ['Day = ', 872]
# (tensor(-7.7769e-08+1.2588e-07j, dtype=torch.complex128), tensor(1.5328e-08+9.9031e-09j, dtype=torch.complex128))
# ['Day = ', 873]
# (tensor(-2.2901e-08+1.3601e-07j, dtype=torch.complex128), tensor(2.1518e-08-4.8198e-09j, dtype=torch.complex128))
# ['Day = ', 874]
# (tensor(-2.3909e-08+1.0402e-07j, dtype=torch.complex128), tensor(2.2760e-08-2.3339e-09j, dtype=torch.complex128))
# ['Day = ', 875]
# (tensor(-1.9311e-08+7.3077e-08j, dtype=torch.complex128), tensor(1.4848e-08+1.6106e-09j, dtype=torch.complex128))
# ['Day = ', 876]
# (tensor(-2.5762e-08+6.0784e-08j, dtype=torch.complex128), tensor(1.8981e-08-2.0417e-09j, dtype=torch.complex128))
# ['Day = ', 877]
# (tensor(-3.0438e-08+4.4276e-08j, dtype=torch.complex128), tensor(2.3669e-08-1.4353e-08j, dtype=torch.complex128))
# ['Day = ', 878]
# (tensor(-6.8845e-08+8.2866e-10j, dtype=torch.complex128), tensor(1.9570e-08-3.3738e-09j, dtype=torch.complex128))
# ['Day = ', 879]
# (tensor(-1.0911e-07+6.7974e-08j, dtype=torch.complex128), tensor(-1.4079e-08+4.3924e-08j, dtype=torch.complex128))
# ['Day = ', 880]
# (tensor(-6.8235e-08+1.5774e-07j, dtype=torch.complex128), tensor(6.2228e-08-2.8028e-08j, dtype=torch.complex128))
# ['Day = ', 881]
# (tensor(-1.0672e-10-3.5007e-08j, dtype=torch.complex128), tensor(7.7707e-08-4.2903e-08j, dtype=torch.complex128))
# ['Day = ', 882]
# (tensor(-1.3534e-07-3.0485e-08j, dtype=torch.complex128), tensor(-1.6310e-07+1.6620e-07j, dtype=torch.complex128))
# ['Day = ', 883]
# (tensor(-1.4994e-07+4.7146e-07j, dtype=torch.complex128), tensor(8.5359e-08-5.5012e-08j, dtype=torch.complex128))
# ['Day = ', 884]
# (tensor(-8.7531e-08+2.5334e-08j, dtype=torch.complex128), tensor(2.2427e-08-2.7649e-09j, dtype=torch.complex128))
# ['Day = ', 885]
# (tensor(-7.7994e-08+1.2612e-07j, dtype=torch.complex128), tensor(1.4961e-08+1.0316e-08j, dtype=torch.complex128))
# ['Day = ', 886]
# (tensor(-2.2707e-08+1.3676e-07j, dtype=torch.complex128), tensor(2.1911e-08-5.3279e-09j, dtype=torch.complex128))
# ['Day = ', 887]
# (tensor(-2.3341e-08+1.0226e-07j, dtype=torch.complex128), tensor(2.3142e-08-2.3894e-09j, dtype=torch.complex128))
# ['Day = ', 888]
# (tensor(-2.0497e-08+7.3436e-08j, dtype=torch.complex128), tensor(1.2444e-08+3.6255e-09j, dtype=torch.complex128))
# ['Day = ', 889]
# (tensor(-2.5771e-08+6.5890e-08j, dtype=torch.complex128), tensor(2.1620e-08-4.4633e-09j, dtype=torch.complex128))
# ['Day = ', 890]
# (tensor(-2.6710e-08+3.6493e-08j, dtype=torch.complex128), tensor(2.7606e-08-1.7444e-08j, dtype=torch.complex128))
# ['Day = ', 891]
# (tensor(-7.3876e-08-3.5667e-09j, dtype=torch.complex128), tensor(6.7893e-09+8.0344e-09j, dtype=torch.complex128))
# ['Day = ', 892]
# (tensor(-1.1394e-07+9.7044e-08j, dtype=torch.complex128), tensor(-7.6372e-09+3.8091e-08j, dtype=torch.complex128))
# ['Day = ', 893]
# (tensor(-4.7587e-08+1.3159e-07j, dtype=torch.complex128), tensor(9.1485e-08-5.3741e-08j, dtype=torch.complex128))
# ['Day = ', 894]
# (tensor(-1.4695e-08-8.4778e-08j, dtype=torch.complex128), tensor(1.7619e-08+9.0942e-09j, dtype=torch.complex128))
# ['Day = ', 895]
# (tensor(-1.7710e-07+1.1457e-07j, dtype=torch.complex128), tensor(-1.6955e-07+1.7112e-07j, dtype=torch.complex128))
# ['Day = ', 896]
# (tensor(-5.1019e-08+4.1886e-07j, dtype=torch.complex128), tensor(2.7225e-07-2.1455e-07j, dtype=torch.complex128))
# ['Day = ', 897]
# (tensor(-8.7603e-08+2.5116e-08j, dtype=torch.complex128), tensor(2.2076e-08-2.8683e-09j, dtype=torch.complex128))
# ['Day = ', 898]
# (tensor(-7.8220e-08+1.2673e-07j, dtype=torch.complex128), tensor(1.4790e-08+1.0439e-08j, dtype=torch.complex128))
# ['Day = ', 899]
# (tensor(-2.2289e-08+1.3694e-07j, dtype=torch.complex128), tensor(2.2431e-08-6.0261e-09j, dtype=torch.complex128))
# ['Day = ', 900]

# %%
## Write spectral data for possible restart
##
torch.save(zmn1,datapath+'zmn1.spectral.pt')
torch.save(zmn2,datapath+'zmn2.spectral.pt')
torch.save(dmn1,datapath+'dmn1.spectral.pt')
torch.save(dmn2,datapath+'dmn2.spectral.pt')
torch.save(tmn1,datapath+'tmn1.spectral.pt')
torch.save(tmn2,datapath+'tmn2.spectral.pt')
torch.save(qmn1,datapath+'qmn1.spectral.pt')
torch.save(qmn2,datapath+'qmn2.spectral.pt')
