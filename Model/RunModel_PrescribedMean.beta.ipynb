# %%
import logging
logging.captureWarnings(False)
logging.getLogger('py.warnings').setLevel(logging.ERROR)
from dask.distributed import Client, progress
client = Client(n_workers=5, threads_per_worker=4, memory_limit='30GB')
client
# Out:
# /Users/bkirtman/miniconda3/envs/myenv/lib/python3.9/site-packages/distributed/node.py:179: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 55677 instead
#   warnings.warn(
# 2023-12-29 20:34:05,452 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/jd/v995m27s62746tw3wq1xg1mh0000gn/T/dask-worker-space/worker-fnppkjiw', purging
# 2023-12-29 20:34:05,452 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/jd/v995m27s62746tw3wq1xg1mh0000gn/T/dask-worker-space/worker-w0t5u9xc', purging
# 2023-12-29 20:34:05,452 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/jd/v995m27s62746tw3wq1xg1mh0000gn/T/dask-worker-space/worker-opnzr72d', purging
# 2023-12-29 20:34:05,452 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/jd/v995m27s62746tw3wq1xg1mh0000gn/T/dask-worker-space/worker-yk7d8usi', purging
# 2023-12-29 20:34:05,452 - distributed.diskutils - INFO - Found stale lock file and directory '/var/folders/jd/v995m27s62746tw3wq1xg1mh0000gn/T/dask-worker-space/worker-0mks5iml', purging
# <Client: 'tcp://127.0.0.1:55678' processes=5 threads=20, memory=139.70 GiB>

# %%
import xarray
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import numpy as np
import scipy as sp
import pandas as pd
from netCDF4 import Dataset
import dask
import torch
import torch.nn as nn
import torch.fft as fft
import subprocess
import sys

from sht_utils import *
from subs1_utils import *

# %%
### This cell initializes the model
###
###     First Define all spectral grids
###
zw = 42 # zonal wave number
mw = 42 # meridional wave number
kmax = 11
imax = 128
jmax = 64
steps_per_day = 216 ### Changing this number implies time step changes and should
#                       be implemented carefully
###
spec = (mw,zw,kmax)
grid = (imax,jmax,kmax)
#
#
# provide experiment name and data path for writing out data
# datapath may need to be edited for your system
#
expname = 'PrescribedMeanT42L11F'
foo = str(subprocess.check_output(['whoami']))
end = len(foo) - 3
uname = foo[2:end]
datapath = '/Users/'+uname+'/Work/AGCM/AGCM/tmp4/'+expname+'/'
subprocess.call(['rm','-r', datapath])
subprocess.check_output(['mkdir', datapath])
# Out:
# b''

# %%
# Get the Gaussian latitudes and equally spaced longitudes
#
cost_lg, wlg = legendre_gauss_weights(jmax, -1, 1)
lats = np.flip(np.arccos(cost_lg))
lats = -90+180*lats/(np.pi)
#
lons = np.linspace(0.0,360.0-360.0/imax,imax)
#
# Initialize grid to spectral (sht) and spectral to grid (isht)
# transforms
#
sht = RealSHT(jmax, imax, lmax=mw, mmax=zw, grid="legendre-gauss", csphase=False)
isht = InverseRealSHT(jmax, imax, lmax=mw, mmax=zw, grid="legendre-gauss", csphase=False)
vsht = RealVectorSHT(jmax, imax, lmax=mw, mmax=zw, grid="legendre-gauss", csphase=False)
ivsht = InverseRealVectorSHT(jmax, imax, lmax=mw, mmax=zw, grid="legendre-gauss", csphase=False)

# %%
#
# Initialization: Could read spectral restarts, or could
#              start at rest. If wanting to use grid point see
#              jupyter notebook preprocess
#              
#
# Implement at rest initial condition, but need coriolis
#
#
coriolis = np.zeros((jmax,imax))
for jj in range(jmax):
    coriolis[jj,:] = -(4.0*np.pi/86400)*cost_lg[jj] # minus sign because 
                                                    #grid runs South-To-North
#
#
# Initialize spectral fields (at rest or to be read in)
#
zmn1 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
zmn2 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
zmn3 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
dmn1 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
dmn2 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
dmn3 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
tmn1 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
tmn2 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
tmn3 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
wmn1 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
wmn2 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
wmn3 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
qmn1 = torch.zeros((mw,zw),dtype=torch.complex128)
qmn2 = torch.zeros((mw,zw),dtype=torch.complex128)
qmn3 = torch.zeros((mw,zw),dtype=torch.complex128)
#
# Introduce an initial perturbation to get things going
#
datapath_init = '/Users/'+uname+'/Work/AGCM/AGCM/tmp4/Restarts/PerturbationT42L11/'
zmn1 = torch.load(datapath_init+'zmn1.spectral.pt')
zmn2 = torch.load(datapath_init+'zmn2.spectral.pt')
dmn1 = torch.load(datapath_init+'dmn1.spectral.pt')
dmn2 = torch.load(datapath_init+'dmn2.spectral.pt')
tmn1 = torch.load(datapath_init+'tmn1.spectral.pt')
tmn2 = torch.load(datapath_init+'tmn2.spectral.pt')
qmn1 = torch.load(datapath_init+'qmn1.spectral.pt')
qmn2 = torch.load(datapath_init+'qmn2.spectral.pt')
#
#
# Topography data - this should be spectral data or can be
#                        initialized to zero. If grid point data
#                        is desired see gptosp.agcm.ipynb for how to
#                        convert to spectral. 
#
# Setting topography to zero here
#
phismn = torch.zeros((mw,zw),dtype=torch.complex128)
#
# If non-zero topog read here
#
####phismn = torch.load('topog.spectral.pt') # only read topography is background state is zonally symmetric
#
#
# Adding heating here see preprocess.ipynb
#
heat = torch.load('heat.ggrid.pt')
#
# or set to zero
#
###heat = torch.zeros((kmax,jmax,imax),dtype=torch.float64)
#
#
# Read Climatology on Gausian Grid
#
uclim = torch.load('usig.ggrid.pt')
vclim = torch.load('vsig.ggrid.pt')
tclim = torch.load('tsig.ggrid.pt')
vortclim = torch.load('vortsig.ggrid.pt')
divclim = torch.load('divsig.ggrid.pt')
dxqclim = torch.load('dxq_gg.ggrid.pt')
dyqclim = torch.load('dyq_gg.ggrid.pt')
#
#

# %%
###
### Constants, parameters, vertical differencing parameters,
### matricies for geopotential height, etc ...
###
delsig, si, sl, sikap, slkap, cth1, cth2, r1b, r2b = bscst(kmax)
### The above code is in subs1_utils.py - vertical structure related
### This code would need to be changed if the vertical resolution
### is changed - could be done by simply specifying delsig in bscst
###
amtrx, cmtrx, dmtrx = mcoeff(kmax,si,sl,slkap,r1b,r2b,delsig)
### The above code is for geopotential height and implicit scheme
### in subs1_utils.py but unlikely any changes would be needed
emtrx = inv_em(dmtrx,steps_per_day,kmax,mw,zw)
### The above code
### emtrix is used in the implicit time scheme, computed once here to save cpu time
### changes unlikely

# %%
#### Preprocessing is complete - now time to run model
#
#
# The Model Runs in 30-day chuncks - need to specify how many 30-day chunks to run
tl = 30 ##### tl is the chunk size - typically 30 days, but for testing 3 is reasonable
#
# Suggested ichunk for time dependent models: 120
#
ae = 6.371E+06 # Earth radius
tmnt = torch.zeros((tl,kmax,mw,zw),dtype=torch.complex128)
zmnt = torch.zeros((tl,kmax,mw,zw),dtype=torch.complex128)
dmnt = torch.zeros((tl,kmax,mw,zw),dtype=torch.complex128)
qmnt = torch.zeros((tl,mw,zw),dtype=torch.complex128)
wmnt = torch.zeros((tl,kmax,mw,zw),dtype=torch.complex128)
#
ddtdiv = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
ddtvort = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
junk = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
ttend = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
#
vort = torch.zeros((kmax,jmax,imax),dtype=torch.float64)
div = torch.zeros((kmax,jmax,imax),dtype=torch.float64)
temp = torch.zeros((kmax,jmax,imax),dtype=torch.float64)
qdot = torch.zeros((kmax,jmax,imax),dtype=torch.float64)
times = pd.date_range(start = '1950-01-01', end='2100-01-01', freq='D')
# 
ichunk = 30
#
idays = tl * ichunk
#
#
#
#
# Begin Time Loop
#
ii = 0
savedat = 0
daycount = 0
total_days = 0
nstep = idays*steps_per_day
while ii < nstep:
    ii = ii + 1
    savedat = savedat + 1
    zmnt[daycount] = zmnt[daycount] + zmn1/steps_per_day
    dmnt[daycount] = dmnt[daycount] + dmn1/steps_per_day
    tmnt[daycount] = tmnt[daycount] + tmn1/steps_per_day
    qmnt[daycount] = qmnt[daycount] + qmn1/steps_per_day
    wmnt[daycount] = wmnt[daycount] + wmn1/steps_per_day
    if (savedat == steps_per_day): # post processing
        #
        # Call Postprocessing Routine as needed
        #
        print((dmn1[10,2,2],dmn1[9,2,1]))
        daycount = daycount + 1
        total_days = total_days + 1
        print(['Day = ',total_days])
        if (daycount == tl):
            times_30day = times[total_days-tl:total_days]
            postprocessing(isht,ivsht,zmnt,dmnt,tmnt,qmnt,wmnt,\
                           phismn,amtrx,times_30day,mw,zw,\
                           kmax,imax,jmax,sl,lats,lons,tl,datapath)
            tmnt = torch.zeros((tl,kmax,mw,zw),dtype=torch.complex128)
            zmnt = torch.zeros((tl,kmax,mw,zw),dtype=torch.complex128)
            dmnt = torch.zeros((tl,kmax,mw,zw),dtype=torch.complex128)
            qmnt = torch.zeros((tl,mw,zw),dtype=torch.complex128)
            wmnt = torch.zeros((tl,kmax,mw,zw),dtype=torch.complex128)
            daycount = 0
        savedat = 0
    #
    # Run model for one time step
    #
    # Spectral to grid transformation of needed fields:
    #   Vorticity, divergence, temperature, U, V, 
    #   grad(ln(Ps)), Q prescibed heating
    #
    #
    for k in range(kmax):
        vort[k] = isht(zmn2[k]).cpu() ### This is the relative vorticity
        div[k] = isht(dmn2[k]).cpu()
        temp[k] = isht(tmn2[k]).cpu()
        qdot[k] = isht(wmn2[k]).cpu()
    u,v = uv(ivsht,zmn2,dmn2,mw,zw,kmax,imax,jmax)
    dxq,dyq = gradq(ivsht,qmn2,mw,zw,imax,jmax)
    #
    # Stack grid variables climo first[0] perturbation second[1]
    #
    vort2 = torch.stack((vortclim,vort)) # vortclim is the absolute vorticity
    div2 = torch.stack((divclim,div))
    temp2 = torch.stack((tclim,temp))
    u2 = torch.stack((uclim,u))
    v2 = torch.stack((vclim,v))
    dxq2 = torch.stack((dxqclim,dxq))
    dyq2 = torch.stack((dyqclim,dyq))
    #
    # Non-Linear products
    #
    a,b,e,ut,vt,ri,wj,cbar,dbar = nlprod_prescribed_mean(u2,v2,vort2,div2,temp2,dxq2,dyq2,heat,coriolis,delsig,si,sikap,slkap,\
                                         r1b,r2b,cth1,cth2,cost_lg,kmax,imax,jmax)
    #
    #
    # Grid to spectral transformation of nlprod results
    #
    ddtdiv,ddtvort = vortdivspec(vsht,a,b,kmax,mw,zw)
    zmn3 = - ddtvort
    dmn3 = ddtdiv
    junk,ttend = vortdivspec(vsht,ut,vt,kmax,mw,zw)
    for k in range(kmax):
        dddt = dmn3[k] - lap_sht(sht,e[k],mw,zw) 
        dmn3[k] = dddt
        tmn3[k] = -ttend[k] + sht(ri[k]).cpu()
        wmn3[k] = sht(wj[k]).cpu() ### Prescribed heating converted to spectral
    qmn3 = -sht(cbar[1]).cpu() ### Only cbar here since dbar is included in implicit or explicit
    # 
    # Diffusion, Damping, Implicit or Explicit time differencing, Time filter
    #
    zmn3,dmn3,tmn3 = diffsn(zmn1,zmn3,dmn1,dmn3,tmn1,tmn3,\
                            kmax,mw,zw)
    #
    zmn3,dmn3,tmn3,qmn3 = damp_prescribed_mean(zmn1,zmn3,dmn1,dmn3,tmn1,tmn3,qmn1,qmn3,\
                          kmax)
    #
    dt = 86400.0/steps_per_day
    #
    zmn1,zmn2,zmn3,dmn1,dmn2,dmn3,tmn1,tmn2,tmn3,qmn1,qmn2,qmn3 = \
                        explicit(dt,amtrx,cmtrx,dmtrx,emtrx,\
                        zmn1,zmn2,zmn3,dmn1,dmn2,dmn3,tmn1,tmn2,\
                        tmn3,wmn1,wmn2,wmn3,qmn1,qmn2,qmn3,phismn,\
                        delsig,kmax,mw,zw)
    ####
    ## Reset zmn3, dmn3, tmn3,wmn3 & qmn3
    ###
    zmn3 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
    dmn3 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
    tmn3 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
    wmn3 = torch.zeros((kmax,mw,zw),dtype=torch.complex128)
    qmn3 = torch.zeros((mw,zw),dtype=torch.complex128)
#
# Done
# Out:
# (tensor(-1.7397e-07-1.1668e-07j, dtype=torch.complex128), tensor(-1.1757e-07+1.8326e-07j, dtype=torch.complex128))
# ['Day = ', 1]
# (tensor(-3.2959e-10+1.0126e-08j, dtype=torch.complex128), tensor(-2.4516e-07+2.9107e-07j, dtype=torch.complex128))
# ['Day = ', 2]
# (tensor(2.0175e-07-8.7955e-08j, dtype=torch.complex128), tensor(-3.6639e-08+8.5444e-08j, dtype=torch.complex128))
# ['Day = ', 3]
# (tensor(2.8687e-07-1.0874e-07j, dtype=torch.complex128), tensor(1.4893e-08+1.0102e-07j, dtype=torch.complex128))
# ['Day = ', 4]
# (tensor(2.4848e-07-1.4224e-07j, dtype=torch.complex128), tensor(-2.2656e-07+1.9145e-07j, dtype=torch.complex128))
# ['Day = ', 5]
# (tensor(1.6312e-07-1.6538e-07j, dtype=torch.complex128), tensor(-1.7997e-07+3.2779e-07j, dtype=torch.complex128))
# ['Day = ', 6]
# (tensor(1.4062e-07-1.3138e-07j, dtype=torch.complex128), tensor(-1.0490e-07-2.4742e-08j, dtype=torch.complex128))
# ['Day = ', 7]
# (tensor(-4.5492e-08+6.8552e-08j, dtype=torch.complex128), tensor(-1.0895e-07-6.6595e-08j, dtype=torch.complex128))
# ['Day = ', 8]
# (tensor(-5.8249e-08+1.3458e-07j, dtype=torch.complex128), tensor(-1.3516e-07+3.3424e-07j, dtype=torch.complex128))
# ['Day = ', 9]
# (tensor(2.2631e-08-1.3913e-07j, dtype=torch.complex128), tensor(3.8027e-08+1.4411e-07j, dtype=torch.complex128))
# ['Day = ', 10]
# (tensor(8.8114e-08-2.4083e-07j, dtype=torch.complex128), tensor(1.1029e-07+5.6305e-08j, dtype=torch.complex128))
# ['Day = ', 11]
# (tensor(-3.3072e-08-2.3954e-08j, dtype=torch.complex128), tensor(3.7869e-08+2.2501e-07j, dtype=torch.complex128))
# ['Day = ', 12]
# (tensor(-2.0565e-09-1.2379e-07j, dtype=torch.complex128), tensor(-1.5976e-08+2.3417e-07j, dtype=torch.complex128))
# ['Day = ', 13]
# (tensor(9.8290e-08+5.6517e-08j, dtype=torch.complex128), tensor(-3.0624e-08+1.7206e-07j, dtype=torch.complex128))
# ['Day = ', 14]
# (tensor(1.8663e-08-5.3286e-08j, dtype=torch.complex128), tensor(7.4178e-08+1.1573e-07j, dtype=torch.complex128))
# ['Day = ', 15]
# (tensor(-2.2856e-07+7.4043e-08j, dtype=torch.complex128), tensor(7.0971e-08-1.1205e-08j, dtype=torch.complex128))
# ['Day = ', 16]
# (tensor(-5.2828e-08-8.5708e-08j, dtype=torch.complex128), tensor(-4.6636e-08+4.1030e-08j, dtype=torch.complex128))
# ['Day = ', 17]
# (tensor(-2.0395e-07-2.5871e-08j, dtype=torch.complex128), tensor(4.2224e-08+1.8524e-07j, dtype=torch.complex128))
# ['Day = ', 18]
# (tensor(-2.0531e-07+1.7516e-07j, dtype=torch.complex128), tensor(-5.3029e-08+4.1959e-07j, dtype=torch.complex128))
# ['Day = ', 19]
# (tensor(-2.2528e-07+1.9653e-07j, dtype=torch.complex128), tensor(1.9288e-08+1.5591e-07j, dtype=torch.complex128))
# ['Day = ', 20]
# (tensor(-1.3414e-07+4.9940e-08j, dtype=torch.complex128), tensor(7.9763e-08+6.0063e-08j, dtype=torch.complex128))
# ['Day = ', 21]
# (tensor(-1.6095e-07-1.0571e-07j, dtype=torch.complex128), tensor(1.6855e-07+1.5047e-07j, dtype=torch.complex128))
# ['Day = ', 22]
# (tensor(-2.2691e-07+1.8473e-07j, dtype=torch.complex128), tensor(6.7579e-08+4.5684e-08j, dtype=torch.complex128))
# ['Day = ', 23]
# (tensor(-1.9346e-07+1.0298e-07j, dtype=torch.complex128), tensor(-8.7230e-08+1.8696e-07j, dtype=torch.complex128))
# ['Day = ', 24]
# (tensor(-1.3363e-07+8.3431e-08j, dtype=torch.complex128), tensor(-1.9481e-08+6.6927e-08j, dtype=torch.complex128))
# ['Day = ', 25]
# (tensor(-8.8728e-08-1.4912e-08j, dtype=torch.complex128), tensor(1.8065e-07-2.1663e-08j, dtype=torch.complex128))
# ['Day = ', 26]
# (tensor(-6.8599e-08+9.3597e-08j, dtype=torch.complex128), tensor(-1.7489e-07-5.1275e-08j, dtype=torch.complex128))
# ['Day = ', 27]
# (tensor(-4.2560e-07+2.0995e-07j, dtype=torch.complex128), tensor(-2.1401e-07+1.5708e-07j, dtype=torch.complex128))
# ['Day = ', 28]
# (tensor(-4.0661e-07+7.2754e-08j, dtype=torch.complex128), tensor(-1.7671e-07+1.6281e-07j, dtype=torch.complex128))
# ['Day = ', 29]
# (tensor(-3.6893e-07+1.4080e-07j, dtype=torch.complex128), tensor(-2.4630e-07+1.0424e-07j, dtype=torch.complex128))
# ['Day = ', 30]
# (tensor(-1.3629e-07+7.8168e-08j, dtype=torch.complex128), tensor(-8.2957e-08+2.6681e-07j, dtype=torch.complex128))
# ['Day = ', 31]
# (tensor(-1.2543e-07+1.5542e-07j, dtype=torch.complex128), tensor(8.9213e-08+3.6864e-07j, dtype=torch.complex128))
# ['Day = ', 32]
# (tensor(-2.0099e-07+3.7483e-09j, dtype=torch.complex128), tensor(-1.2870e-07+3.8386e-07j, dtype=torch.complex128))
# ['Day = ', 33]
# (tensor(-1.0580e-07+1.6872e-07j, dtype=torch.complex128), tensor(-4.1081e-08+3.3303e-07j, dtype=torch.complex128))
# ['Day = ', 34]
# (tensor(-5.2781e-08+9.5413e-09j, dtype=torch.complex128), tensor(2.3108e-08-1.7394e-07j, dtype=torch.complex128))
# ['Day = ', 35]
# (tensor(-1.1327e-07+4.7601e-08j, dtype=torch.complex128), tensor(9.1734e-08+2.3918e-07j, dtype=torch.complex128))
# ['Day = ', 36]
# (tensor(-1.2534e-07+2.2810e-07j, dtype=torch.complex128), tensor(2.2962e-07+3.8939e-08j, dtype=torch.complex128))
# ['Day = ', 37]
# (tensor(-2.7107e-07+2.8968e-07j, dtype=torch.complex128), tensor(2.4880e-07+2.5351e-07j, dtype=torch.complex128))
# ['Day = ', 38]
# (tensor(-2.1907e-07+3.5461e-07j, dtype=torch.complex128), tensor(-1.8673e-08+3.8328e-08j, dtype=torch.complex128))
# ['Day = ', 39]
# (tensor(-1.6122e-07+3.0130e-07j, dtype=torch.complex128), tensor(8.9619e-08-2.0613e-07j, dtype=torch.complex128))
# ['Day = ', 40]
# (tensor(-2.5193e-08+2.5455e-07j, dtype=torch.complex128), tensor(1.7794e-07+7.6866e-08j, dtype=torch.complex128))
# ['Day = ', 41]
# (tensor(-7.2525e-08+4.4604e-08j, dtype=torch.complex128), tensor(5.6079e-08+1.7454e-07j, dtype=torch.complex128))
# ['Day = ', 42]
# (tensor(5.3939e-08+4.7633e-08j, dtype=torch.complex128), tensor(1.3402e-07+1.2881e-07j, dtype=torch.complex128))
# ['Day = ', 43]
# (tensor(1.6045e-07+5.1851e-08j, dtype=torch.complex128), tensor(-1.9286e-08+1.3692e-07j, dtype=torch.complex128))
# ['Day = ', 44]
# (tensor(1.6251e-07+9.6179e-08j, dtype=torch.complex128), tensor(-9.2776e-09+2.0034e-07j, dtype=torch.complex128))
# ['Day = ', 45]
# (tensor(-1.6282e-07+1.9997e-07j, dtype=torch.complex128), tensor(-1.0167e-07+8.4157e-08j, dtype=torch.complex128))
# ['Day = ', 46]
# (tensor(-2.5962e-07+2.9841e-07j, dtype=torch.complex128), tensor(4.6819e-08+2.1322e-07j, dtype=torch.complex128))
# ['Day = ', 47]
# (tensor(-1.7071e-07+2.5477e-07j, dtype=torch.complex128), tensor(-3.4688e-08+1.6778e-07j, dtype=torch.complex128))
# ['Day = ', 48]
# (tensor(-8.9123e-08+1.4646e-07j, dtype=torch.complex128), tensor(-2.8320e-07+1.7832e-07j, dtype=torch.complex128))
# ['Day = ', 49]
# (tensor(-4.7094e-08+1.6407e-07j, dtype=torch.complex128), tensor(-2.2589e-08+1.0593e-07j, dtype=torch.complex128))
# ['Day = ', 50]
# (tensor(-5.8610e-08+1.9625e-07j, dtype=torch.complex128), tensor(3.1534e-08+8.6347e-08j, dtype=torch.complex128))
# ['Day = ', 51]
# (tensor(3.8549e-08+1.4303e-07j, dtype=torch.complex128), tensor(-3.2007e-08+1.6660e-07j, dtype=torch.complex128))
# ['Day = ', 52]
# (tensor(4.7453e-08-6.5916e-08j, dtype=torch.complex128), tensor(-1.3916e-07-2.5533e-08j, dtype=torch.complex128))
# ['Day = ', 53]
# (tensor(1.1147e-07+5.4706e-09j, dtype=torch.complex128), tensor(1.0274e-07+1.7631e-07j, dtype=torch.complex128))
# ['Day = ', 54]
# (tensor(-1.0343e-07+2.2568e-07j, dtype=torch.complex128), tensor(9.1221e-08-9.8591e-08j, dtype=torch.complex128))
# ['Day = ', 55]
# (tensor(-2.6816e-07+2.7951e-07j, dtype=torch.complex128), tensor(-1.1675e-07+9.7748e-08j, dtype=torch.complex128))
# ['Day = ', 56]
# (tensor(-7.0937e-08+2.1985e-07j, dtype=torch.complex128), tensor(1.4260e-07-8.4042e-08j, dtype=torch.complex128))
# ['Day = ', 57]
# (tensor(-1.6007e-07+2.3395e-07j, dtype=torch.complex128), tensor(7.6709e-09-1.5653e-07j, dtype=torch.complex128))
# ['Day = ', 58]
# (tensor(-1.8464e-07+3.4311e-07j, dtype=torch.complex128), tensor(-9.5393e-08+1.8248e-07j, dtype=torch.complex128))
# ['Day = ', 59]
# (tensor(-1.3577e-07+2.1702e-07j, dtype=torch.complex128), tensor(-3.1617e-07+1.4315e-07j, dtype=torch.complex128))
# ['Day = ', 60]
# (tensor(-1.1217e-07+6.1031e-08j, dtype=torch.complex128), tensor(-1.3063e-07+4.3289e-08j, dtype=torch.complex128))
# ['Day = ', 61]
# (tensor(-8.5013e-08+2.0366e-07j, dtype=torch.complex128), tensor(-2.1181e-07+3.1347e-07j, dtype=torch.complex128))
# ['Day = ', 62]
# (tensor(-1.9203e-09-1.2562e-08j, dtype=torch.complex128), tensor(-1.7488e-07-1.2122e-07j, dtype=torch.complex128))
# ['Day = ', 63]
# (tensor(-3.9033e-09-2.9274e-08j, dtype=torch.complex128), tensor(-5.4852e-07+2.1060e-07j, dtype=torch.complex128))
# ['Day = ', 64]
# (tensor(-8.9135e-08+1.6034e-07j, dtype=torch.complex128), tensor(-9.7558e-08-1.2360e-08j, dtype=torch.complex128))
# ['Day = ', 65]
# (tensor(-2.1361e-07+1.0274e-07j, dtype=torch.complex128), tensor(-9.1206e-09+1.1254e-07j, dtype=torch.complex128))
# ['Day = ', 66]
# (tensor(7.6206e-08+1.0976e-07j, dtype=torch.complex128), tensor(-4.1649e-08+2.3204e-08j, dtype=torch.complex128))
# ['Day = ', 67]
# (tensor(-6.8229e-08+8.5041e-08j, dtype=torch.complex128), tensor(6.5069e-08-8.9890e-08j, dtype=torch.complex128))
# ['Day = ', 68]
# (tensor(-2.0839e-07-5.3526e-08j, dtype=torch.complex128), tensor(-4.4626e-08+1.6621e-07j, dtype=torch.complex128))
# ['Day = ', 69]
# (tensor(-3.0370e-07+1.7473e-07j, dtype=torch.complex128), tensor(-7.1273e-08-1.8305e-07j, dtype=torch.complex128))
# ['Day = ', 70]
# (tensor(-3.3722e-07+1.8503e-07j, dtype=torch.complex128), tensor(-1.8847e-07+1.4094e-07j, dtype=torch.complex128))
# ['Day = ', 71]
# (tensor(-2.8428e-07+3.5368e-07j, dtype=torch.complex128), tensor(-2.4678e-07+2.8830e-08j, dtype=torch.complex128))
# ['Day = ', 72]
# (tensor(-2.2743e-07+3.8495e-07j, dtype=torch.complex128), tensor(-2.5868e-07+1.8810e-07j, dtype=torch.complex128))
# ['Day = ', 73]
# (tensor(-3.8023e-07+3.8772e-07j, dtype=torch.complex128), tensor(-2.1024e-07+3.1749e-07j, dtype=torch.complex128))
# ['Day = ', 74]
# (tensor(-1.5844e-07+1.9784e-07j, dtype=torch.complex128), tensor(-2.4018e-08+1.2979e-07j, dtype=torch.complex128))
# ['Day = ', 75]
# (tensor(4.7548e-08+3.7038e-07j, dtype=torch.complex128), tensor(-4.3742e-07+1.7138e-07j, dtype=torch.complex128))
# ['Day = ', 76]
# (tensor(-1.2185e-07+2.4522e-07j, dtype=torch.complex128), tensor(-1.1482e-07+2.5466e-07j, dtype=torch.complex128))
# ['Day = ', 77]
# (tensor(-2.2549e-08+1.1114e-07j, dtype=torch.complex128), tensor(-2.9387e-08+6.5991e-08j, dtype=torch.complex128))
# ['Day = ', 78]
# (tensor(-1.0564e-07+1.6659e-07j, dtype=torch.complex128), tensor(-1.3270e-07+1.8721e-07j, dtype=torch.complex128))
# ['Day = ', 79]
# (tensor(5.5842e-09+2.3915e-07j, dtype=torch.complex128), tensor(1.0455e-09+2.2613e-07j, dtype=torch.complex128))
# ['Day = ', 80]
# (tensor(-1.1369e-07+1.2175e-07j, dtype=torch.complex128), tensor(1.8459e-07+1.3803e-07j, dtype=torch.complex128))
# ['Day = ', 81]
# (tensor(4.8543e-08+8.2621e-08j, dtype=torch.complex128), tensor(4.7797e-09+4.2734e-08j, dtype=torch.complex128))
# ['Day = ', 82]
# (tensor(9.8041e-08+2.7083e-08j, dtype=torch.complex128), tensor(-2.9797e-09+1.9603e-07j, dtype=torch.complex128))
# ['Day = ', 83]
# (tensor(-4.9436e-08+1.3048e-07j, dtype=torch.complex128), tensor(-8.6574e-08-5.9081e-09j, dtype=torch.complex128))
# ['Day = ', 84]
# (tensor(1.1762e-08-3.7278e-09j, dtype=torch.complex128), tensor(1.7255e-07+5.4991e-08j, dtype=torch.complex128))
# ['Day = ', 85]
# (tensor(-3.4351e-08+1.1209e-07j, dtype=torch.complex128), tensor(-1.3070e-08+3.2935e-08j, dtype=torch.complex128))
# ['Day = ', 86]
# (tensor(-3.7077e-08-2.7336e-08j, dtype=torch.complex128), tensor(-2.9932e-07+3.4404e-08j, dtype=torch.complex128))
# ['Day = ', 87]
# (tensor(-2.8628e-11+4.6414e-08j, dtype=torch.complex128), tensor(-5.0887e-08-3.5346e-07j, dtype=torch.complex128))
# ['Day = ', 88]
# (tensor(-4.1144e-08+2.2696e-07j, dtype=torch.complex128), tensor(-6.1183e-08+1.3755e-07j, dtype=torch.complex128))
# ['Day = ', 89]
# (tensor(7.2564e-09-1.0340e-07j, dtype=torch.complex128), tensor(-1.5562e-07+5.0327e-08j, dtype=torch.complex128))
# ['Day = ', 90]
# (tensor(-9.2509e-08+2.6003e-07j, dtype=torch.complex128), tensor(-1.0535e-07-1.5835e-08j, dtype=torch.complex128))
# ['Day = ', 91]
# (tensor(-2.2164e-07+2.2908e-07j, dtype=torch.complex128), tensor(1.5997e-08-1.8738e-07j, dtype=torch.complex128))
# ['Day = ', 92]
# (tensor(3.3341e-08+1.3955e-07j, dtype=torch.complex128), tensor(-1.6349e-07-2.4981e-08j, dtype=torch.complex128))
# ['Day = ', 93]
# (tensor(-2.3361e-07+1.4494e-07j, dtype=torch.complex128), tensor(-1.7015e-07-1.1639e-08j, dtype=torch.complex128))
# ['Day = ', 94]
# (tensor(-1.8910e-07+6.0628e-08j, dtype=torch.complex128), tensor(-2.8757e-07+6.8852e-08j, dtype=torch.complex128))
# ['Day = ', 95]
# (tensor(2.0255e-08-9.8398e-08j, dtype=torch.complex128), tensor(-2.8937e-07+4.6864e-08j, dtype=torch.complex128))
# ['Day = ', 96]
# (tensor(-2.8215e-08-8.5148e-09j, dtype=torch.complex128), tensor(-1.2697e-07+2.0573e-07j, dtype=torch.complex128))
# ['Day = ', 97]
# (tensor(-4.3331e-08+1.1659e-07j, dtype=torch.complex128), tensor(-4.2119e-08+2.5771e-07j, dtype=torch.complex128))
# ['Day = ', 98]
# (tensor(4.0743e-09-7.2896e-08j, dtype=torch.complex128), tensor(-2.0460e-07+1.8415e-08j, dtype=torch.complex128))
# ['Day = ', 99]
# (tensor(1.1185e-07-9.5041e-08j, dtype=torch.complex128), tensor(7.5390e-08-1.6863e-09j, dtype=torch.complex128))
# ['Day = ', 100]
# (tensor(-1.2295e-08+7.1622e-08j, dtype=torch.complex128), tensor(-8.5404e-08+1.5514e-07j, dtype=torch.complex128))
# ['Day = ', 101]
# (tensor(-5.1201e-08+7.8742e-08j, dtype=torch.complex128), tensor(-6.8758e-08-4.2376e-09j, dtype=torch.complex128))
# ['Day = ', 102]
# (tensor(-4.8169e-08+1.0713e-07j, dtype=torch.complex128), tensor(-2.4767e-08+6.4002e-08j, dtype=torch.complex128))
# ['Day = ', 103]
# (tensor(1.8851e-08-8.5504e-08j, dtype=torch.complex128), tensor(-3.6385e-07+1.4617e-07j, dtype=torch.complex128))
# ['Day = ', 104]
# (tensor(4.2059e-08-1.2534e-07j, dtype=torch.complex128), tensor(2.3649e-08+2.3740e-07j, dtype=torch.complex128))
# ['Day = ', 105]
# (tensor(-2.1320e-08+7.2234e-08j, dtype=torch.complex128), tensor(-3.6539e-08+1.1099e-07j, dtype=torch.complex128))
# ['Day = ', 106]
# (tensor(3.7449e-08+8.0379e-08j, dtype=torch.complex128), tensor(-1.3695e-07+2.5266e-07j, dtype=torch.complex128))
# ['Day = ', 107]
# (tensor(-1.2534e-09-4.7902e-09j, dtype=torch.complex128), tensor(-3.1564e-07-3.5674e-08j, dtype=torch.complex128))
# ['Day = ', 108]
# (tensor(-8.7178e-08+1.9477e-07j, dtype=torch.complex128), tensor(-2.7332e-07-4.9173e-08j, dtype=torch.complex128))
# ['Day = ', 109]
# (tensor(-7.0733e-08+1.9276e-07j, dtype=torch.complex128), tensor(-1.8130e-07+2.2383e-07j, dtype=torch.complex128))
# ['Day = ', 110]
# (tensor(-5.1368e-08+1.3439e-07j, dtype=torch.complex128), tensor(-3.3126e-07+3.3470e-07j, dtype=torch.complex128))
# ['Day = ', 111]
# (tensor(6.4896e-09+1.6632e-08j, dtype=torch.complex128), tensor(-1.1847e-08+1.6680e-08j, dtype=torch.complex128))
# ['Day = ', 112]
# (tensor(5.6477e-09+6.0666e-08j, dtype=torch.complex128), tensor(-4.9796e-08-2.5466e-07j, dtype=torch.complex128))
# ['Day = ', 113]
# (tensor(-7.2799e-08-9.7154e-08j, dtype=torch.complex128), tensor(-6.0818e-08+1.0224e-07j, dtype=torch.complex128))
# ['Day = ', 114]
# (tensor(-2.9928e-07-1.6677e-07j, dtype=torch.complex128), tensor(-1.9052e-08-1.7127e-07j, dtype=torch.complex128))
# ['Day = ', 115]
# (tensor(-2.7058e-07-1.0161e-07j, dtype=torch.complex128), tensor(-1.9853e-07+1.3755e-07j, dtype=torch.complex128))
# ['Day = ', 116]
# (tensor(-1.2674e-07-1.0565e-07j, dtype=torch.complex128), tensor(-1.1005e-07-1.5488e-07j, dtype=torch.complex128))
# ['Day = ', 117]
# (tensor(-3.4014e-08-1.3085e-07j, dtype=torch.complex128), tensor(9.3893e-08+7.8155e-08j, dtype=torch.complex128))
# ['Day = ', 118]
# (tensor(-1.1393e-07-2.1796e-07j, dtype=torch.complex128), tensor(-2.0230e-07-1.2655e-07j, dtype=torch.complex128))
# ['Day = ', 119]
# (tensor(-1.0117e-08-3.9086e-07j, dtype=torch.complex128), tensor(-3.3937e-07+1.4906e-07j, dtype=torch.complex128))
# ['Day = ', 120]
# (tensor(1.1677e-07-2.7353e-07j, dtype=torch.complex128), tensor(-3.2686e-08+5.1155e-08j, dtype=torch.complex128))
# ['Day = ', 121]
# (tensor(-1.0210e-08-2.8884e-07j, dtype=torch.complex128), tensor(-1.4408e-07-2.1301e-08j, dtype=torch.complex128))
# ['Day = ', 122]
# (tensor(4.0401e-08-1.4894e-07j, dtype=torch.complex128), tensor(-5.3201e-08+3.7769e-07j, dtype=torch.complex128))
# ['Day = ', 123]
# (tensor(9.2100e-08+9.9649e-08j, dtype=torch.complex128), tensor(3.1888e-08+1.4440e-07j, dtype=torch.complex128))
# ['Day = ', 124]
# (tensor(8.4773e-08+3.8306e-07j, dtype=torch.complex128), tensor(-7.0326e-08+1.3450e-07j, dtype=torch.complex128))
# ['Day = ', 125]
# (tensor(-6.6249e-08+4.3166e-07j, dtype=torch.complex128), tensor(-1.7642e-07+2.5315e-07j, dtype=torch.complex128))
# ['Day = ', 126]
# (tensor(1.2547e-07+3.0917e-07j, dtype=torch.complex128), tensor(-1.0906e-07+2.3869e-07j, dtype=torch.complex128))
# ['Day = ', 127]
# (tensor(-3.9163e-09+2.6200e-07j, dtype=torch.complex128), tensor(9.4827e-08+3.9375e-07j, dtype=torch.complex128))
# ['Day = ', 128]
# (tensor(6.8443e-08+3.5206e-07j, dtype=torch.complex128), tensor(1.2388e-07+1.4735e-07j, dtype=torch.complex128))
# ['Day = ', 129]
# (tensor(-9.7961e-08+2.6825e-07j, dtype=torch.complex128), tensor(7.9594e-08+2.2899e-07j, dtype=torch.complex128))
# ['Day = ', 130]
# (tensor(-7.8265e-08+3.5330e-07j, dtype=torch.complex128), tensor(2.0005e-07+8.0862e-08j, dtype=torch.complex128))
# ['Day = ', 131]
# (tensor(-1.2386e-08+3.0846e-07j, dtype=torch.complex128), tensor(-1.9588e-07-7.0385e-08j, dtype=torch.complex128))
# ['Day = ', 132]
# (tensor(5.2373e-09+2.0654e-07j, dtype=torch.complex128), tensor(-2.0670e-07+1.3484e-07j, dtype=torch.complex128))
# ['Day = ', 133]
# (tensor(2.2245e-08-1.2181e-08j, dtype=torch.complex128), tensor(2.8832e-07+2.3169e-07j, dtype=torch.complex128))
# ['Day = ', 134]
# (tensor(1.7517e-07+6.4793e-08j, dtype=torch.complex128), tensor(-7.8530e-08+3.7036e-07j, dtype=torch.complex128))
# ['Day = ', 135]
# (tensor(7.9332e-08-2.5580e-08j, dtype=torch.complex128), tensor(1.0492e-07-6.3427e-08j, dtype=torch.complex128))
# ['Day = ', 136]
# (tensor(-1.4696e-07-1.2668e-07j, dtype=torch.complex128), tensor(-1.2748e-07+5.2850e-08j, dtype=torch.complex128))
# ['Day = ', 137]
# (tensor(6.4900e-08-7.7107e-08j, dtype=torch.complex128), tensor(-1.9341e-07+8.7926e-08j, dtype=torch.complex128))
# ['Day = ', 138]
# (tensor(-4.1240e-08-1.8194e-07j, dtype=torch.complex128), tensor(-8.2163e-08+7.4659e-08j, dtype=torch.complex128))
# ['Day = ', 139]
# (tensor(-9.3579e-08-3.0685e-07j, dtype=torch.complex128), tensor(5.3262e-08+1.3193e-07j, dtype=torch.complex128))
# ['Day = ', 140]
# (tensor(8.0254e-08-1.8643e-07j, dtype=torch.complex128), tensor(-9.2561e-08-1.1609e-07j, dtype=torch.complex128))
# ['Day = ', 141]
# (tensor(-2.9084e-08-3.3591e-08j, dtype=torch.complex128), tensor(2.9437e-08-1.1204e-08j, dtype=torch.complex128))
# ['Day = ', 142]
# (tensor(-9.1790e-08+1.3428e-07j, dtype=torch.complex128), tensor(-2.2130e-07-1.2543e-07j, dtype=torch.complex128))
# ['Day = ', 143]
# (tensor(-2.4774e-08-6.1009e-08j, dtype=torch.complex128), tensor(-7.2267e-08+7.5565e-08j, dtype=torch.complex128))
# ['Day = ', 144]
# (tensor(1.7545e-08+2.3119e-08j, dtype=torch.complex128), tensor(-1.2708e-07+8.4236e-08j, dtype=torch.complex128))
# ['Day = ', 145]
# (tensor(-2.0217e-07+1.3730e-07j, dtype=torch.complex128), tensor(-2.0390e-07-1.0814e-08j, dtype=torch.complex128))
# ['Day = ', 146]
# (tensor(5.7341e-08+1.8434e-07j, dtype=torch.complex128), tensor(-3.6496e-07+1.1811e-07j, dtype=torch.complex128))
# ['Day = ', 147]
# (tensor(-3.5492e-08+1.0693e-07j, dtype=torch.complex128), tensor(-1.9072e-07+9.1409e-08j, dtype=torch.complex128))
# ['Day = ', 148]
# (tensor(-1.1226e-08-6.8255e-09j, dtype=torch.complex128), tensor(-9.8733e-08+2.3701e-07j, dtype=torch.complex128))
# ['Day = ', 149]
# (tensor(-2.2645e-07-1.3787e-07j, dtype=torch.complex128), tensor(-1.4746e-07+2.2799e-07j, dtype=torch.complex128))
# ['Day = ', 150]
# (tensor(-8.1969e-08+8.4805e-08j, dtype=torch.complex128), tensor(-1.0526e-07+1.5022e-07j, dtype=torch.complex128))
# ['Day = ', 151]
# (tensor(8.0505e-08+1.0570e-07j, dtype=torch.complex128), tensor(-1.8076e-07+8.9710e-08j, dtype=torch.complex128))
# ['Day = ', 152]
# (tensor(-1.8323e-08+7.1965e-08j, dtype=torch.complex128), tensor(-2.1044e-07-2.6805e-08j, dtype=torch.complex128))
# ['Day = ', 153]
# (tensor(5.9138e-09+1.5395e-07j, dtype=torch.complex128), tensor(-1.9663e-07+1.0793e-07j, dtype=torch.complex128))
# ['Day = ', 154]
# (tensor(1.0537e-07-5.9946e-08j, dtype=torch.complex128), tensor(-2.7143e-08+2.4343e-07j, dtype=torch.complex128))
# ['Day = ', 155]
# (tensor(7.8654e-08+5.7570e-08j, dtype=torch.complex128), tensor(-3.3560e-07+2.0388e-07j, dtype=torch.complex128))
# ['Day = ', 156]
# (tensor(3.5469e-08+2.8799e-08j, dtype=torch.complex128), tensor(1.0903e-07+1.2310e-07j, dtype=torch.complex128))
# ['Day = ', 157]
# (tensor(-1.5521e-07+5.1481e-08j, dtype=torch.complex128), tensor(-1.8902e-07-7.9738e-08j, dtype=torch.complex128))
# ['Day = ', 158]
# (tensor(1.8957e-09+2.5882e-07j, dtype=torch.complex128), tensor(-6.5316e-08+2.0932e-07j, dtype=torch.complex128))
# ['Day = ', 159]
# (tensor(7.3133e-09+2.7341e-07j, dtype=torch.complex128), tensor(-6.3597e-08+2.6210e-07j, dtype=torch.complex128))
# ['Day = ', 160]
# (tensor(-9.0413e-08+3.0904e-07j, dtype=torch.complex128), tensor(-2.7269e-07+1.1421e-07j, dtype=torch.complex128))
# ['Day = ', 161]
# (tensor(-8.2167e-08+9.7276e-08j, dtype=torch.complex128), tensor(-2.3345e-07+1.6022e-07j, dtype=torch.complex128))
# ['Day = ', 162]
# (tensor(8.5474e-09-2.0962e-07j, dtype=torch.complex128), tensor(-1.8777e-07-2.0290e-08j, dtype=torch.complex128))
# ['Day = ', 163]
# (tensor(-3.5946e-07+3.0176e-07j, dtype=torch.complex128), tensor(-1.2393e-07+3.0440e-07j, dtype=torch.complex128))
# ['Day = ', 164]
# (tensor(-3.3725e-07+1.4348e-07j, dtype=torch.complex128), tensor(-3.1605e-07+2.0113e-07j, dtype=torch.complex128))
# ['Day = ', 165]
# (tensor(2.7899e-09+1.1250e-07j, dtype=torch.complex128), tensor(-3.0451e-07+1.5062e-07j, dtype=torch.complex128))
# ['Day = ', 166]
# (tensor(-5.7564e-08+2.1525e-07j, dtype=torch.complex128), tensor(-2.6452e-07+1.2268e-07j, dtype=torch.complex128))
# ['Day = ', 167]
# (tensor(-2.8658e-07+1.4978e-07j, dtype=torch.complex128), tensor(-9.2420e-08+1.3872e-07j, dtype=torch.complex128))
# ['Day = ', 168]
# (tensor(-1.8863e-08+2.6532e-07j, dtype=torch.complex128), tensor(8.8986e-09+1.3312e-07j, dtype=torch.complex128))
# ['Day = ', 169]
# (tensor(2.2050e-08+1.0997e-07j, dtype=torch.complex128), tensor(1.3606e-07+3.0917e-07j, dtype=torch.complex128))
# ['Day = ', 170]
# (tensor(-1.3082e-07+2.0225e-07j, dtype=torch.complex128), tensor(-1.3259e-08+1.6672e-07j, dtype=torch.complex128))
# ['Day = ', 171]
# (tensor(-1.4185e-08+4.8079e-07j, dtype=torch.complex128), tensor(-3.0793e-07+1.4787e-07j, dtype=torch.complex128))
# ['Day = ', 172]
# (tensor(2.3827e-07+3.0410e-07j, dtype=torch.complex128), tensor(-3.0326e-08+2.9963e-07j, dtype=torch.complex128))
# ['Day = ', 173]
# (tensor(2.2266e-07+2.4545e-07j, dtype=torch.complex128), tensor(-2.2867e-08+9.7943e-08j, dtype=torch.complex128))
# ['Day = ', 174]
# (tensor(-9.6431e-09+4.8111e-07j, dtype=torch.complex128), tensor(1.5102e-07+2.0740e-07j, dtype=torch.complex128))
# ['Day = ', 175]
# (tensor(-8.8369e-09+4.4749e-07j, dtype=torch.complex128), tensor(1.5977e-07+2.5464e-07j, dtype=torch.complex128))
# ['Day = ', 176]
# (tensor(7.2041e-08+3.3854e-07j, dtype=torch.complex128), tensor(8.3988e-08+2.2469e-07j, dtype=torch.complex128))
# ['Day = ', 177]
# (tensor(-1.9949e-07+7.0896e-07j, dtype=torch.complex128), tensor(1.1442e-07+2.5499e-07j, dtype=torch.complex128))
# ['Day = ', 178]
# (tensor(-6.6006e-08+5.4654e-07j, dtype=torch.complex128), tensor(1.9977e-07+5.9279e-08j, dtype=torch.complex128))
# ['Day = ', 179]
# (tensor(-4.0660e-08+3.6239e-07j, dtype=torch.complex128), tensor(2.7017e-07+1.5951e-07j, dtype=torch.complex128))
# ['Day = ', 180]
# (tensor(-1.4876e-07+2.0411e-07j, dtype=torch.complex128), tensor(1.0287e-07+1.3127e-07j, dtype=torch.complex128))
# ['Day = ', 181]
# (tensor(-1.6605e-07+1.7825e-07j, dtype=torch.complex128), tensor(7.0466e-08+7.9165e-08j, dtype=torch.complex128))
# ['Day = ', 182]
# (tensor(-2.2356e-07+4.1335e-07j, dtype=torch.complex128), tensor(-3.1651e-08-3.0099e-08j, dtype=torch.complex128))
# ['Day = ', 183]
# (tensor(-2.8735e-07+1.6463e-07j, dtype=torch.complex128), tensor(-5.4271e-09+7.0148e-10j, dtype=torch.complex128))
# ['Day = ', 184]
# (tensor(-3.7171e-07+4.2113e-07j, dtype=torch.complex128), tensor(-1.0400e-07+9.5528e-08j, dtype=torch.complex128))
# ['Day = ', 185]
# (tensor(-8.0956e-08+4.3333e-07j, dtype=torch.complex128), tensor(9.2002e-08+1.3593e-07j, dtype=torch.complex128))
# ['Day = ', 186]
# (tensor(2.7405e-07+2.8886e-07j, dtype=torch.complex128), tensor(-1.8043e-07+1.0540e-07j, dtype=torch.complex128))
# ['Day = ', 187]
# (tensor(1.5287e-07+3.3027e-07j, dtype=torch.complex128), tensor(-7.7024e-09+2.1760e-07j, dtype=torch.complex128))
# ['Day = ', 188]
# (tensor(-2.6611e-07+2.4369e-07j, dtype=torch.complex128), tensor(-7.0550e-08+5.2005e-08j, dtype=torch.complex128))
# ['Day = ', 189]
# (tensor(-1.9978e-07+2.9505e-07j, dtype=torch.complex128), tensor(-4.0320e-07+2.7830e-07j, dtype=torch.complex128))
# ['Day = ', 190]
# (tensor(-3.5452e-08+4.8998e-07j, dtype=torch.complex128), tensor(-1.5687e-07+1.5548e-07j, dtype=torch.complex128))
# ['Day = ', 191]
# (tensor(-1.9425e-07+1.8257e-07j, dtype=torch.complex128), tensor(-2.6391e-07+2.1503e-07j, dtype=torch.complex128))
# ['Day = ', 192]
# (tensor(-2.0409e-07+3.6850e-07j, dtype=torch.complex128), tensor(-3.1291e-08+3.4133e-07j, dtype=torch.complex128))
# ['Day = ', 193]
# (tensor(1.0237e-10+4.9703e-07j, dtype=torch.complex128), tensor(1.0151e-07+4.1870e-07j, dtype=torch.complex128))
# ['Day = ', 194]
# (tensor(-3.3243e-07+3.0263e-07j, dtype=torch.complex128), tensor(3.1136e-08+9.5331e-09j, dtype=torch.complex128))
# ['Day = ', 195]
# (tensor(-9.4067e-08+1.9682e-07j, dtype=torch.complex128), tensor(6.1150e-08+1.3418e-07j, dtype=torch.complex128))
# ['Day = ', 196]
# (tensor(-1.1063e-07+7.3683e-08j, dtype=torch.complex128), tensor(-4.9254e-07+1.5325e-07j, dtype=torch.complex128))
# ['Day = ', 197]
# (tensor(-1.9477e-07+1.4629e-07j, dtype=torch.complex128), tensor(1.5754e-07+4.4587e-07j, dtype=torch.complex128))
# ['Day = ', 198]
# (tensor(-3.6945e-07+6.2348e-08j, dtype=torch.complex128), tensor(1.7610e-07+2.4122e-07j, dtype=torch.complex128))
# ['Day = ', 199]
# (tensor(-4.0655e-07+2.5912e-07j, dtype=torch.complex128), tensor(-8.4906e-08+1.4856e-07j, dtype=torch.complex128))
# ['Day = ', 200]
# (tensor(-6.4500e-08+4.7344e-07j, dtype=torch.complex128), tensor(-1.8612e-07+5.7845e-08j, dtype=torch.complex128))
# ['Day = ', 201]
# (tensor(-7.9404e-08+3.0500e-07j, dtype=torch.complex128), tensor(-2.9820e-08+4.6932e-07j, dtype=torch.complex128))
# ['Day = ', 202]
# (tensor(-2.0986e-07+3.6466e-07j, dtype=torch.complex128), tensor(-5.5419e-08+6.8314e-08j, dtype=torch.complex128))
# ['Day = ', 203]
# (tensor(-3.2318e-07+6.6524e-07j, dtype=torch.complex128), tensor(-1.3509e-08+3.3396e-07j, dtype=torch.complex128))
# ['Day = ', 204]
# (tensor(-3.5931e-07+5.2673e-07j, dtype=torch.complex128), tensor(1.0389e-08+2.0296e-08j, dtype=torch.complex128))
# ['Day = ', 205]
# (tensor(-3.2086e-07+6.4138e-07j, dtype=torch.complex128), tensor(-5.3964e-08+1.9727e-07j, dtype=torch.complex128))
# ['Day = ', 206]
# (tensor(-2.6920e-07+3.4389e-07j, dtype=torch.complex128), tensor(1.9598e-09+3.5518e-07j, dtype=torch.complex128))
# ['Day = ', 207]
# (tensor(-1.7647e-07+4.8977e-07j, dtype=torch.complex128), tensor(-1.0866e-07+6.3584e-08j, dtype=torch.complex128))
# ['Day = ', 208]
# (tensor(-3.3350e-08+3.9934e-07j, dtype=torch.complex128), tensor(3.3060e-07-8.2896e-08j, dtype=torch.complex128))
# ['Day = ', 209]
# (tensor(-4.3710e-07+5.5632e-07j, dtype=torch.complex128), tensor(-1.0571e-07-3.0907e-08j, dtype=torch.complex128))
# ['Day = ', 210]
# (tensor(-4.1248e-07+5.3711e-07j, dtype=torch.complex128), tensor(-7.2957e-08+3.2861e-07j, dtype=torch.complex128))
# ['Day = ', 211]
# (tensor(-2.0156e-07+3.1098e-07j, dtype=torch.complex128), tensor(-2.8219e-07-2.4907e-08j, dtype=torch.complex128))
# ['Day = ', 212]
# (tensor(-1.5288e-07+1.3453e-07j, dtype=torch.complex128), tensor(-5.1525e-08+6.6141e-08j, dtype=torch.complex128))
# ['Day = ', 213]
# (tensor(-1.5517e-07+3.4857e-08j, dtype=torch.complex128), tensor(-3.9284e-08+2.4720e-07j, dtype=torch.complex128))
# ['Day = ', 214]
# (tensor(-1.6980e-07+3.1715e-08j, dtype=torch.complex128), tensor(1.3097e-07+1.5603e-07j, dtype=torch.complex128))
# ['Day = ', 215]
# (tensor(-1.4816e-07-1.7036e-07j, dtype=torch.complex128), tensor(-7.1694e-09+1.6101e-07j, dtype=torch.complex128))
# ['Day = ', 216]
# (tensor(-5.0890e-08-1.2373e-07j, dtype=torch.complex128), tensor(2.6608e-08-2.8668e-08j, dtype=torch.complex128))
# ['Day = ', 217]
# (tensor(-2.0040e-07-7.3878e-08j, dtype=torch.complex128), tensor(-1.5359e-07-8.0840e-08j, dtype=torch.complex128))
# ['Day = ', 218]
# (tensor(-7.9410e-08+5.7586e-08j, dtype=torch.complex128), tensor(2.8723e-07+2.9612e-09j, dtype=torch.complex128))
# ['Day = ', 219]
# (tensor(-2.9183e-07+1.8091e-07j, dtype=torch.complex128), tensor(-2.0932e-07-5.9410e-08j, dtype=torch.complex128))
# ['Day = ', 220]
# (tensor(-1.5748e-07+2.3134e-07j, dtype=torch.complex128), tensor(-3.1754e-07+1.7408e-07j, dtype=torch.complex128))
# ['Day = ', 221]
# (tensor(-2.0448e-08-3.5849e-09j, dtype=torch.complex128), tensor(-1.8103e-07+1.5987e-07j, dtype=torch.complex128))
# ['Day = ', 222]
# (tensor(-5.7483e-08+1.8595e-07j, dtype=torch.complex128), tensor(-1.5418e-07-2.2714e-07j, dtype=torch.complex128))
# ['Day = ', 223]
# (tensor(-1.7668e-07+9.1191e-08j, dtype=torch.complex128), tensor(-2.2715e-07-1.3380e-07j, dtype=torch.complex128))
# ['Day = ', 224]
# (tensor(-2.8748e-07-1.5996e-08j, dtype=torch.complex128), tensor(-5.2436e-08+2.4407e-07j, dtype=torch.complex128))
# ['Day = ', 225]
# (tensor(-1.7474e-07+1.1257e-07j, dtype=torch.complex128), tensor(-1.3841e-07-1.3617e-08j, dtype=torch.complex128))
# ['Day = ', 226]
# (tensor(-1.1327e-07+1.7243e-07j, dtype=torch.complex128), tensor(-3.3112e-08-6.2113e-09j, dtype=torch.complex128))
# ['Day = ', 227]
# (tensor(-2.0273e-07+1.2007e-07j, dtype=torch.complex128), tensor(-7.9138e-08+8.1017e-09j, dtype=torch.complex128))
# ['Day = ', 228]
# (tensor(-1.2366e-07+8.2109e-08j, dtype=torch.complex128), tensor(-3.3405e-07+1.8417e-07j, dtype=torch.complex128))
# ['Day = ', 229]
# (tensor(-2.9672e-07-3.4037e-08j, dtype=torch.complex128), tensor(-3.0379e-07+2.5338e-08j, dtype=torch.complex128))
# ['Day = ', 230]
# (tensor(-1.7962e-07+1.6384e-07j, dtype=torch.complex128), tensor(-2.8144e-07+3.2601e-08j, dtype=torch.complex128))
# ['Day = ', 231]
# (tensor(-1.6983e-07+3.1807e-07j, dtype=torch.complex128), tensor(-3.9755e-07-1.5914e-08j, dtype=torch.complex128))
# ['Day = ', 232]
# (tensor(-1.2760e-07+1.5394e-07j, dtype=torch.complex128), tensor(-1.1898e-07+7.4328e-08j, dtype=torch.complex128))
# ['Day = ', 233]
# (tensor(-8.9870e-08+1.0389e-07j, dtype=torch.complex128), tensor(7.4160e-08+4.8157e-08j, dtype=torch.complex128))
# ['Day = ', 234]
# (tensor(-2.7015e-07+2.4026e-07j, dtype=torch.complex128), tensor(-3.9973e-07+1.4476e-07j, dtype=torch.complex128))
# ['Day = ', 235]
# (tensor(-1.0773e-07+7.3689e-08j, dtype=torch.complex128), tensor(-1.8906e-07+1.4303e-07j, dtype=torch.complex128))
# ['Day = ', 236]
# (tensor(-1.9692e-07-4.9005e-09j, dtype=torch.complex128), tensor(-8.8928e-08+5.1989e-08j, dtype=torch.complex128))
# ['Day = ', 237]
# (tensor(-2.2547e-07-1.3602e-07j, dtype=torch.complex128), tensor(-2.4255e-07+1.8290e-07j, dtype=torch.complex128))
# ['Day = ', 238]
# (tensor(-1.3397e-07-7.9991e-08j, dtype=torch.complex128), tensor(-7.5451e-08+2.6803e-07j, dtype=torch.complex128))
# ['Day = ', 239]
# (tensor(-1.5110e-07-1.8582e-07j, dtype=torch.complex128), tensor(-1.1666e-07+3.5615e-07j, dtype=torch.complex128))
# ['Day = ', 240]
# (tensor(-7.4292e-08-1.3702e-07j, dtype=torch.complex128), tensor(-1.6467e-07+8.2753e-08j, dtype=torch.complex128))
# ['Day = ', 241]
# (tensor(-1.2453e-07-8.5778e-08j, dtype=torch.complex128), tensor(-2.7402e-07+7.3067e-08j, dtype=torch.complex128))
# ['Day = ', 242]
# (tensor(-1.2313e-07-8.5634e-08j, dtype=torch.complex128), tensor(-9.1900e-08-1.0861e-07j, dtype=torch.complex128))
# ['Day = ', 243]
# (tensor(-2.6838e-07+2.1791e-07j, dtype=torch.complex128), tensor(-1.3889e-07-3.0542e-08j, dtype=torch.complex128))
# ['Day = ', 244]
# (tensor(-3.5381e-07+5.4340e-07j, dtype=torch.complex128), tensor(-2.1542e-07-3.4762e-08j, dtype=torch.complex128))
# ['Day = ', 245]
# (tensor(-2.2708e-07+5.1918e-07j, dtype=torch.complex128), tensor(-4.0573e-08+1.7529e-08j, dtype=torch.complex128))
# ['Day = ', 246]
# (tensor(-1.3637e-07+3.8754e-07j, dtype=torch.complex128), tensor(2.0369e-08+5.1086e-08j, dtype=torch.complex128))
# ['Day = ', 247]
# (tensor(-1.4883e-07+3.5711e-07j, dtype=torch.complex128), tensor(2.3358e-08+7.0841e-08j, dtype=torch.complex128))
# ['Day = ', 248]
# (tensor(-1.5070e-07+2.1872e-07j, dtype=torch.complex128), tensor(1.0578e-07+1.8090e-07j, dtype=torch.complex128))
# ['Day = ', 249]
# (tensor(-7.1645e-08+2.0456e-07j, dtype=torch.complex128), tensor(1.0578e-07+8.7619e-08j, dtype=torch.complex128))
# ['Day = ', 250]
# (tensor(-1.1770e-07+1.0438e-07j, dtype=torch.complex128), tensor(1.4894e-07+4.3663e-08j, dtype=torch.complex128))
# ['Day = ', 251]
# (tensor(-1.8844e-07+2.2582e-08j, dtype=torch.complex128), tensor(-5.7687e-08+1.2697e-07j, dtype=torch.complex128))
# ['Day = ', 252]
# (tensor(-2.2471e-07-1.2080e-09j, dtype=torch.complex128), tensor(-2.4617e-07-3.1219e-08j, dtype=torch.complex128))
# ['Day = ', 253]
# (tensor(-3.1757e-07+1.0719e-07j, dtype=torch.complex128), tensor(-3.4472e-08+1.2497e-07j, dtype=torch.complex128))
# ['Day = ', 254]
# (tensor(-1.3056e-07+2.1177e-07j, dtype=torch.complex128), tensor(-1.4701e-07+1.3916e-07j, dtype=torch.complex128))
# ['Day = ', 255]
# (tensor(-6.6226e-08+1.0345e-07j, dtype=torch.complex128), tensor(-4.4873e-08+1.6329e-07j, dtype=torch.complex128))
# ['Day = ', 256]
# (tensor(-5.0548e-08-7.7600e-08j, dtype=torch.complex128), tensor(2.9810e-08+8.4076e-08j, dtype=torch.complex128))
# ['Day = ', 257]
# (tensor(-5.9411e-08-6.0160e-08j, dtype=torch.complex128), tensor(-5.0213e-08+3.2529e-08j, dtype=torch.complex128))
# ['Day = ', 258]
# (tensor(-9.4305e-08+8.6048e-08j, dtype=torch.complex128), tensor(6.9668e-08-1.0607e-07j, dtype=torch.complex128))
# ['Day = ', 259]
# (tensor(-7.3117e-08+5.5456e-08j, dtype=torch.complex128), tensor(1.9325e-08-7.0285e-08j, dtype=torch.complex128))
# ['Day = ', 260]
# (tensor(-3.4739e-08+1.6126e-07j, dtype=torch.complex128), tensor(-1.9587e-07+6.7822e-08j, dtype=torch.complex128))
# ['Day = ', 261]
# (tensor(-1.0969e-07-3.4309e-09j, dtype=torch.complex128), tensor(-1.0141e-07+4.1262e-09j, dtype=torch.complex128))
# ['Day = ', 262]
# (tensor(-2.0418e-08+4.4240e-08j, dtype=torch.complex128), tensor(-1.0306e-07+9.9568e-08j, dtype=torch.complex128))
# ['Day = ', 263]
# (tensor(8.7510e-08+9.7315e-08j, dtype=torch.complex128), tensor(2.1590e-07+5.1353e-08j, dtype=torch.complex128))
# ['Day = ', 264]
# (tensor(-4.8059e-08+1.6850e-08j, dtype=torch.complex128), tensor(4.8649e-08-1.6674e-08j, dtype=torch.complex128))
# ['Day = ', 265]
# (tensor(-9.0262e-08+1.2400e-07j, dtype=torch.complex128), tensor(-1.0179e-07-2.6779e-07j, dtype=torch.complex128))
# ['Day = ', 266]
# (tensor(-2.9205e-07+3.6188e-07j, dtype=torch.complex128), tensor(-5.5442e-08-1.0096e-07j, dtype=torch.complex128))
# ['Day = ', 267]
# (tensor(-2.0758e-07+2.8249e-07j, dtype=torch.complex128), tensor(4.9563e-08+9.5667e-08j, dtype=torch.complex128))
# ['Day = ', 268]
# (tensor(-2.7642e-07+1.1897e-07j, dtype=torch.complex128), tensor(1.9238e-08-2.4491e-08j, dtype=torch.complex128))
# ['Day = ', 269]
# (tensor(-2.0048e-07+2.2873e-07j, dtype=torch.complex128), tensor(-9.1799e-08+1.4095e-07j, dtype=torch.complex128))
# ['Day = ', 270]
# (tensor(-2.4947e-07+2.8355e-07j, dtype=torch.complex128), tensor(8.9541e-08+1.1257e-08j, dtype=torch.complex128))
# ['Day = ', 271]
# (tensor(-1.1622e-07+2.4969e-07j, dtype=torch.complex128), tensor(-3.9222e-08+1.5178e-07j, dtype=torch.complex128))
# ['Day = ', 272]
# (tensor(-4.6011e-08+2.0561e-07j, dtype=torch.complex128), tensor(1.9049e-07-8.1237e-09j, dtype=torch.complex128))
# ['Day = ', 273]
# (tensor(-1.0437e-07+1.4603e-07j, dtype=torch.complex128), tensor(-6.3409e-08-7.6012e-09j, dtype=torch.complex128))
# ['Day = ', 274]
# (tensor(-3.8605e-07+5.4133e-07j, dtype=torch.complex128), tensor(2.0026e-07+4.4099e-08j, dtype=torch.complex128))
# ['Day = ', 275]
# (tensor(-3.3102e-07+4.1202e-07j, dtype=torch.complex128), tensor(-2.9852e-07+1.1338e-07j, dtype=torch.complex128))
# ['Day = ', 276]
# (tensor(-3.1620e-07+1.8491e-07j, dtype=torch.complex128), tensor(-1.3168e-07+8.3051e-08j, dtype=torch.complex128))
# ['Day = ', 277]
# (tensor(-2.5278e-07+7.4180e-08j, dtype=torch.complex128), tensor(6.7224e-08+1.0507e-08j, dtype=torch.complex128))
# ['Day = ', 278]
# (tensor(-2.0134e-07+1.2818e-07j, dtype=torch.complex128), tensor(3.8106e-09+5.2929e-08j, dtype=torch.complex128))
# ['Day = ', 279]
# (tensor(2.2346e-08-2.0704e-07j, dtype=torch.complex128), tensor(-1.7501e-07+1.6886e-07j, dtype=torch.complex128))
# ['Day = ', 280]
# (tensor(-1.5314e-07-4.6188e-08j, dtype=torch.complex128), tensor(-3.6545e-08-4.0268e-08j, dtype=torch.complex128))
# ['Day = ', 281]
# (tensor(-2.3925e-07+1.6626e-07j, dtype=torch.complex128), tensor(-1.0685e-07-4.4698e-08j, dtype=torch.complex128))
# ['Day = ', 282]
# (tensor(-3.0451e-07+3.2231e-07j, dtype=torch.complex128), tensor(2.5614e-07-3.0249e-08j, dtype=torch.complex128))
# ['Day = ', 283]
# (tensor(-8.3802e-08+4.7865e-08j, dtype=torch.complex128), tensor(-4.9344e-08+2.6856e-07j, dtype=torch.complex128))
# ['Day = ', 284]
# (tensor(7.0237e-09-4.7706e-08j, dtype=torch.complex128), tensor(-2.3387e-07+1.3213e-08j, dtype=torch.complex128))
# ['Day = ', 285]
# (tensor(-2.7770e-08-7.4748e-08j, dtype=torch.complex128), tensor(-4.1945e-08+1.3853e-07j, dtype=torch.complex128))
# ['Day = ', 286]
# (tensor(-7.1765e-08-8.7130e-08j, dtype=torch.complex128), tensor(-2.6780e-08+8.2395e-08j, dtype=torch.complex128))
# ['Day = ', 287]
# (tensor(-2.4388e-07-2.0613e-08j, dtype=torch.complex128), tensor(-2.1363e-07-1.3431e-07j, dtype=torch.complex128))
# ['Day = ', 288]
# (tensor(-1.0996e-07+3.2696e-08j, dtype=torch.complex128), tensor(-3.5819e-07+1.3795e-07j, dtype=torch.complex128))
# ['Day = ', 289]
# (tensor(-2.4306e-07+2.4600e-07j, dtype=torch.complex128), tensor(5.8299e-10+5.6755e-08j, dtype=torch.complex128))
# ['Day = ', 290]
# (tensor(-1.5282e-07-2.6504e-08j, dtype=torch.complex128), tensor(-2.6411e-08+5.6467e-09j, dtype=torch.complex128))
# ['Day = ', 291]
# (tensor(2.1737e-08+1.7504e-07j, dtype=torch.complex128), tensor(-1.4525e-07+1.7895e-08j, dtype=torch.complex128))
# ['Day = ', 292]
# (tensor(-1.4037e-07+1.3468e-07j, dtype=torch.complex128), tensor(-9.3026e-08+1.4799e-07j, dtype=torch.complex128))
# ['Day = ', 293]
# (tensor(-1.3219e-07+2.8786e-07j, dtype=torch.complex128), tensor(-9.3559e-08+1.6661e-07j, dtype=torch.complex128))
# ['Day = ', 294]
# (tensor(-1.3913e-08+1.6680e-07j, dtype=torch.complex128), tensor(1.4788e-09+3.7520e-08j, dtype=torch.complex128))
# ['Day = ', 295]
# (tensor(1.0916e-07-4.3324e-09j, dtype=torch.complex128), tensor(1.4029e-08-1.2030e-07j, dtype=torch.complex128))
# ['Day = ', 296]
# (tensor(1.3664e-07-9.7345e-08j, dtype=torch.complex128), tensor(5.9981e-08+1.7552e-07j, dtype=torch.complex128))
# ['Day = ', 297]
# (tensor(-9.4263e-08+5.6029e-08j, dtype=torch.complex128), tensor(-1.4748e-07-2.7212e-08j, dtype=torch.complex128))
# ['Day = ', 298]
# (tensor(-2.5146e-08+3.8644e-08j, dtype=torch.complex128), tensor(-2.2774e-07+1.3473e-07j, dtype=torch.complex128))
# ['Day = ', 299]
# (tensor(-1.2886e-07-1.6236e-08j, dtype=torch.complex128), tensor(-2.8181e-07+1.6756e-07j, dtype=torch.complex128))
# ['Day = ', 300]
# (tensor(6.5208e-09+9.8036e-09j, dtype=torch.complex128), tensor(-3.2410e-07-2.6056e-08j, dtype=torch.complex128))
# ['Day = ', 301]
# (tensor(-4.9224e-08+1.9033e-07j, dtype=torch.complex128), tensor(-1.7387e-07+4.7534e-08j, dtype=torch.complex128))
# ['Day = ', 302]
# (tensor(-4.4394e-07+3.1734e-07j, dtype=torch.complex128), tensor(-8.5227e-08+1.9680e-07j, dtype=torch.complex128))
# ['Day = ', 303]
# (tensor(-2.0429e-07+1.9356e-07j, dtype=torch.complex128), tensor(-5.2736e-07+3.0766e-07j, dtype=torch.complex128))
# ['Day = ', 304]
# (tensor(-2.1793e-07+2.6246e-07j, dtype=torch.complex128), tensor(-1.1441e-07+1.1162e-07j, dtype=torch.complex128))
# ['Day = ', 305]
# (tensor(-6.8541e-08-1.0118e-08j, dtype=torch.complex128), tensor(-8.1270e-08+2.0924e-07j, dtype=torch.complex128))
# ['Day = ', 306]
# (tensor(1.5012e-09+1.1996e-07j, dtype=torch.complex128), tensor(7.1904e-08+8.7680e-08j, dtype=torch.complex128))
# ['Day = ', 307]
# (tensor(3.7167e-08+3.2011e-07j, dtype=torch.complex128), tensor(-1.9326e-07+8.9945e-08j, dtype=torch.complex128))
# ['Day = ', 308]
# (tensor(4.0828e-09+4.2255e-07j, dtype=torch.complex128), tensor(9.6216e-08-1.9298e-08j, dtype=torch.complex128))
# ['Day = ', 309]
# (tensor(-2.3998e-08+3.0468e-07j, dtype=torch.complex128), tensor(-7.2465e-08-9.7013e-08j, dtype=torch.complex128))
# ['Day = ', 310]
# (tensor(-1.7895e-07+2.2477e-07j, dtype=torch.complex128), tensor(-2.0479e-07+1.0544e-07j, dtype=torch.complex128))
# ['Day = ', 311]
# (tensor(-2.7569e-07+2.4598e-07j, dtype=torch.complex128), tensor(-2.0138e-07+3.3752e-07j, dtype=torch.complex128))
# ['Day = ', 312]
# (tensor(-1.1029e-07+8.8364e-09j, dtype=torch.complex128), tensor(-5.8699e-08+3.0275e-07j, dtype=torch.complex128))
# ['Day = ', 313]
# (tensor(-1.8595e-07-6.1679e-08j, dtype=torch.complex128), tensor(-3.7115e-07+5.6058e-08j, dtype=torch.complex128))
# ['Day = ', 314]
# (tensor(-2.1458e-07-1.7654e-07j, dtype=torch.complex128), tensor(-3.9733e-07+4.0728e-07j, dtype=torch.complex128))
# ['Day = ', 315]
# (tensor(-2.3244e-07+5.5698e-09j, dtype=torch.complex128), tensor(-1.1856e-07+2.1548e-07j, dtype=torch.complex128))
# ['Day = ', 316]
# (tensor(-9.8455e-08-4.5407e-08j, dtype=torch.complex128), tensor(-2.6177e-07+1.1280e-07j, dtype=torch.complex128))
# ['Day = ', 317]
# (tensor(-2.2362e-07+2.2571e-07j, dtype=torch.complex128), tensor(-1.2714e-08-2.7100e-07j, dtype=torch.complex128))
# ['Day = ', 318]
# (tensor(-3.5152e-07+3.2395e-07j, dtype=torch.complex128), tensor(1.3480e-07+5.5981e-08j, dtype=torch.complex128))
# ['Day = ', 319]
# (tensor(-3.7205e-07+2.7445e-07j, dtype=torch.complex128), tensor(4.4271e-08+4.5130e-07j, dtype=torch.complex128))
# ['Day = ', 320]
# (tensor(-8.9357e-08+2.2831e-07j, dtype=torch.complex128), tensor(-1.8070e-07+2.2997e-07j, dtype=torch.complex128))
# ['Day = ', 321]
# (tensor(-1.9651e-07+3.0758e-07j, dtype=torch.complex128), tensor(5.5086e-08+6.8895e-08j, dtype=torch.complex128))
# ['Day = ', 322]
# (tensor(8.1201e-08+2.8407e-07j, dtype=torch.complex128), tensor(-1.1555e-07+1.1451e-07j, dtype=torch.complex128))
# ['Day = ', 323]
# (tensor(1.0428e-07+3.5898e-07j, dtype=torch.complex128), tensor(-3.9641e-08+2.1131e-07j, dtype=torch.complex128))
# ['Day = ', 324]
# (tensor(4.4190e-08+1.8362e-07j, dtype=torch.complex128), tensor(3.8828e-08+1.5833e-07j, dtype=torch.complex128))
# ['Day = ', 325]
# (tensor(3.6010e-08+2.5201e-07j, dtype=torch.complex128), tensor(-1.7177e-07-5.8949e-08j, dtype=torch.complex128))
# ['Day = ', 326]
# (tensor(-5.4781e-08+4.5842e-07j, dtype=torch.complex128), tensor(1.1787e-07-1.2752e-07j, dtype=torch.complex128))
# ['Day = ', 327]
# (tensor(-1.4888e-07+3.3935e-07j, dtype=torch.complex128), tensor(-6.4701e-08-7.6423e-08j, dtype=torch.complex128))
# ['Day = ', 328]
# (tensor(-4.2701e-07+4.8100e-07j, dtype=torch.complex128), tensor(-3.5221e-08+1.4784e-07j, dtype=torch.complex128))
# ['Day = ', 329]
# (tensor(-4.3065e-07+2.6033e-07j, dtype=torch.complex128), tensor(-2.9380e-07-1.0899e-07j, dtype=torch.complex128))
# ['Day = ', 330]
# (tensor(-2.7720e-07+3.3602e-07j, dtype=torch.complex128), tensor(-4.3051e-07+1.3538e-07j, dtype=torch.complex128))
# ['Day = ', 331]
# (tensor(-3.1074e-07+4.1981e-07j, dtype=torch.complex128), tensor(-2.7924e-07+9.1305e-08j, dtype=torch.complex128))
# ['Day = ', 332]
# (tensor(-2.4183e-07+5.1648e-08j, dtype=torch.complex128), tensor(-2.8461e-07+1.8356e-07j, dtype=torch.complex128))
# ['Day = ', 333]
# (tensor(-5.6014e-08-1.7368e-07j, dtype=torch.complex128), tensor(-4.2491e-07+4.3685e-07j, dtype=torch.complex128))
# ['Day = ', 334]
# (tensor(-1.6731e-07-1.8178e-08j, dtype=torch.complex128), tensor(-2.3915e-07+2.7014e-07j, dtype=torch.complex128))
# ['Day = ', 335]
# (tensor(-2.4736e-07+1.7663e-07j, dtype=torch.complex128), tensor(6.9194e-08+2.5174e-07j, dtype=torch.complex128))
# ['Day = ', 336]
# (tensor(-2.7101e-07+3.1344e-07j, dtype=torch.complex128), tensor(-1.5567e-07+3.3047e-07j, dtype=torch.complex128))
# ['Day = ', 337]
# (tensor(-3.5915e-07+4.8726e-07j, dtype=torch.complex128), tensor(-4.0478e-08+2.1383e-07j, dtype=torch.complex128))
# ['Day = ', 338]
# (tensor(-2.9466e-07+1.6398e-07j, dtype=torch.complex128), tensor(-1.4693e-07-4.6923e-08j, dtype=torch.complex128))
# ['Day = ', 339]
# (tensor(1.0640e-08+1.6980e-07j, dtype=torch.complex128), tensor(-1.5406e-07-2.8545e-08j, dtype=torch.complex128))
# ['Day = ', 340]
# (tensor(-4.3166e-08+1.0649e-07j, dtype=torch.complex128), tensor(-8.5805e-08+7.6781e-08j, dtype=torch.complex128))
# ['Day = ', 341]
# (tensor(5.5240e-08+1.6064e-07j, dtype=torch.complex128), tensor(-1.0458e-07+1.6143e-07j, dtype=torch.complex128))
# ['Day = ', 342]
# (tensor(-1.3380e-07+2.7829e-08j, dtype=torch.complex128), tensor(9.1368e-08-4.2880e-09j, dtype=torch.complex128))
# ['Day = ', 343]
# (tensor(-4.7277e-08+2.5159e-07j, dtype=torch.complex128), tensor(1.2234e-07-1.0318e-08j, dtype=torch.complex128))
# ['Day = ', 344]
# (tensor(1.0374e-07+3.6959e-07j, dtype=torch.complex128), tensor(8.2132e-08-4.9746e-09j, dtype=torch.complex128))
# ['Day = ', 345]
# (tensor(-5.3447e-08+2.6779e-07j, dtype=torch.complex128), tensor(-7.2106e-08+2.2398e-07j, dtype=torch.complex128))
# ['Day = ', 346]
# (tensor(7.7714e-09+1.4428e-07j, dtype=torch.complex128), tensor(1.7611e-07-1.6641e-07j, dtype=torch.complex128))
# ['Day = ', 347]
# (tensor(-9.1415e-08+1.2762e-07j, dtype=torch.complex128), tensor(1.7491e-07+1.0672e-07j, dtype=torch.complex128))
# ['Day = ', 348]
# (tensor(-2.1854e-07+7.4492e-08j, dtype=torch.complex128), tensor(-9.9962e-08-1.3322e-07j, dtype=torch.complex128))
# ['Day = ', 349]
# (tensor(-1.5895e-07+1.3127e-08j, dtype=torch.complex128), tensor(-6.0662e-08-1.1070e-07j, dtype=torch.complex128))
# ['Day = ', 350]
# (tensor(-1.0062e-07+4.7100e-08j, dtype=torch.complex128), tensor(-2.6058e-07+3.8843e-07j, dtype=torch.complex128))
# ['Day = ', 351]
# (tensor(1.5584e-08-3.5804e-08j, dtype=torch.complex128), tensor(-4.3247e-07-4.3553e-08j, dtype=torch.complex128))
# ['Day = ', 352]
# (tensor(-8.5225e-08+2.6050e-08j, dtype=torch.complex128), tensor(-1.4726e-07+8.3776e-08j, dtype=torch.complex128))
# ['Day = ', 353]
# (tensor(-1.4914e-07+1.1020e-07j, dtype=torch.complex128), tensor(-9.3412e-09-2.4852e-08j, dtype=torch.complex128))
# ['Day = ', 354]
# (tensor(1.3291e-08+2.6407e-09j, dtype=torch.complex128), tensor(-9.4335e-08+3.7202e-07j, dtype=torch.complex128))
# ['Day = ', 355]
# (tensor(-8.4916e-08+3.7599e-07j, dtype=torch.complex128), tensor(-2.0503e-07-1.1093e-07j, dtype=torch.complex128))
# ['Day = ', 356]
# (tensor(-9.6923e-08+5.2789e-07j, dtype=torch.complex128), tensor(-1.6468e-07-3.6849e-08j, dtype=torch.complex128))
# ['Day = ', 357]
# (tensor(-2.6643e-07+4.9256e-07j, dtype=torch.complex128), tensor(-9.9165e-08-1.2162e-07j, dtype=torch.complex128))
# ['Day = ', 358]
# (tensor(-3.7933e-08+3.1275e-07j, dtype=torch.complex128), tensor(-1.8520e-07+2.3903e-07j, dtype=torch.complex128))
# ['Day = ', 359]
# (tensor(-9.5600e-08+1.5506e-07j, dtype=torch.complex128), tensor(6.3044e-08+2.9410e-07j, dtype=torch.complex128))
# ['Day = ', 360]
# (tensor(2.3985e-08+2.2056e-07j, dtype=torch.complex128), tensor(-6.8926e-08+1.3030e-07j, dtype=torch.complex128))
# ['Day = ', 361]
# (tensor(8.1987e-09+2.3730e-07j, dtype=torch.complex128), tensor(-1.5762e-07+1.8830e-07j, dtype=torch.complex128))
# ['Day = ', 362]
# (tensor(7.2370e-08+1.5571e-07j, dtype=torch.complex128), tensor(-5.4598e-08+1.1419e-07j, dtype=torch.complex128))
# ['Day = ', 363]
# (tensor(-9.5650e-08+1.9983e-07j, dtype=torch.complex128), tensor(-1.0983e-07+8.8969e-08j, dtype=torch.complex128))
# ['Day = ', 364]
# (tensor(-1.3997e-07+8.6779e-08j, dtype=torch.complex128), tensor(1.2200e-07+4.0130e-08j, dtype=torch.complex128))
# ['Day = ', 365]
# (tensor(-5.0459e-07+4.1781e-07j, dtype=torch.complex128), tensor(-1.0732e-07-5.3035e-08j, dtype=torch.complex128))
# ['Day = ', 366]
# (tensor(-2.0019e-07+3.8223e-07j, dtype=torch.complex128), tensor(-1.8553e-07-2.2239e-08j, dtype=torch.complex128))
# ['Day = ', 367]
# (tensor(-1.9969e-07+6.4963e-08j, dtype=torch.complex128), tensor(-3.0079e-07+1.0265e-07j, dtype=torch.complex128))
# ['Day = ', 368]
# ...
# ['Day = ', 778]
# (tensor(-1.9655e-07+1.4095e-07j, dtype=torch.complex128), tensor(6.7106e-10+1.8762e-08j, dtype=torch.complex128))
# ['Day = ', 779]
# (tensor(-1.9955e-07+3.6976e-07j, dtype=torch.complex128), tensor(-2.0867e-07+4.3926e-08j, dtype=torch.complex128))
# ['Day = ', 780]
# (tensor(-1.6444e-07+5.4793e-07j, dtype=torch.complex128), tensor(-4.3648e-08-2.0942e-08j, dtype=torch.complex128))
# ['Day = ', 781]
# (tensor(-1.4023e-07+6.1295e-07j, dtype=torch.complex128), tensor(-3.8021e-09-9.7384e-08j, dtype=torch.complex128))
# ['Day = ', 782]
# (tensor(5.1052e-08+1.8349e-07j, dtype=torch.complex128), tensor(-6.1890e-08-1.4720e-07j, dtype=torch.complex128))
# ['Day = ', 783]
# (tensor(-1.6210e-07+2.3391e-07j, dtype=torch.complex128), tensor(-1.0212e-07-4.6971e-08j, dtype=torch.complex128))
# ['Day = ', 784]
# (tensor(-1.7739e-07+2.4227e-07j, dtype=torch.complex128), tensor(-3.3519e-08+3.4463e-08j, dtype=torch.complex128))
# ['Day = ', 785]
# (tensor(3.3895e-08+3.7915e-10j, dtype=torch.complex128), tensor(4.2206e-08+5.9704e-08j, dtype=torch.complex128))
# ['Day = ', 786]
# (tensor(-4.9939e-08+1.5419e-07j, dtype=torch.complex128), tensor(2.0698e-07-6.8006e-08j, dtype=torch.complex128))
# ['Day = ', 787]
# (tensor(-8.5383e-08+3.0664e-07j, dtype=torch.complex128), tensor(-1.1017e-08-8.2325e-08j, dtype=torch.complex128))
# ['Day = ', 788]
# (tensor(-1.0634e-07+3.7774e-07j, dtype=torch.complex128), tensor(-1.2544e-07+1.7374e-07j, dtype=torch.complex128))
# ['Day = ', 789]
# (tensor(-8.4795e-08+2.5210e-07j, dtype=torch.complex128), tensor(-6.0144e-08+1.6314e-07j, dtype=torch.complex128))
# ['Day = ', 790]
# (tensor(-4.3225e-08+6.5216e-08j, dtype=torch.complex128), tensor(8.7897e-08+9.5535e-08j, dtype=torch.complex128))
# ['Day = ', 791]
# (tensor(-2.1200e-07+2.6932e-07j, dtype=torch.complex128), tensor(-4.7290e-08+7.4258e-08j, dtype=torch.complex128))
# ['Day = ', 792]
# (tensor(-2.4663e-07+4.8706e-07j, dtype=torch.complex128), tensor(-2.7278e-07+3.1935e-07j, dtype=torch.complex128))
# ['Day = ', 793]
# (tensor(-2.0986e-07+2.1918e-07j, dtype=torch.complex128), tensor(-3.1294e-07+2.9100e-07j, dtype=torch.complex128))
# ['Day = ', 794]
# (tensor(-1.0393e-07+1.2423e-07j, dtype=torch.complex128), tensor(-2.7696e-07+9.0857e-08j, dtype=torch.complex128))
# ['Day = ', 795]
# (tensor(-1.0719e-07+1.4029e-07j, dtype=torch.complex128), tensor(-2.0460e-07+2.6300e-07j, dtype=torch.complex128))
# ['Day = ', 796]
# (tensor(7.9900e-08+9.2706e-08j, dtype=torch.complex128), tensor(2.6881e-08+1.0317e-07j, dtype=torch.complex128))
# ['Day = ', 797]
# (tensor(1.0917e-08+1.1388e-07j, dtype=torch.complex128), tensor(-1.2350e-07+2.2733e-07j, dtype=torch.complex128))
# ['Day = ', 798]
# (tensor(5.6508e-08+1.4243e-08j, dtype=torch.complex128), tensor(-1.7741e-07+2.9386e-07j, dtype=torch.complex128))
# ['Day = ', 799]
# (tensor(1.2030e-07+1.6132e-07j, dtype=torch.complex128), tensor(-1.0560e-07+6.4931e-08j, dtype=torch.complex128))
# ['Day = ', 800]
# (tensor(-4.4260e-08+1.3333e-07j, dtype=torch.complex128), tensor(-6.8569e-08+1.6256e-07j, dtype=torch.complex128))
# ['Day = ', 801]
# (tensor(-5.6698e-08+1.6347e-07j, dtype=torch.complex128), tensor(-1.4672e-07+1.8888e-07j, dtype=torch.complex128))
# ['Day = ', 802]
# (tensor(-4.0892e-08+3.1888e-07j, dtype=torch.complex128), tensor(-3.4663e-07+8.4431e-08j, dtype=torch.complex128))
# ['Day = ', 803]
# (tensor(-8.5886e-09+1.6673e-07j, dtype=torch.complex128), tensor(1.6285e-07+3.3331e-07j, dtype=torch.complex128))
# ['Day = ', 804]
# (tensor(4.1308e-10+2.6189e-08j, dtype=torch.complex128), tensor(-1.9634e-07+1.8383e-07j, dtype=torch.complex128))
# ['Day = ', 805]
# (tensor(-5.0082e-07+1.4335e-07j, dtype=torch.complex128), tensor(-3.0183e-07+1.8265e-07j, dtype=torch.complex128))
# ['Day = ', 806]
# (tensor(-4.0020e-07+6.9839e-08j, dtype=torch.complex128), tensor(-1.0495e-07+1.8360e-07j, dtype=torch.complex128))
# ['Day = ', 807]
# (tensor(-1.8783e-07+2.1087e-07j, dtype=torch.complex128), tensor(-9.3148e-08+2.5555e-07j, dtype=torch.complex128))
# ['Day = ', 808]
# (tensor(-3.6330e-07+8.3668e-08j, dtype=torch.complex128), tensor(-2.1511e-07+5.0837e-07j, dtype=torch.complex128))
# ['Day = ', 809]
# (tensor(-3.7425e-07+2.0895e-07j, dtype=torch.complex128), tensor(-7.2772e-08+2.4568e-07j, dtype=torch.complex128))
# ['Day = ', 810]
# (tensor(-1.3555e-07+4.4647e-07j, dtype=torch.complex128), tensor(3.1893e-08-8.7324e-08j, dtype=torch.complex128))
# ['Day = ', 811]
# (tensor(-2.8813e-07+2.3883e-07j, dtype=torch.complex128), tensor(8.2883e-08+1.2834e-07j, dtype=torch.complex128))
# ['Day = ', 812]
# (tensor(-2.9817e-07+1.4762e-07j, dtype=torch.complex128), tensor(-2.7413e-09-8.8213e-08j, dtype=torch.complex128))
# ['Day = ', 813]
# (tensor(-6.9302e-08+1.6241e-07j, dtype=torch.complex128), tensor(-7.4877e-08-2.6152e-07j, dtype=torch.complex128))
# ['Day = ', 814]
# (tensor(-2.8254e-07+1.0336e-07j, dtype=torch.complex128), tensor(-7.0788e-09+7.7144e-08j, dtype=torch.complex128))
# ['Day = ', 815]
# (tensor(-1.7543e-07+3.0796e-07j, dtype=torch.complex128), tensor(1.2359e-07-1.9295e-07j, dtype=torch.complex128))
# ['Day = ', 816]
# (tensor(-1.7699e-07+4.0950e-07j, dtype=torch.complex128), tensor(2.9384e-08-2.2937e-07j, dtype=torch.complex128))
# ['Day = ', 817]
# (tensor(-4.9440e-07+4.3316e-07j, dtype=torch.complex128), tensor(3.8132e-08-1.5438e-07j, dtype=torch.complex128))
# ['Day = ', 818]
# (tensor(-5.2046e-07+4.2780e-07j, dtype=torch.complex128), tensor(-2.0896e-07-5.3322e-08j, dtype=torch.complex128))
# ['Day = ', 819]
# (tensor(-3.5906e-07+1.1509e-07j, dtype=torch.complex128), tensor(-1.7888e-07-1.3880e-07j, dtype=torch.complex128))
# ['Day = ', 820]
# (tensor(-4.2290e-07+2.8618e-07j, dtype=torch.complex128), tensor(-9.5061e-08+5.5620e-08j, dtype=torch.complex128))
# ['Day = ', 821]
# (tensor(-3.4358e-07+1.6460e-07j, dtype=torch.complex128), tensor(2.6773e-08+4.2016e-08j, dtype=torch.complex128))
# ['Day = ', 822]
# (tensor(-3.3423e-07+3.6789e-08j, dtype=torch.complex128), tensor(5.5592e-08+1.0786e-07j, dtype=torch.complex128))
# ['Day = ', 823]
# (tensor(-1.4963e-07+2.5649e-07j, dtype=torch.complex128), tensor(-2.4360e-08-6.7770e-08j, dtype=torch.complex128))
# ['Day = ', 824]
# (tensor(-1.3295e-07+1.9053e-07j, dtype=torch.complex128), tensor(-3.3257e-08+1.5604e-07j, dtype=torch.complex128))
# ['Day = ', 825]
# (tensor(-5.1658e-08+6.8197e-08j, dtype=torch.complex128), tensor(2.2249e-08-3.6256e-08j, dtype=torch.complex128))
# ['Day = ', 826]
# (tensor(2.7564e-08+1.8802e-07j, dtype=torch.complex128), tensor(2.0554e-08+2.7775e-07j, dtype=torch.complex128))
# ['Day = ', 827]
# (tensor(-2.9317e-08+4.6320e-08j, dtype=torch.complex128), tensor(1.1749e-07+1.1646e-07j, dtype=torch.complex128))
# ['Day = ', 828]
# (tensor(-7.8704e-08+1.5103e-07j, dtype=torch.complex128), tensor(6.2480e-08+9.2178e-08j, dtype=torch.complex128))
# ['Day = ', 829]
# (tensor(-3.0593e-08+1.1883e-07j, dtype=torch.complex128), tensor(-3.9210e-08-5.5388e-08j, dtype=torch.complex128))
# ['Day = ', 830]
# (tensor(1.0696e-07+4.4478e-08j, dtype=torch.complex128), tensor(1.5271e-07-1.9186e-08j, dtype=torch.complex128))
# ['Day = ', 831]
# (tensor(1.4097e-07+6.3040e-08j, dtype=torch.complex128), tensor(1.0166e-07-3.8998e-08j, dtype=torch.complex128))
# ['Day = ', 832]
# (tensor(1.7864e-07-7.8006e-08j, dtype=torch.complex128), tensor(-6.0285e-08-3.6183e-08j, dtype=torch.complex128))
# ['Day = ', 833]
# (tensor(2.1091e-07-1.2578e-07j, dtype=torch.complex128), tensor(-6.4793e-09+3.6346e-08j, dtype=torch.complex128))
# ['Day = ', 834]
# (tensor(1.0504e-07-6.3523e-08j, dtype=torch.complex128), tensor(5.0914e-08-3.7178e-09j, dtype=torch.complex128))
# ['Day = ', 835]
# (tensor(7.7186e-08-6.6796e-08j, dtype=torch.complex128), tensor(6.4670e-08-9.5201e-08j, dtype=torch.complex128))
# ['Day = ', 836]
# (tensor(-1.0763e-07+9.1180e-08j, dtype=torch.complex128), tensor(3.3783e-08-1.4800e-07j, dtype=torch.complex128))
# ['Day = ', 837]
# (tensor(-3.4531e-07+1.7112e-07j, dtype=torch.complex128), tensor(-1.1624e-07+3.4418e-08j, dtype=torch.complex128))
# ['Day = ', 838]
# (tensor(-2.1848e-07+3.3918e-08j, dtype=torch.complex128), tensor(-3.0081e-08+9.7098e-08j, dtype=torch.complex128))
# ['Day = ', 839]
# (tensor(-1.6869e-07-1.3085e-07j, dtype=torch.complex128), tensor(-4.4128e-08-7.0205e-09j, dtype=torch.complex128))
# ['Day = ', 840]
# (tensor(4.9796e-08-4.7000e-08j, dtype=torch.complex128), tensor(-7.5948e-08-1.3737e-07j, dtype=torch.complex128))
# ['Day = ', 841]
# (tensor(-4.2789e-08+1.1365e-08j, dtype=torch.complex128), tensor(2.0849e-08-2.7485e-07j, dtype=torch.complex128))
# ['Day = ', 842]
# (tensor(3.6651e-08-8.5459e-08j, dtype=torch.complex128), tensor(1.8442e-07-8.2534e-08j, dtype=torch.complex128))
# ['Day = ', 843]
# (tensor(1.4273e-07-8.4921e-08j, dtype=torch.complex128), tensor(-3.7227e-08+7.2252e-08j, dtype=torch.complex128))
# ['Day = ', 844]
# (tensor(3.7455e-08+9.1756e-08j, dtype=torch.complex128), tensor(-1.7544e-07+4.3724e-09j, dtype=torch.complex128))
# ['Day = ', 845]
# (tensor(-1.0375e-07+2.4592e-07j, dtype=torch.complex128), tensor(4.4126e-08-1.1195e-07j, dtype=torch.complex128))
# ['Day = ', 846]
# (tensor(-1.0682e-07+1.1335e-07j, dtype=torch.complex128), tensor(2.5527e-07+1.4087e-07j, dtype=torch.complex128))
# ['Day = ', 847]
# (tensor(-4.7737e-08-1.0358e-07j, dtype=torch.complex128), tensor(-1.0134e-07+1.1510e-07j, dtype=torch.complex128))
# ['Day = ', 848]
# (tensor(-2.4580e-08+5.3585e-08j, dtype=torch.complex128), tensor(-2.7310e-07-3.5690e-08j, dtype=torch.complex128))
# ['Day = ', 849]
# (tensor(1.2982e-07+1.1517e-07j, dtype=torch.complex128), tensor(3.1837e-08+2.1682e-07j, dtype=torch.complex128))
# ['Day = ', 850]
# (tensor(1.8597e-07+1.8109e-08j, dtype=torch.complex128), tensor(-1.2512e-07+2.2325e-08j, dtype=torch.complex128))
# ['Day = ', 851]
# (tensor(7.5269e-09+1.3283e-07j, dtype=torch.complex128), tensor(-8.6349e-08+1.6348e-07j, dtype=torch.complex128))
# ['Day = ', 852]
# (tensor(1.0716e-08-6.9625e-09j, dtype=torch.complex128), tensor(3.4883e-08+4.0270e-08j, dtype=torch.complex128))
# ['Day = ', 853]
# (tensor(6.7202e-08+1.8009e-07j, dtype=torch.complex128), tensor(-7.2629e-08+1.5546e-07j, dtype=torch.complex128))
# ['Day = ', 854]
# (tensor(-1.0951e-08+3.8920e-08j, dtype=torch.complex128), tensor(7.7645e-08-7.2335e-08j, dtype=torch.complex128))
# ['Day = ', 855]
# (tensor(1.1277e-07+1.0350e-07j, dtype=torch.complex128), tensor(1.8270e-08-2.4860e-08j, dtype=torch.complex128))
# ['Day = ', 856]
# (tensor(1.8503e-07+1.2968e-07j, dtype=torch.complex128), tensor(1.9364e-07+5.3316e-08j, dtype=torch.complex128))
# ['Day = ', 857]
# (tensor(1.9918e-08+1.5896e-07j, dtype=torch.complex128), tensor(-1.4808e-07-9.5238e-08j, dtype=torch.complex128))
# ['Day = ', 858]
# (tensor(4.5415e-09-4.3888e-08j, dtype=torch.complex128), tensor(1.4716e-07+1.5857e-07j, dtype=torch.complex128))
# ['Day = ', 859]
# (tensor(1.6528e-08+1.0851e-07j, dtype=torch.complex128), tensor(-3.4148e-08+8.0549e-08j, dtype=torch.complex128))
# ['Day = ', 860]
# (tensor(-2.9564e-07+2.0137e-07j, dtype=torch.complex128), tensor(-1.1950e-07-8.9754e-08j, dtype=torch.complex128))
# ['Day = ', 861]
# (tensor(1.7427e-07+2.8913e-07j, dtype=torch.complex128), tensor(3.4298e-08-1.9509e-07j, dtype=torch.complex128))
# ['Day = ', 862]
# (tensor(4.4915e-08+2.4778e-07j, dtype=torch.complex128), tensor(-1.2758e-07-2.1734e-07j, dtype=torch.complex128))
# ['Day = ', 863]
# (tensor(4.8535e-08+1.4673e-07j, dtype=torch.complex128), tensor(5.3977e-08+1.3155e-08j, dtype=torch.complex128))
# ['Day = ', 864]
# (tensor(2.3726e-08+2.0841e-07j, dtype=torch.complex128), tensor(-8.8283e-08+9.0369e-09j, dtype=torch.complex128))
# ['Day = ', 865]
# (tensor(-1.0601e-07+1.7471e-07j, dtype=torch.complex128), tensor(-2.0958e-07+6.0155e-08j, dtype=torch.complex128))
# ['Day = ', 866]
# (tensor(4.1182e-09+1.9848e-07j, dtype=torch.complex128), tensor(-3.0691e-07-2.3631e-07j, dtype=torch.complex128))
# ['Day = ', 867]
# (tensor(1.3733e-07-1.7771e-08j, dtype=torch.complex128), tensor(-1.3259e-07+2.6561e-07j, dtype=torch.complex128))
# ['Day = ', 868]
# (tensor(1.0133e-07+1.5688e-08j, dtype=torch.complex128), tensor(-1.2720e-07+1.9626e-07j, dtype=torch.complex128))
# ['Day = ', 869]
# (tensor(5.0007e-08+2.7575e-08j, dtype=torch.complex128), tensor(-1.3395e-07+7.0763e-09j, dtype=torch.complex128))
# ['Day = ', 870]
# (tensor(2.5536e-08-3.1322e-08j, dtype=torch.complex128), tensor(4.8932e-08+1.6487e-07j, dtype=torch.complex128))
# ['Day = ', 871]
# (tensor(8.7699e-08-1.4898e-08j, dtype=torch.complex128), tensor(-1.8180e-07+9.3019e-08j, dtype=torch.complex128))
# ['Day = ', 872]
# (tensor(-4.4249e-08-1.5167e-08j, dtype=torch.complex128), tensor(-2.1944e-07+7.9909e-08j, dtype=torch.complex128))
# ['Day = ', 873]
# (tensor(-3.6915e-08-6.1014e-08j, dtype=torch.complex128), tensor(8.8104e-08-1.5128e-07j, dtype=torch.complex128))
# ['Day = ', 874]
# (tensor(4.7668e-08-6.0345e-08j, dtype=torch.complex128), tensor(-1.2608e-07+1.9402e-07j, dtype=torch.complex128))
# ['Day = ', 875]
# (tensor(-1.3078e-07+2.7584e-07j, dtype=torch.complex128), tensor(-2.4438e-07-7.5765e-08j, dtype=torch.complex128))
# ['Day = ', 876]
# (tensor(-1.2793e-07+1.7703e-08j, dtype=torch.complex128), tensor(-3.3867e-07+2.8657e-07j, dtype=torch.complex128))
# ['Day = ', 877]
# (tensor(-1.7938e-07+2.4432e-07j, dtype=torch.complex128), tensor(-1.3671e-07+1.6533e-07j, dtype=torch.complex128))
# ['Day = ', 878]
# (tensor(-3.4325e-07+2.5444e-07j, dtype=torch.complex128), tensor(2.7966e-09+2.8969e-07j, dtype=torch.complex128))
# ['Day = ', 879]
# (tensor(-2.6224e-07+1.8586e-07j, dtype=torch.complex128), tensor(-2.9638e-07+1.1660e-07j, dtype=torch.complex128))
# ['Day = ', 880]
# (tensor(-1.3954e-07+1.0425e-10j, dtype=torch.complex128), tensor(-9.8698e-08+1.2557e-07j, dtype=torch.complex128))
# ['Day = ', 881]
# (tensor(4.9869e-08-9.6161e-08j, dtype=torch.complex128), tensor(-1.6134e-07+2.8198e-07j, dtype=torch.complex128))
# ['Day = ', 882]
# (tensor(1.0282e-08+1.8442e-07j, dtype=torch.complex128), tensor(6.1521e-08+9.8220e-08j, dtype=torch.complex128))
# ['Day = ', 883]
# (tensor(-4.1881e-08+2.2290e-07j, dtype=torch.complex128), tensor(5.2019e-08+2.2490e-07j, dtype=torch.complex128))
# ['Day = ', 884]
# (tensor(8.2534e-08+2.2672e-07j, dtype=torch.complex128), tensor(-1.2113e-08+5.0959e-08j, dtype=torch.complex128))
# ['Day = ', 885]
# (tensor(-2.2897e-07+2.5477e-07j, dtype=torch.complex128), tensor(3.2389e-08+1.0394e-07j, dtype=torch.complex128))
# ['Day = ', 886]
# (tensor(-1.2888e-07+1.9678e-07j, dtype=torch.complex128), tensor(1.3882e-07-4.4999e-07j, dtype=torch.complex128))
# ['Day = ', 887]
# (tensor(-4.3457e-07+3.5188e-07j, dtype=torch.complex128), tensor(1.6026e-08-7.6332e-08j, dtype=torch.complex128))
# ['Day = ', 888]
# (tensor(-5.4137e-07+5.0613e-07j, dtype=torch.complex128), tensor(2.0734e-07-2.7907e-07j, dtype=torch.complex128))
# ['Day = ', 889]
# (tensor(-3.3302e-07+4.1959e-07j, dtype=torch.complex128), tensor(-4.8015e-08-3.0229e-11j, dtype=torch.complex128))
# ['Day = ', 890]
# (tensor(-6.1105e-08+2.4101e-07j, dtype=torch.complex128), tensor(2.2897e-08+7.3703e-08j, dtype=torch.complex128))
# ['Day = ', 891]
# (tensor(-1.5218e-07-4.1723e-08j, dtype=torch.complex128), tensor(-1.9531e-07+3.6363e-08j, dtype=torch.complex128))
# ['Day = ', 892]
# (tensor(-1.9959e-07+8.0503e-09j, dtype=torch.complex128), tensor(-1.0458e-07+6.4999e-08j, dtype=torch.complex128))
# ['Day = ', 893]
# (tensor(-6.1007e-08-1.5908e-08j, dtype=torch.complex128), tensor(-1.6056e-07-2.2128e-08j, dtype=torch.complex128))
# ['Day = ', 894]
# (tensor(-1.1271e-07+2.1624e-07j, dtype=torch.complex128), tensor(4.9176e-08-1.6618e-07j, dtype=torch.complex128))
# ['Day = ', 895]
# (tensor(-1.4420e-07+2.0586e-07j, dtype=torch.complex128), tensor(-3.5089e-07-1.2141e-07j, dtype=torch.complex128))
# ['Day = ', 896]
# (tensor(4.5088e-08+1.1443e-07j, dtype=torch.complex128), tensor(-1.0736e-07+1.6981e-07j, dtype=torch.complex128))
# ['Day = ', 897]
# (tensor(2.3327e-08-8.8253e-08j, dtype=torch.complex128), tensor(2.9924e-07+5.8536e-08j, dtype=torch.complex128))
# ['Day = ', 898]
# (tensor(-2.6493e-08+3.0210e-08j, dtype=torch.complex128), tensor(-2.1544e-07-1.8076e-07j, dtype=torch.complex128))
# ['Day = ', 899]
# (tensor(-2.0513e-07+1.1728e-07j, dtype=torch.complex128), tensor(-1.9568e-07-4.1601e-07j, dtype=torch.complex128))
# ['Day = ', 900]

# %%
## Write spectral data for possible restart
##
torch.save(zmn1,datapath+'zmn1.spectral.pt')
torch.save(zmn2,datapath+'zmn2.spectral.pt')
torch.save(dmn1,datapath+'dmn1.spectral.pt')
torch.save(dmn2,datapath+'dmn2.spectral.pt')
torch.save(tmn1,datapath+'tmn1.spectral.pt')
torch.save(tmn2,datapath+'tmn2.spectral.pt')
torch.save(qmn1,datapath+'qmn1.spectral.pt')
torch.save(qmn2,datapath+'qmn2.spectral.pt')
